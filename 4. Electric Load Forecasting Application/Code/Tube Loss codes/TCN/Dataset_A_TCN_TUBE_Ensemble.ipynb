# %% [markdown]
# # Ensembling for Dataset A

# %%
import pandas as pd
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tcn import TCN
import time

# %%
# ------------------- DATA PREP -------------------
df = pd.read_csv("D:/SELC_AD/Code/paper_code/data/Dataset_A.csv", index_col='DateTime', parse_dates=True)
df = df[df['LCLid'] == 'MAC000002']

df.columns = df.columns.str.strip()
df.rename(columns={'KWH/hh (per half hour)': 'kwh'}, inplace=True)
df['kwh'] = pd.to_numeric(df['kwh'].astype(str).str.strip(), errors='coerce')
df = df.ffill()

# %%
data = df["kwh"].to_numpy().reshape((len(df["kwh"]), 1))
mean_data = np.mean(data)
std_data = np.std(data)
data_normalized = (data - mean_data) / std_data if std_data != 0 else data - mean_data
print(mean_data)
print(std_data)

# %%
def truncate(x, feature_cols=range(1), target_cols=range(1), train_len=48, test_len=1):
    in_, out_ = [], []
    for i in range(len(x) - train_len - test_len + 1):
        in_.append(x[i:(i + train_len), feature_cols].tolist())
        out_.append(x[(i + train_len):(i + train_len + test_len), target_cols].tolist())
    return np.array(in_), np.array(out_)

X_in, X_out = truncate(data_normalized, feature_cols=range(1), target_cols=range(1), train_len=24, test_len=1) # Dataset A
print(X_in.shape, X_out.shape)

# %%
n = X_in.shape[0]
train_end = int(n * 0.8)
val_end = int(n * 0.9)

train_x, val_x, test_x = X_in[:train_end], X_in[train_end:val_end], X_in[val_end:]
train_y, val_y, test_y = X_out[:train_end], X_out[train_end:val_end], X_out[val_end:]
train_y = np.repeat(train_y, 2, axis=1)
val_y = np.repeat(val_y, 2, axis=1)
test_y = np.repeat(test_y, 2, axis=1)

# %%
# ------------------- LOSS FUNCTION -------------------
q = 0.95
l = 2

r = 0.7
delta = 0.002

def confidence_loss(y_true, y_pred):
    y_true = y_true[:, 0]
    f1, f2 = y_pred[:, 0], y_pred[:, 1]
    c1 = (1 - q) * (y_true - f2)
    c2 = (1 - q) * (f1 - y_true)
    c3 = q * (f2 - y_true)
    c4 = q * (y_true - f1)
    loss = tf.where(tf.math.logical_and(y_true <= f1, y_true >= f2),
                    tf.where(y_true > r * (f1 + f2), c1, c2),
                    tf.where(f2 > y_true, c3, c4)) + (delta * tf.math.abs(f1 - f2))
    return loss

# %%
# ------------------- MODEL -------------------
def build_tcn_model(input_shape, num_outputs=2):
    inputs = Input(shape=input_shape)
    x = TCN(nb_filters=64, kernel_size=3, nb_stacks=1, dilations=(1, 2, 4, 8),
            dropout_rate=0.3, return_sequences=False)(inputs)
    outputs = Dense(num_outputs)(x)
    return Model(inputs, outputs)

# %%
# ------------------- ENSEMBLE TRAINING -------------------
results = []
batch_size = 64

for run in range(1, 6):
    print(f"\n===== RUN {run} =====")
    tf.keras.utils.set_random_seed(run)  # different seed for each run

    model = build_tcn_model(input_shape=(train_x.shape[1], train_x.shape[2]))
    model.compile(loss=confidence_loss, optimizer=Adam(learning_rate=0.001))

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')
    start_time = datetime.datetime.now()

    model.fit(train_x, train_y, validation_data=(val_x, val_y),
              epochs=100, batch_size=batch_size, verbose=1, callbacks=[early_stopping])

    end_time = datetime.datetime.now()
    total_time = end_time - start_time
    print('seconds taken:', round(total_time.total_seconds(), 1),
            '\nstart_time:', start_time.strftime('%H:%M:%S'),
            'end_time:', end_time.strftime('%H:%M:%S'))

    # ----- Validation -----
    val_pred = model.predict(val_x, verbose=0)
    val_y_true = np.squeeze(val_y[:, 0]) * std_data + mean_data
    val_u = val_pred[:, 0] * std_data + mean_data
    val_l = val_pred[:, 1] * std_data + mean_data
  
    # ----- Test -----
    test_pred = model.predict(test_x, verbose=0)
    test_y_true = np.squeeze(test_y[:, 0]) * std_data + mean_data
    test_u = test_pred[:, 0] * std_data + mean_data
    test_l = test_pred[:, 1] * std_data + mean_data
    np.save(f"TCN_TUBE_UK_test_upper_run{run}_dtA.npy", test_u)
    np.save(f"TCN_TUBE_UK_test_lower_run{run}_dtA.npy", test_l)

    # Metrics
    val_picp = np.mean((val_u > val_y_true) * (val_l < val_y_true))
    val_mpiw = np.mean(val_u - val_l)
    test_picp = np.mean((test_u > test_y_true) * (test_l < test_y_true))
    test_mpiw = np.mean(test_u - test_l)

    results.append({
        "Training Time (s)": total_time,
        "Run": run,
        "Val_PICP": val_picp,
        "Val_MPIW": val_mpiw,
        "Test_PICP": test_picp,
        "Test_MPIW": test_mpiw
    })
# Out:
# ===== RUN 1 =====
# Epoch 1/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.9117 - val_loss: 0.1328
# Epoch 2/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1589 - val_loss: 0.1233
# Epoch 3/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1386 - val_loss: 0.1160
# Epoch 4/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1308 - val_loss: 0.1116
# Epoch 5/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1280 - val_loss: 0.1079
# Epoch 6/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1231 - val_loss: 0.1053
# Epoch 7/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1210 - val_loss: 0.1050
# Epoch 8/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1199 - val_loss: 0.1029
# Epoch 9/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1185 - val_loss: 0.1021
# Epoch 10/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1176 - val_loss: 0.1023
# Epoch 11/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1161 - val_loss: 0.1028
# Epoch 12/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1150 - val_loss: 0.0986
# Epoch 13/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1127 - val_loss: 0.0965
# Epoch 14/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1115 - val_loss: 0.0973
# Epoch 15/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1118 - val_loss: 0.0954
# Epoch 16/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1084 - val_loss: 0.0976
# Epoch 17/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1093 - val_loss: 0.0951
# Epoch 18/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1082 - val_loss: 0.0938
# Epoch 19/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1082 - val_loss: 0.0934
# Epoch 20/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1058 - val_loss: 0.0932
# Epoch 21/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1061 - val_loss: 0.0929
# Epoch 22/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1064 - val_loss: 0.0885
# Epoch 23/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1042 - val_loss: 0.0932
# Epoch 24/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1047 - val_loss: 0.0917
# Epoch 25/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1043 - val_loss: 0.0900
# Epoch 26/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1023 - val_loss: 0.0903
# Epoch 27/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1016 - val_loss: 0.0906
# seconds taken: 98.0
# start_time: 15:16:43 end_time: 15:18:21
#
# ===== RUN 2 =====
# Epoch 1/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.4243 - val_loss: 0.1236
# Epoch 2/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1449 - val_loss: 0.1156
# Epoch 3/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1302 - val_loss: 0.1111
# Epoch 4/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1216 - val_loss: 0.1085
# Epoch 5/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1201 - val_loss: 0.1047
# Epoch 6/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1184 - val_loss: 0.1021
# Epoch 7/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1152 - val_loss: 0.0999
# Epoch 8/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1116 - val_loss: 0.0977
# Epoch 9/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1106 - val_loss: 0.0971
# Epoch 10/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1094 - val_loss: 0.0992
# Epoch 11/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1099 - val_loss: 0.0955
# Epoch 12/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1077 - val_loss: 0.0947
# Epoch 13/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1053 - val_loss: 0.0961
# Epoch 14/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1044 - val_loss: 0.0933
# Epoch 15/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1028 - val_loss: 0.0928
# Epoch 16/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1038 - val_loss: 0.0938
# Epoch 17/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1049 - val_loss: 0.0923
# Epoch 18/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1017 - val_loss: 0.0925
# Epoch 19/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1020 - val_loss: 0.0914
# Epoch 20/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1015 - val_loss: 0.0911
# Epoch 21/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0992 - val_loss: 0.0907
# Epoch 22/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1000 - val_loss: 0.0886
# Epoch 23/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0986 - val_loss: 0.0899
# Epoch 24/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0970 - val_loss: 0.0888
# Epoch 25/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0978 - val_loss: 0.0883
# Epoch 26/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0976 - val_loss: 0.0899
# Epoch 27/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0964 - val_loss: 0.0879
# Epoch 28/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0966 - val_loss: 0.0877
# Epoch 29/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0968 - val_loss: 0.0889
# Epoch 30/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0977 - val_loss: 0.0869
# Epoch 31/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0965 - val_loss: 0.0872
# Epoch 32/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0957 - val_loss: 0.0877
# Epoch 33/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0951 - val_loss: 0.0902
# Epoch 34/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0947 - val_loss: 0.0865
# Epoch 35/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0931 - val_loss: 0.0893
# Epoch 36/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0940 - val_loss: 0.0876
# Epoch 37/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0932 - val_loss: 0.0869
# Epoch 38/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0941 - val_loss: 0.0868
# Epoch 39/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0937 - val_loss: 0.0874
# seconds taken: 143.4
# start_time: 15:18:22 end_time: 15:20:45
#
# ===== RUN 3 =====
# Epoch 1/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.5502 - val_loss: 0.1353
# Epoch 2/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1536 - val_loss: 0.1201
# Epoch 3/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1349 - val_loss: 0.1129
# Epoch 4/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1271 - val_loss: 0.1089
# Epoch 5/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1232 - val_loss: 0.1060
# Epoch 6/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1216 - val_loss: 0.1072
# Epoch 7/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1210 - val_loss: 0.1062
# Epoch 8/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1166 - val_loss: 0.1044
# Epoch 9/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1155 - val_loss: 0.1012
# Epoch 10/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1131 - val_loss: 0.1002
# Epoch 11/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1138 - val_loss: 0.0987
# Epoch 12/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1126 - val_loss: 0.0969
# Epoch 13/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1099 - val_loss: 0.0975
# Epoch 14/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1107 - val_loss: 0.0968
# Epoch 15/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1081 - val_loss: 0.0971
# Epoch 16/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1078 - val_loss: 0.0976
# Epoch 17/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1085 - val_loss: 0.0985
# Epoch 18/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1072 - val_loss: 0.0921
# Epoch 19/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1060 - val_loss: 0.0979
# Epoch 20/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1076 - val_loss: 0.0934
# Epoch 21/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1042 - val_loss: 0.0961
# Epoch 22/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1037 - val_loss: 0.0950
# Epoch 23/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1031 - val_loss: 0.0937
# seconds taken: 91.0
# start_time: 15:20:46 end_time: 15:22:17
#
# ===== RUN 4 =====
# Epoch 1/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 1.0024 - val_loss: 0.1397
# Epoch 2/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1618 - val_loss: 0.1237
# Epoch 3/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1379 - val_loss: 0.1124
# Epoch 4/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1291 - val_loss: 0.1122
# Epoch 5/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1264 - val_loss: 0.1085
# Epoch 6/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1214 - val_loss: 0.1080
# Epoch 7/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1191 - val_loss: 0.1072
# Epoch 8/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1172 - val_loss: 0.1033
# Epoch 9/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1157 - val_loss: 0.1030
# Epoch 10/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1144 - val_loss: 0.1034
# Epoch 11/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1146 - val_loss: 0.1022
# Epoch 12/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1128 - val_loss: 0.1021
# Epoch 13/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1120 - val_loss: 0.0993
# Epoch 14/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1113 - val_loss: 0.0988
# Epoch 15/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1109 - val_loss: 0.0976
# Epoch 16/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1078 - val_loss: 0.0970
# Epoch 17/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1092 - val_loss: 0.0943
# Epoch 18/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1055 - val_loss: 0.0965
# Epoch 19/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1066 - val_loss: 0.0970
# Epoch 20/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1060 - val_loss: 0.0958
# Epoch 21/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1040 - val_loss: 0.0947
# Epoch 22/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1034 - val_loss: 0.0944
# seconds taken: 87.8
# start_time: 15:22:18 end_time: 15:23:46
#
# ===== RUN 5 =====
# Epoch 1/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.5089 - val_loss: 0.1243
# Epoch 2/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1502 - val_loss: 0.1168
# Epoch 3/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1311 - val_loss: 0.1121
# Epoch 4/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1239 - val_loss: 0.1067
# Epoch 5/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1205 - val_loss: 0.1048
# Epoch 6/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1178 - val_loss: 0.1066
# Epoch 7/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1162 - val_loss: 0.1019
# Epoch 8/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1139 - val_loss: 0.1024
# Epoch 9/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1114 - val_loss: 0.0978
# Epoch 10/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1118 - val_loss: 0.0989
# Epoch 11/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1095 - val_loss: 0.0958
# Epoch 12/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1074 - val_loss: 0.0951
# Epoch 13/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1081 - val_loss: 0.0918
# Epoch 14/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1067 - val_loss: 0.0954
# Epoch 15/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1078 - val_loss: 0.0947
# Epoch 16/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1058 - val_loss: 0.0921
# Epoch 17/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1028 - val_loss: 0.0901
# Epoch 18/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1021 - val_loss: 0.0906
# Epoch 19/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1027 - val_loss: 0.0893
# Epoch 20/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1025 - val_loss: 0.0875
# Epoch 21/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1028 - val_loss: 0.0895
# Epoch 22/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1005 - val_loss: 0.0889
# Epoch 23/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0997 - val_loss: 0.0883
# Epoch 24/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0999 - val_loss: 0.0896
# Epoch 25/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0978 - val_loss: 0.0873
# Epoch 26/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1002 - val_loss: 0.0878
# Epoch 27/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0976 - val_loss: 0.0883
# Epoch 28/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0986 - val_loss: 0.0869
# Epoch 29/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0980 - val_loss: 0.0877
# Epoch 30/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0979 - val_loss: 0.0860
# Epoch 31/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0973 - val_loss: 0.0861
# Epoch 32/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0941 - val_loss: 0.0859
# Epoch 33/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0949 - val_loss: 0.0874
# Epoch 34/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0941 - val_loss: 0.0862
# Epoch 35/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0935 - val_loss: 0.0843
# Epoch 36/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0948 - val_loss: 0.0836
# Epoch 37/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0945 - val_loss: 0.0847
# Epoch 38/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0951 - val_loss: 0.0837
# Epoch 39/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0941 - val_loss: 0.0842
# Epoch 40/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0934 - val_loss: 0.0845
# Epoch 41/100
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0934 - val_loss: 0.0849
# seconds taken: 154.8
# start_time: 15:23:47 end_time: 15:26:22

# %%
# ================== Save results ==================
results_df = pd.DataFrame(results)
results_df.to_excel("ensemble_results_dtA.xlsx", index=False)
print("\nResults saved to Excel.")

# %%
# ================== Save test data ==================
np.save("test_X_dtA.npy", test_x)
np.save("test_y_dtA.npy", test_y)

# %% [markdown]
# ## Computing new PICP and MPIW (AFTER ENSEMBLING)

# %%
# Path where bounds are stored
base_path = ""
runs = 5

# %%
# Load test_y

import os

test_y = np.load(os.path.join(base_path, "test_y_dtA.npy"))

# Storage for all runs
all_upper = []
all_lower = []

# %%
# Load bounds from each run
for run in range(1, runs+1):
    lower_bounds = np.load(os.path.join(base_path, f"TCN_TUBE_UK_test_lower_run{run}_dtA.npy"))
    upper_bounds = np.load(os.path.join(base_path, f"TCN_TUBE_UK_test_upper_run{run}_dtA.npy"))
    
    all_lower.append(lower_bounds)
    all_upper.append(upper_bounds)

# %%
# Convert to arrays: shape = (runs, num_samples)
all_lower = np.array(all_lower)
all_upper = np.array(all_upper)

# Mean across runs (axis=0 → average over runs)
mean_lower = np.mean(all_lower, axis=0)
mean_upper = np.mean(all_upper, axis=0)

# %%
# Std. deviation (sigma) across runs
sigma_lower = np.std(all_lower, axis=0, ddof=1)  # ddof=1 for sample std
sigma_upper = np.std(all_upper, axis=0, ddof=1)

# %%
print(np.mean(sigma_lower))
print(np.mean(sigma_upper))

# %%
# Calculate new bounds using formula
factor = 1.96 * (1 / np.sqrt(runs))
new_upper = mean_upper + factor * sigma_upper
new_lower = mean_lower - factor * sigma_lower

# %%
test_y_true = np.squeeze(test_y[:, 0]) * std_data + mean_data

PICP = np.mean((new_upper > test_y_true) * (new_lower < test_y_true))
MPIW = np.mean(new_upper - new_lower)

# %%
print(PICP)
print(MPIW)

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt

start = 0
end = 200  # Or any other small window

subset_range = range(start, end)

plt.figure(figsize=(12, 6))
plt.plot(subset_range, test_y_true[start:end], label='Actual', color='green')
plt.plot(subset_range, new_upper[start:end], label='Upper Bound (q2)', color='red')
plt.plot(subset_range, new_lower[start:end], label='Lower Bound (q1)', color='blue')
plt.fill_between(subset_range, new_lower[start:end], new_upper[start:end], color='gray', alpha=0.3, label='Prediction Interval')
plt.xlabel('Time Steps')
plt.ylabel('Consumption')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
