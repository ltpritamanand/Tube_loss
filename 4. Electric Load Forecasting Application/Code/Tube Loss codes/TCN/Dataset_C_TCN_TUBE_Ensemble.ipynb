# %% [markdown]
# # Ensembling for Dataset C

# %%
import pandas as pd
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tcn import TCN
import time

# %%
# ------------------- DATA PREP -------------------
df = pd.read_csv("D:/SELC_AD/Code/paper_code/data/Dataset_C.csv", index_col='DateTime', parse_dates=True)
df = df[df['LCLid'] == 'MAC000006']

df.columns = df.columns.str.strip()
df.rename(columns={'KWH/hh (per half hour)': 'kwh'}, inplace=True)
df['kwh'] = pd.to_numeric(df['kwh'].astype(str).str.strip(), errors='coerce')
df = df.ffill()

# %%
data = df["kwh"].to_numpy().reshape((len(df["kwh"]), 1))
mean_data = np.mean(data)
std_data = np.std(data)
data_normalized = (data - mean_data) / std_data if std_data != 0 else data - mean_data
print(mean_data)
print(std_data)

# %%
def truncate(x, feature_cols=range(1), target_cols=range(1), train_len=48, test_len=1):
    in_, out_ = [], []
    for i in range(len(x) - train_len - test_len + 1):
        in_.append(x[i:(i + train_len), feature_cols].tolist())
        out_.append(x[(i + train_len):(i + train_len + test_len), target_cols].tolist())
    return np.array(in_), np.array(out_)

X_in, X_out = truncate(data_normalized, feature_cols=range(1), target_cols=range(1), train_len=48, test_len=1)
print(X_in.shape, X_out.shape)

# %%
n = X_in.shape[0]
train_end = int(n * 0.8)
val_end = int(n * 0.9)

train_x, val_x, test_x = X_in[:train_end], X_in[train_end:val_end], X_in[val_end:]
train_y, val_y, test_y = X_out[:train_end], X_out[train_end:val_end], X_out[val_end:]
train_y = np.repeat(train_y, 2, axis=1)
val_y = np.repeat(val_y, 2, axis=1)
test_y = np.repeat(test_y, 2, axis=1)

# %%
# ------------------- LOSS FUNCTION -------------------
q = 0.95
l = 2

r = 0.8
delta = 0.001

def confidence_loss(y_true, y_pred):
    y_true = y_true[:, 0]
    f1, f2 = y_pred[:, 0], y_pred[:, 1]
    c1 = (1 - q) * (y_true - f2)
    c2 = (1 - q) * (f1 - y_true)
    c3 = q * (f2 - y_true)
    c4 = q * (y_true - f1)
    loss = tf.where(tf.math.logical_and(y_true <= f1, y_true >= f2),
                    tf.where(y_true > r * (f1 + f2), c1, c2),
                    tf.where(f2 > y_true, c3, c4)) + (delta * tf.math.abs(f1 - f2))
    return loss

# %%
# ------------------- MODEL -------------------
def build_tcn_model(input_shape, num_outputs=2):
    inputs = Input(shape=input_shape)
    x = TCN(nb_filters=64, kernel_size=3, nb_stacks=1, dilations=(1, 2, 4, 8),
            dropout_rate=0.3, return_sequences=False)(inputs)
    outputs = Dense(num_outputs)(x)
    return Model(inputs, outputs)

# %%
# ------------------- ENSEMBLE TRAINING -------------------
results = []
batch_size = 64

for run in range(1, 6):
    print(f"\n===== RUN {run} =====")
    tf.keras.utils.set_random_seed(run)  # different seed for each run

    model = build_tcn_model(input_shape=(train_x.shape[1], train_x.shape[2]))
    model.compile(loss=confidence_loss, optimizer=Adam(learning_rate=0.001))

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')
    start_time = datetime.datetime.now()

    model.fit(train_x, train_y, validation_data=(val_x, val_y),
              epochs=100, batch_size=batch_size, verbose=1, callbacks=[early_stopping])

    end_time = datetime.datetime.now()
    total_time = end_time - start_time
    print('seconds taken:', round(total_time.total_seconds(), 1),
            '\nstart_time:', start_time.strftime('%H:%M:%S'),
            'end_time:', end_time.strftime('%H:%M:%S'))

    # ----- Validation -----
    val_pred = model.predict(val_x, verbose=0)
    val_y_true = np.squeeze(val_y[:, 0]) * std_data + mean_data
    val_u = val_pred[:, 0] * std_data + mean_data
    val_l = val_pred[:, 1] * std_data + mean_data
  
    # ----- Test -----
    test_pred = model.predict(test_x, verbose=0)
    test_y_true = np.squeeze(test_y[:, 0]) * std_data + mean_data
    test_u = test_pred[:, 0] * std_data + mean_data
    test_l = test_pred[:, 1] * std_data + mean_data
    np.save(f"TCN_TUBE_UK_test_upper_run{run}_dtC.npy", test_u)
    np.save(f"TCN_TUBE_UK_test_lower_run{run}_dtC.npy", test_l)

    # Metrics
    val_picp = np.mean((val_u > val_y_true) * (val_l < val_y_true))
    val_mpiw = np.mean(val_u - val_l)
    test_picp = np.mean((test_u > test_y_true) * (test_l < test_y_true))
    test_mpiw = np.mean(test_u - test_l)

    results.append({
        "Training Time (s)": total_time,
        "Run": run,
        "Val_PICP": val_picp,
        "Val_MPIW": val_mpiw,
        "Test_PICP": test_picp,
        "Test_MPIW": test_mpiw
    })
# Out:
# ===== RUN 1 =====
# Epoch 1/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 1.0676 - val_loss: 0.1425
# Epoch 2/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.1623 - val_loss: 0.1263
# Epoch 3/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.1413 - val_loss: 0.1224
# Epoch 4/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1346 - val_loss: 0.1196
# Epoch 5/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1312 - val_loss: 0.1200
# Epoch 6/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1301 - val_loss: 0.1182
# Epoch 7/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1284 - val_loss: 0.1195
# Epoch 8/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1270 - val_loss: 0.1167
# Epoch 9/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1240 - val_loss: 0.1169
# Epoch 10/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1258 - val_loss: 0.1158
# Epoch 11/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1226 - val_loss: 0.1167
# Epoch 12/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1230 - val_loss: 0.1149
# Epoch 13/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1216 - val_loss: 0.1150
# Epoch 14/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.1215 - val_loss: 0.1149
# Epoch 15/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1204 - val_loss: 0.1137
# Epoch 16/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1210 - val_loss: 0.1146
# Epoch 17/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.1206 - val_loss: 0.1139
# Epoch 18/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1196 - val_loss: 0.1129
# Epoch 19/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1196 - val_loss: 0.1152
# Epoch 20/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1175 - val_loss: 0.1132
# Epoch 21/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1185 - val_loss: 0.1137
# Epoch 22/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1186 - val_loss: 0.1120
# Epoch 23/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1179 - val_loss: 0.1141
# Epoch 24/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1179 - val_loss: 0.1132
# Epoch 25/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1162 - val_loss: 0.1130
# Epoch 26/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1167 - val_loss: 0.1131
# Epoch 27/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1158 - val_loss: 0.1123
# seconds taken: 162.5
# start_time: 15:38:31 end_time: 15:41:13
#
# ===== RUN 2 =====
# Epoch 1/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.4439 - val_loss: 0.1385
# Epoch 2/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1505 - val_loss: 0.1270
# Epoch 3/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1371 - val_loss: 0.1217
# Epoch 4/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1332 - val_loss: 0.1214
# Epoch 5/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1311 - val_loss: 0.1180
# Epoch 6/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1287 - val_loss: 0.1191
# Epoch 7/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1281 - val_loss: 0.1180
# Epoch 8/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1265 - val_loss: 0.1176
# Epoch 9/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1258 - val_loss: 0.1195
# Epoch 10/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1249 - val_loss: 0.1173
# Epoch 11/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1242 - val_loss: 0.1148
# Epoch 12/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 0.1228 - val_loss: 0.1148
# Epoch 13/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1228 - val_loss: 0.1145
# Epoch 14/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1228 - val_loss: 0.1180
# Epoch 15/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1217 - val_loss: 0.1154
# Epoch 16/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1207 - val_loss: 0.1172
# Epoch 17/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1206 - val_loss: 0.1143
# Epoch 18/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1204 - val_loss: 0.1150
# Epoch 19/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1198 - val_loss: 0.1135
# Epoch 20/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1188 - val_loss: 0.1145
# Epoch 21/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1183 - val_loss: 0.1136
# Epoch 22/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1191 - val_loss: 0.1134
# Epoch 23/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1181 - val_loss: 0.1140
# Epoch 24/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1184 - val_loss: 0.1141
# Epoch 25/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1172 - val_loss: 0.1128
# Epoch 26/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1170 - val_loss: 0.1126
# Epoch 27/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1172 - val_loss: 0.1125
# Epoch 28/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1164 - val_loss: 0.1126
# Epoch 29/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1164 - val_loss: 0.1116
# Epoch 30/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1156 - val_loss: 0.1120
# Epoch 31/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1162 - val_loss: 0.1108
# Epoch 32/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1153 - val_loss: 0.1114
# Epoch 33/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1155 - val_loss: 0.1116
# Epoch 34/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1147 - val_loss: 0.1111
# Epoch 35/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1149 - val_loss: 0.1128
# Epoch 36/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1155 - val_loss: 0.1111
# seconds taken: 204.2
# start_time: 15:41:14 end_time: 15:44:38
#
# ===== RUN 3 =====
# Epoch 1/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 0.5916 - val_loss: 0.1307
# Epoch 2/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1481 - val_loss: 0.1222
# Epoch 3/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1327 - val_loss: 0.1210
# Epoch 4/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1286 - val_loss: 0.1202
# Epoch 5/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1262 - val_loss: 0.1181
# Epoch 6/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1250 - val_loss: 0.1178
# Epoch 7/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1232 - val_loss: 0.1171
# Epoch 8/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1214 - val_loss: 0.1168
# Epoch 9/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1210 - val_loss: 0.1156
# Epoch 10/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1204 - val_loss: 0.1166
# Epoch 11/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1206 - val_loss: 0.1170
# Epoch 12/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1188 - val_loss: 0.1151
# Epoch 13/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1184 - val_loss: 0.1164
# Epoch 14/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1179 - val_loss: 0.1140
# Epoch 15/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1167 - val_loss: 0.1145
# Epoch 16/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1166 - val_loss: 0.1127
# Epoch 17/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1163 - val_loss: 0.1122
# Epoch 18/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1153 - val_loss: 0.1145
# Epoch 19/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1143 - val_loss: 0.1131
# Epoch 20/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1140 - val_loss: 0.1122
# Epoch 21/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1150 - val_loss: 0.1130
# Epoch 22/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1132 - val_loss: 0.1124
# seconds taken: 132.1
# start_time: 15:44:40 end_time: 15:46:52
#
# ===== RUN 4 =====
# Epoch 1/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 1.0247 - val_loss: 0.1383
# Epoch 2/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1595 - val_loss: 0.1253
# Epoch 3/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1395 - val_loss: 0.1213
# Epoch 4/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1348 - val_loss: 0.1209
# Epoch 5/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1308 - val_loss: 0.1185
# Epoch 6/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1283 - val_loss: 0.1205
# Epoch 7/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1279 - val_loss: 0.1193
# Epoch 8/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1264 - val_loss: 0.1199
# Epoch 9/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1257 - val_loss: 0.1175
# Epoch 10/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1249 - val_loss: 0.1174
# Epoch 11/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1226 - val_loss: 0.1160
# Epoch 12/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1217 - val_loss: 0.1179
# Epoch 13/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1219 - val_loss: 0.1144
# Epoch 14/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1205 - val_loss: 0.1148
# Epoch 15/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1201 - val_loss: 0.1138
# Epoch 16/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1184 - val_loss: 0.1165
# Epoch 17/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1194 - val_loss: 0.1136
# Epoch 18/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1181 - val_loss: 0.1143
# Epoch 19/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1177 - val_loss: 0.1135
# Epoch 20/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1174 - val_loss: 0.1131
# Epoch 21/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1165 - val_loss: 0.1144
# Epoch 22/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1157 - val_loss: 0.1137
# Epoch 23/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1168 - val_loss: 0.1129
# Epoch 24/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.1153 - val_loss: 0.1115
# Epoch 25/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1141 - val_loss: 0.1128
# Epoch 26/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1148 - val_loss: 0.1121
# Epoch 27/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.1149 - val_loss: 0.1129
# Epoch 28/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1150 - val_loss: 0.1134
# Epoch 29/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1139 - val_loss: 0.1113
# Epoch 30/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1135 - val_loss: 0.1111
# Epoch 31/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1124 - val_loss: 0.1115
# Epoch 32/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1141 - val_loss: 0.1105
# Epoch 33/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1133 - val_loss: 0.1103
# Epoch 34/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1134 - val_loss: 0.1111
# Epoch 35/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1124 - val_loss: 0.1131
# Epoch 36/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1134 - val_loss: 0.1083
# Epoch 37/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1125 - val_loss: 0.1098
# Epoch 38/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1115 - val_loss: 0.1107
# Epoch 39/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1115 - val_loss: 0.1103
# Epoch 40/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1108 - val_loss: 0.1107
# Epoch 41/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1105 - val_loss: 0.1095
# seconds taken: 251.5
# start_time: 15:46:53 end_time: 15:51:05
#
# ===== RUN 5 =====
# Epoch 1/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.5957 - val_loss: 0.1346
# Epoch 2/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1583 - val_loss: 0.1248
# Epoch 3/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1424 - val_loss: 0.1206
# Epoch 4/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1364 - val_loss: 0.1194
# Epoch 5/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1338 - val_loss: 0.1195
# Epoch 6/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1312 - val_loss: 0.1167
# Epoch 7/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1292 - val_loss: 0.1164
# Epoch 8/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1277 - val_loss: 0.1157
# Epoch 9/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1258 - val_loss: 0.1155
# Epoch 10/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1265 - val_loss: 0.1165
# Epoch 11/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1263 - val_loss: 0.1131
# Epoch 12/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1261 - val_loss: 0.1157
# Epoch 13/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1241 - val_loss: 0.1137
# Epoch 14/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1235 - val_loss: 0.1142
# Epoch 15/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1230 - val_loss: 0.1133
# Epoch 16/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1224 - val_loss: 0.1119
# Epoch 17/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1210 - val_loss: 0.1132
# Epoch 18/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1226 - val_loss: 0.1112
# Epoch 19/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1205 - val_loss: 0.1119
# Epoch 20/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1201 - val_loss: 0.1125
# Epoch 21/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1196 - val_loss: 0.1123
# Epoch 22/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1202 - val_loss: 0.1103
# Epoch 23/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1194 - val_loss: 0.1121
# Epoch 24/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1192 - val_loss: 0.1105
# Epoch 25/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1187 - val_loss: 0.1109
# Epoch 26/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1159 - val_loss: 0.1119
# Epoch 27/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1194 - val_loss: 0.1087
# Epoch 28/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1166 - val_loss: 0.1089
# Epoch 29/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1178 - val_loss: 0.1093
# Epoch 30/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1180 - val_loss: 0.1115
# Epoch 31/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1176 - val_loss: 0.1108
# Epoch 32/100
# 456/456 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1176 - val_loss: 0.1098
# seconds taken: 171.4
# start_time: 15:51:06 end_time: 15:53:57

# %%
# ================== Save results ==================
results_df = pd.DataFrame(results)
results_df.to_excel("ensemble_results_dtC.xlsx", index=False)
print("\nResults saved to Excel.")

# %%
# ================== Save test data ==================
np.save("test_X_dtC.npy", test_x)
np.save("test_y_dtC.npy", test_y)

# %% [markdown]
# ## Computing new PICP and MPIW (AFTER ENSEMBLING)

# %%
# Path where bounds are stored
base_path = ""
runs = 5

# %%
# Load test_y

import os

test_y = np.load(os.path.join(base_path, "test_y_dtC.npy"))

# Storage for all runs
all_upper = []
all_lower = []

# %%
# Load bounds from each run
for run in range(1, runs+1):
    folder_path = os.path.join(base_path, f"it{run}")
    lower_bounds = np.load(os.path.join(base_path, f"TCN_TUBE_UK_test_lower_run{run}_dtC.npy"))
    upper_bounds = np.load(os.path.join(base_path, f"TCN_TUBE_UK_test_upper_run{run}_dtC.npy"))
    
    all_lower.append(lower_bounds)
    all_upper.append(upper_bounds)

# %%
# Convert to arrays: shape = (runs, num_samples)
all_lower = np.array(all_lower)
all_upper = np.array(all_upper)

# Mean across runs (axis=0 → average over runs)
mean_lower = np.mean(all_lower, axis=0)
mean_upper = np.mean(all_upper, axis=0)

# %%
# Std. deviation (sigma) across runs
sigma_lower = np.std(all_lower, axis=0, ddof=1)  # ddof=1 for sample std
sigma_upper = np.std(all_upper, axis=0, ddof=1)

# %%
print(np.mean(sigma_lower))
print(np.mean(sigma_upper))

# %%
# Calculate new bounds using formula
factor = 1.96 * (1 / np.sqrt(runs))
new_upper = mean_upper + factor * sigma_upper
new_lower = mean_lower - factor * sigma_lower

# %%
test_y_true = np.squeeze(test_y[:, 0]) * std_data + mean_data

PICP = np.mean((new_upper > test_y_true) * (new_lower < test_y_true))
MPIW = np.mean(new_upper - new_lower)

# %%
print(PICP)
print(MPIW)

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt
# Choose a slice — e.g., first 200 points
start = 0
end = 200  # Or any other small window

subset_range = range(start, end)

plt.figure(figsize=(12, 6))
plt.plot(subset_range, test_y_true[start:end], label='Actual', color='green')
plt.plot(subset_range, new_upper[start:end], label='Upper Bound (q2)', color='red')
plt.plot(subset_range, new_lower[start:end], label='Lower Bound (q1)', color='blue')
plt.fill_between(subset_range, new_lower[start:end], new_upper[start:end], color='gray', alpha=0.3, label='Prediction Interval')
plt.xlabel('Time Steps')
plt.ylabel('Consumption')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
