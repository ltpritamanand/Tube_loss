# %% [markdown]
# # Wind Speed

# %% [markdown]
# ## Import Libraries

# %%
pip install keras-tcn
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.5.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.26.4)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.17.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->keras-tcn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->keras-tcn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->keras-tcn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->keras-tcn) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->keras-tcn) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->keras-tcn) (2.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->keras-tcn) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->keras-tcn) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow->keras-tcn) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->keras-tcn) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow->keras-tcn) (3.1.3)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->keras-tcn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->keras-tcn) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->keras-tcn) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->keras-tcn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->keras-tcn) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->keras-tcn) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->keras-tcn) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow->keras-tcn) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->keras-tcn) (0.1.2)
# Downloading keras_tcn-3.5.6-py3-none-any.whl (12 kB)
# Installing collected packages: keras-tcn
# Successfully installed keras-tcn-3.5.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tcn import TCN
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, concatenate

import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from pylab import rcParams
import statsmodels.api as sm
import plotly.express as px
import os
import csv

from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
# from keras.preprocessing.sequence import TimeseriesGenerator

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
# from keras.preprocessing.sequence import TimeseriesGenerator

import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, LSTM, Dropout, SimpleRNN
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import RepeatVector, TimeDistributed, Input, BatchNormalization, multiply, concatenate, Activation, dot
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop,Adam,SGD,Adagrad, Nadam, Ftrl
from tensorflow.keras.utils import plot_model
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import keras.backend as K
import datetime
from tensorflow.keras import regularizers
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# ## Read CSV

# %%
df = pd.read_csv("/kaggle/input/los-angeles/los angeles.csv",index_col='Date/Time', parse_dates=True)

# %%
dataset = 'LosAngeles'
savefilename = 'LosAngeles.csv'

# %%
df = df[df.index.minute == 0]

# %%
df = pd.DataFrame({'120m' : df['120m']}, index=df.index)

# %%
display(df)
# Out:
#                       120m
# Date/Time
# 2020-01-01 00:00:00   3.25
# 2020-01-01 01:00:00   4.96
# 2020-01-01 02:00:00   5.55
# 2020-01-01 03:00:00   5.08
# 2020-01-01 04:00:00   4.86
# ...                    ...
# 2022-12-31 19:00:00   5.55
# 2022-12-31 20:00:00  14.48
# 2022-12-31 21:00:00  15.95
# 2022-12-31 22:00:00   7.17
# 2022-12-31 23:00:00   6.17
#
# [26304 rows x 1 columns]

# %%
df.describe()
# Out:
#                120m
# count  26304.000000
# mean       3.082705
# std        2.182042
# min        0.020000
# 25%        1.510000
# 50%        2.570000
# 75%        4.260000
# max       19.320000

# %%
df.isna().sum()
# Out:
# 120m    0
# dtype: int64

# %%
plt.plot(df)
plt.title('Wind Speed Over Time')
plt.xlabel('Datetime')
plt.ylabel('Wind Speed (m/s)')
plt.savefig('jaisalmer.png')
plt.show()

# %%
plot_acf(df, lags=100)  # You can adjust the number of lags as needed
plt.title('Autocorrelation Function (ACF)')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %%
plot_pacf(df, lags=50)  # You can adjust the number of lags as needed
plt.title('Partial Autocorrelation Function (PACF)')
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.show()

# %% [markdown]
# ## Define Loss and Model

# %% [markdown]
# ### Loss

# %% [markdown]
# #### QD Loss

# %%
from tensorflow.keras.utils import register_keras_serializable

# %%
# for qd_objective
# lambda_ = 0.05 # lambda in loss fn
alpha_ = 0.1  # capturing (1-alpha)% of samples
soften_ = 160. #160
n_ = 128 # batch size
lambda1 = 0.95
lambda2 = 0.05

def change_qd_var(alpha, soften, n, l1, l2):
    global alpha_, soften_, n_, lambda1, lambda2
    alpha_ = alpha
    soften_ = soften
    n_ = n
    lambda1 = l1
    lambda2 = l2

@register_keras_serializable()
def qd_objective(y_true, y_pred):
    '''Loss_QD-soft, from algorithm 1'''
    y_true = y_true[:, 0]
    y_u = y_pred[:, 0]
    y_l = y_pred[:, 1]

    K_SU = tf.sigmoid(soften_ * (y_u - y_true))
    K_SL = tf.sigmoid(soften_ * (y_true - y_l))
    K_S = tf.multiply(K_SU, K_SL)

    # Calculate MPIW_c using tf.cond
    sum_K_S = tf.reduce_sum(K_S)
    numerator_MPIW_c = tf.reduce_sum(tf.multiply((y_u - y_l), K_S))
    MPIW_c = tf.cond(
        pred=tf.equal(sum_K_S, 0),
        true_fn=lambda: tf.constant(0.0, dtype=tf.float32),
        false_fn=lambda: numerator_MPIW_c / (sum_K_S + 1e-8)
    )

    PICP_S = tf.reduce_mean(K_S)

    penalty = tf.maximum(0.0, y_l - y_true) + tf.maximum(0.0, y_true - y_u)
    non_zero_terms = tf.boolean_mask(penalty, penalty > 0)

    # Calculate pen_loss using tf.cond
    size = tf.size(non_zero_terms)
    pen_loss = tf.cond(
        pred=tf.equal(size, 0),
        true_fn=lambda: tf.constant(0.0, dtype=tf.float32),
        false_fn=lambda: tf.reduce_mean(non_zero_terms)
    )

    Loss_S = lambda1 * MPIW_c + \
             lambda2 * n_ / (alpha_ * (1 - alpha_)) * tf.square(tf.maximum(0.0, (1 - alpha_) - PICP_S)) + \
             pen_loss
    return Loss_S

# %% [markdown]
# #### Confidence Loss(Tube Loss)

# %%
# for confidance loss
r= 0.95 # confidence {0-1}
q = 0.95
delta = 0.001 # 0.05,0.1
qq1 = 0.025
qq2 = 0.975

def change_confidence_var(r_, q_, delta_):
    global r, q, delta
    r = r_
    q = q_
    delta = delta_

def confidence_loss(y_true, y_pred):
    y_true = y_true[:, 0]
    f1 = y_pred[:, 0]
    f2 = y_pred[:, 1]

    c1 = (1 - q) * (y_true - f2)
    c2 = (1 - q) * (f1 - y_true)
    c3 = q * (f2 - y_true)
    c4 = q * (y_true - f1)

    condition1 = tf.math.logical_and(y_true <= f1, y_true >= f2)
    condition2 = y_true > (r * f1 + (1 - r) * f2)
    condition3 = f2 > y_true

    loss_part1 = tf.where(condition1,
                          tf.where(condition2, c1, c2),
                          tf.where(condition3, c3, c4))
    loss = loss_part1 + (delta * tf.math.abs(f1 - f2))
    return loss

# %% [markdown]
# #### Quantile Loss

# %%
from tensorflow.keras.saving import register_keras_serializable
@register_keras_serializable()
def quantile_loss(quantile):
    def loss(y_true, y_pred):
        e = y_true - y_pred
        return tf.reduce_mean(tf.maximum(quantile * e, (quantile - 1) * e), axis=-1)
    return loss

# %% [markdown]
# ### LSTM Model

# %%
def create_lstm(input_shape, layer_units, output_units, dropout_rate=0.0):
    model = Sequential()
    for i, units in enumerate(layer_units[:-1]):
        model.add(LSTM(units=units, return_sequences=True, input_shape=input_shape, activation="relu"))
        if dropout_rate > 0.0:
            model.add(Dropout(dropout_rate))  # Adding dropout between LSTM layers
    # Last LSTM layer without return_sequences
    model.add(LSTM(units=layer_units[-1], activation="relu"))
    if dropout_rate > 0.0:
        model.add(Dropout(dropout_rate))  # Adding dropout after the last LSTM layer
    model.add(Dense(output_units))  # Output layer
    return model

# %% [markdown]
# ### GRU Model

# %%
def create_gru(input_shape, layer_units, output_units, dropout_rate=0.0):
    model = Sequential()
    for i, units in enumerate(layer_units[:-1]):
        model.add(GRU(units=units, return_sequences=True, input_shape=input_shape, activation="relu"))
        if dropout_rate > 0.0:
            model.add(Dropout(dropout_rate))  # Adding dropout between GRU layers
    # Last GRU layer without return_sequences
    model.add(GRU(units=layer_units[-1], activation="relu"))
    if dropout_rate > 0.0:
        model.add(Dropout(dropout_rate))  # Adding dropout after the last GRU layer
    model.add(Dense(output_units))  # Output layer
    return model

# %% [markdown]
# ### TCN Model

# %%
# def create_tcn(input_shape, layer_units, output_units, kernel=3, dropout_rate=0.0):
#     model = Sequential()
#     # print(layer_units)
#     i=0
#     for units in layer_units[:-1]:
#         model.add(TCN(nb_filters=units, kernel_size=kernel, nb_stacks=1, dilations=[2**i], dropout_rate=dropout_rate, return_sequences=True,activation='relu'))
#         i=i+1
#     model.add(TCN(nb_filters=layer_units[-1], kernel_size=kernel, nb_stacks=1, dilations=[2**i], dropout_rate=dropout_rate,activation='relu'))
#     model.add(Dense(output_units))  # Output layer
#     return model

# %%
from tensorflow.keras.layers import Input, Conv1D, ReLU, Dropout, Add, Flatten, Dense
from tensorflow.keras.models import Model

def tcn_block(x, filters, kernel_size, dilation_rate, dropout_rate):
    original_x = x
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    if original_x.shape[-1] != filters:
        original_x = Conv1D(filters=filters, kernel_size=1, padding='same')(original_x)
    x = Add()([original_x, x])
    return x

# %%
def create_tcn(input_shape, filters_list, kernel_size, dropout_rate):
    input_layer = Input(shape=input_shape)
    x = input_layer
    dilation_rates = [2**i for i in range(len(filters_list))]
    for filters, dilation_rate in zip(filters_list, dilation_rates):
        x = tcn_block(x, filters, kernel_size, dilation_rate, dropout_rate)
    x = Flatten()(x)
    output_layer = Dense(2)(x)
    model = Model(inputs=input_layer, outputs=output_layer)
    return model

# %% [markdown]
# ## Train and Test

# %% [markdown]
# #### Split Data

# %%
input_window_size = 24  # window size

# %%
# Time-based train-test split
validation_size = 0.15
test_size = 0.15
split_index_val = int(len(df) * (1 - validation_size - test_size))
split_index_test = int(len(df) * (1 - test_size))

train_data = df[:split_index_val]
validation_data = df[split_index_val:split_index_test]
test_data = df[split_index_test:]

# %%
def truncate(x, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=100, test_len=20):
    in_, out_= [], []
    for i in range(len(x)-train_len-test_len+1):
        in_.append(x[i:(i+train_len), feature_cols].tolist())
        out_.append(x[(i+train_len):(i+train_len+test_len), target_cols].tolist())
    return np.array(in_), np.array(out_)

# %%
train_x, train_y = truncate(train_data.values, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=input_window_size, test_len=1)
val_x, val_y = truncate(validation_data.values, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=input_window_size, test_len=1)
test_x, test_y = truncate(test_data.values, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=input_window_size, test_len=1)

# %%
print("Train shapes:", train_x.shape, train_y.shape)
print("Validation shapes:", val_x.shape, val_y.shape)
print("Test shapes:", test_x.shape, test_y.shape)
# Out:
# Train shapes: (18388, 24, 1) (18388, 1, 1)
# Validation shapes: (3922, 24, 1) (3922, 1, 1)
# Test shapes: (3922, 24, 1) (3922, 1, 1)

# %% [markdown]
# #### MinMax Normalization

# %%
# Min-Max normalization for input features
scaler_x = MinMaxScaler()
scaler_x.fit(train_x.reshape(-1, 1))  # Fit scaler only on training data
train_x = scaler_x.transform(train_x.reshape(-1, 1)).reshape(train_x.shape)
val_x = scaler_x.transform(val_x.reshape(-1, 1)).reshape(val_x.shape)
test_x = scaler_x.transform(test_x.reshape(-1, 1)).reshape(test_x.shape)

# Min-Max normalization for target values
scaler_y = MinMaxScaler()
scaler_y.fit(train_y.reshape(-1, 1))  # Fit scaler only on training data
train_y = scaler_y.transform(train_y.reshape(-1, 1)).reshape(train_y.shape)
val_y = scaler_y.transform(val_y.reshape(-1, 1)).reshape(val_y.shape)
test_y = scaler_y.transform(test_y.reshape(-1, 1)).reshape(test_y.shape)

# %% [markdown]
# #### Model Train

# %% [markdown]
# ##### Save to CSV

# %%
def save_to_csv(filename, *data):
    try:
        with open(filename, 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(data)
        print("Data appended successfully to", filename)
    except Exception as e:
        print("Error:", e)

# save_to_csv(savefilename, "")

# %% [markdown]
# ##### QD

# %% [markdown]
# ###### QD LSTM

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()


for dropout in [0.1]:
    for layers in [[128]]:
        for alp in [0.05]:
            for sof in [160]:
                for l1 in [2]:
                    for l2 in [0.007]:
                        change_qd_var(alp, sof, 128, l1, l2)
                        QD = create_lstm((input_window_size,1),layers,2,dropout)
                        QD.compile(loss=qd_objective,optimizer=Adam(learning_rate=0.001))
                        epc = 300
                        stop_patience = 10
                        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
                        start_time = datetime.datetime.now()
                        history = QD.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
                        end_time = datetime.datetime.now()
                        total_time = end_time - start_time
                        total_time = round(total_time.total_seconds(),2)
                        print('seconds taken:', total_time, '\nstart_time:', start_time.strftime('%H:%M:%S'), 'end_time:', end_time.strftime('%H:%M:%S'))
                        y_pred = QD.predict(test_x, verbose=0)
                        y_pred = scaler_y.inverse_transform(y_pred)
                        test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
                        test_y_ = np.squeeze(test_y_[:,0])
                        y_u_pred = y_pred[:,0]
                        y_l_pred = y_pred[:,1]
                        K_u = y_u_pred > test_y_
                        K_l = y_l_pred < test_y_
                        PICP = np.mean(K_u * K_l)
                        MPIW = np.round(np.mean(y_u_pred - y_l_pred),3)
                        print('PICP:', PICP)
                        print('MPIW:', MPIW)
                        save_to_csv("qd_"+savefilename, dataset, "QD_LSTM", PICP, MPIW, total_time, stop_patience, input_window_size, alpha_, soften_, n_, lambda1, lambda2, layers, dropout)
                        print(dataset, "QD_LSTM", PICP, MPIW, total_time, stop_patience, input_window_size, alpha_, soften_, n_, lambda1, lambda2, layers, dropout)
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 4.9384 - val_loss: 0.7864
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7065 - val_loss: 0.7566
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6933 - val_loss: 0.7145
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6589 - val_loss: 0.6683
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6285 - val_loss: 0.6499
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5964 - val_loss: 0.6044
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5773 - val_loss: 0.5738
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5566 - val_loss: 0.6802
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6021 - val_loss: 0.6216
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5810 - val_loss: 0.5439
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5399 - val_loss: 0.5915
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5515 - val_loss: 0.5361
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5550 - val_loss: 0.5822
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5437 - val_loss: 0.6673
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5558 - val_loss: 0.5335
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5269 - val_loss: 0.5193
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4986 - val_loss: 0.5097
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4918 - val_loss: 0.5156
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5054 - val_loss: 0.5168
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4900 - val_loss: 0.5138
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4904 - val_loss: 0.5334
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4949 - val_loss: 0.5091
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4927 - val_loss: 0.5294
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5248 - val_loss: 0.4974
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4814 - val_loss: 0.5525
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4963 - val_loss: 0.5356
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4882 - val_loss: 0.4926
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4740 - val_loss: 0.5353
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4927 - val_loss: 0.4901
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4767 - val_loss: 0.4804
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4658 - val_loss: 0.4825
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4623 - val_loss: 0.4768
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4721 - val_loss: 0.5384
# Epoch 34/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4892 - val_loss: 0.4760
# Epoch 35/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4558 - val_loss: 0.4695
# Epoch 36/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4624 - val_loss: 0.4735
# Epoch 37/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4496 - val_loss: 0.4711
# Epoch 38/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4773 - val_loss: 0.6441
# Epoch 39/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4950 - val_loss: 0.4837
# Epoch 40/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4603 - val_loss: 0.4669
# Epoch 41/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4510 - val_loss: 0.4731
# Epoch 42/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4550 - val_loss: 0.4664
# Epoch 43/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4521 - val_loss: 0.4607
# Epoch 44/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4500 - val_loss: 0.4576
# Epoch 45/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4469 - val_loss: 0.4595
# Epoch 46/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4403 - val_loss: 0.4751
# Epoch 47/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4407 - val_loss: 0.4702
# Epoch 48/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4472 - val_loss: 0.4537
# Epoch 49/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4534 - val_loss: 0.5009
# Epoch 50/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4494 - val_loss: 0.4675
# Epoch 51/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4504 - val_loss: 0.4588
# Epoch 52/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4328 - val_loss: 0.4601
# Epoch 53/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4434 - val_loss: 0.4608
# Epoch 54/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4389 - val_loss: 0.4659
# Epoch 55/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4689 - val_loss: 0.5936
# Epoch 56/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4758 - val_loss: 0.4637
# Epoch 57/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4511 - val_loss: 0.5493
# Epoch 58/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4717 - val_loss: 0.4486
# Epoch 59/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4367 - val_loss: 0.4627
# Epoch 60/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4464 - val_loss: 0.4517
# Epoch 61/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4299 - val_loss: 0.4458
# Epoch 62/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4428 - val_loss: 0.4492
# Epoch 63/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4323 - val_loss: 0.4427
# Epoch 64/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4312 - val_loss: 0.4473
# Epoch 65/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4622 - val_loss: 0.6280
# Epoch 66/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4933 - val_loss: 0.4651
# Epoch 67/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4424 - val_loss: 0.4541
# Epoch 68/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4360 - val_loss: 0.4523
# Epoch 69/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4341 - val_loss: 0.4440
# Epoch 70/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4356 - val_loss: 0.4466
# Epoch 71/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4307 - val_loss: 0.4435
# Epoch 72/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4292 - val_loss: 0.4486
# Epoch 73/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4356 - val_loss: 0.4497
# seconds taken: 69.35
# start_time: 17:33:11 end_time: 17:34:21
# PICP: 0.9467108618052015
# MPIW: 3.471
# Data appended successfully to qd_LosAngeles.csv
# LosAngeles QD_LSTM 0.9467108618052015 3.471 69.35 10 24 0.05 160 128 2 0.007 [128] 0.1

# %%
QD.save('j_lstm_qd.keras')

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('QD LSTM prediction on Los Angeles Dataset')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %% [markdown]
# ###### QD GRU

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

for dropout in [0.1]:
    for layers in [[128]]:
        for alp in [0.05]:
            for sof in [160]:
                for l1 in [2]:
                    for l2 in [0.007]:
                        gru_model = create_gru((input_window_size, 1), layers, 2, dropout)
                        change_qd_var(alp, sof, 128, l1, l2)
                        gru_model.compile(loss=qd_objective, optimizer=Adam(learning_rate=0.001))
                        epc = 300
                        stop_patience = 10
                        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
                        start_time = datetime.datetime.now()
                        history = gru_model.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128, validation_data=(val_x, val_y), callbacks=[early_stopping])
                        end_time = datetime.datetime.now()
                        total_time = end_time - start_time
                        total_time = round(total_time.total_seconds(), 2)
                        print('seconds taken:', total_time, '\nstart_time:', start_time.strftime('%H:%M:%S'), 'end_time:', end_time.strftime('%H:%M:%S'))
                        y_pred = gru_model.predict(test_x, verbose=0)
                        y_pred = scaler_y.inverse_transform(y_pred)
                        test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
                        test_y_ = np.squeeze(test_y_[:,0])
                        y_u_pred = y_pred[:,0]
                        y_l_pred = y_pred[:,1]
                        K_u = y_u_pred > test_y_
                        K_l = y_l_pred < test_y_
                        PICP = np.mean(K_u * K_l)
                        MPIW = np.round(np.mean(y_u_pred - y_l_pred),3)
                        print('PICP:', PICP)
                        print('MPIW:', MPIW)
                        save_to_csv("qd_"+savefilename, dataset, "QD_GRU", PICP, MPIW, total_time, stop_patience, input_window_size, alpha_, soften_, n_, lambda1, lambda2, layers, dropout)
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - loss: 4.6154 - val_loss: 0.7443
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6424 - val_loss: 0.6420
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5970 - val_loss: 0.6652
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5824 - val_loss: 0.5563
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5332 - val_loss: 0.6318
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5440 - val_loss: 0.5275
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5458 - val_loss: 0.5826
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5649 - val_loss: 0.5171
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5529 - val_loss: 0.6037
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5710 - val_loss: 0.5816
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5249 - val_loss: 0.6076
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5614 - val_loss: 0.5140
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4960 - val_loss: 0.5380
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5139 - val_loss: 0.5063
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4953 - val_loss: 0.5487
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5281 - val_loss: 0.4989
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4840 - val_loss: 0.5144
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4848 - val_loss: 0.4972
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4855 - val_loss: 0.4911
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5093 - val_loss: 0.5239
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4939 - val_loss: 0.5299
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5043 - val_loss: 0.5291
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5010 - val_loss: 0.4941
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4714 - val_loss: 0.5207
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4903 - val_loss: 0.5260
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4862 - val_loss: 0.5201
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4870 - val_loss: 0.4921
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4749 - val_loss: 0.5320
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4968 - val_loss: 0.4918
# seconds taken: 33.3
# start_time: 17:34:23 end_time: 17:34:56
# PICP: 0.9528301886792453
# MPIW: 3.749
# Data appended successfully to qd_LosAngeles.csv

# %%
gru_model.save('j_gru_qd.keras')

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('QD GRU prediction on Los Angeles Dataset')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %% [markdown]
# ###### QD TCN

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

for dropout in [0.1]:
    for kernel in [3]:
        for layers in [[128]]:
            for alp in [0.05]:
                for sof in [160]:
                    for l1 in [5]:
                        for l2 in [0.05]:
                            change_qd_var(alp, sof, 128, l1, l2)
                            tcn_model = create_tcn((input_window_size,1), layers, kernel, dropout)
                            tcn_model.compile(loss=qd_objective, optimizer=Adam(learning_rate=0.001))
                            epc = 300
                            stop_patience = 10
                            early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
                            start_time = datetime.datetime.now()
                            history = tcn_model.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128, validation_data=(val_x, val_y), callbacks=[early_stopping])
                            end_time = datetime.datetime.now()
                            total_time = end_time - start_time
                            total_time = round(total_time.total_seconds(), 2)
                            print('seconds taken:', total_time, '\nstart_time:', start_time.strftime('%H:%M:%S'), 'end_time:', end_time.strftime('%H:%M:%S'))
                            y_pred = tcn_model.predict(test_x, verbose=0)
                            y_pred = scaler_y.inverse_transform(y_pred)
                            test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
                            test_y_ = np.squeeze(test_y_[:,0])
                            y_u_pred = y_pred[:,0]
                            y_l_pred = y_pred[:,1]
                            K_u = y_u_pred > test_y_
                            K_l = y_l_pred < test_y_
                            PICP = np.mean(K_u * K_l)
                            MPIW = np.round(np.mean(y_u_pred - y_l_pred), 3)
                            print('PICP:', PICP)
                            print('MPIW:', MPIW)
                            save_to_csv("qd_"+savefilename, dataset, "TCN", PICP, MPIW, total_time, stop_patience, input_window_size, alpha_, soften_, n_, lambda1, lambda2, layers, dropout, kernel, "improve")
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - loss: 121.3275 - val_loss: 121.1721
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 121.1570 - val_loss: 121.1626
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1507 - val_loss: 121.1499
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1440 - val_loss: 121.1736
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1565 - val_loss: 121.1896
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.2197 - val_loss: 121.1465
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1419 - val_loss: 121.1479
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1405 - val_loss: 121.1454
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1397 - val_loss: 121.1455
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 121.1393 - val_loss: 121.1426
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1386 - val_loss: 121.1460
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1387 - val_loss: 121.1440
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1391 - val_loss: 121.1480
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121.1387 - val_loss: 121.1486
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 117.5724 - val_loss: 9.5942
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.6973 - val_loss: 4.3050
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.3623 - val_loss: 1.5175
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5350 - val_loss: 1.6758
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5369 - val_loss: 1.3948
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3032 - val_loss: 1.7786
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3678 - val_loss: 1.3352
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2356 - val_loss: 1.4937
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3446 - val_loss: 1.3003
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3070 - val_loss: 1.3108
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2430 - val_loss: 1.4289
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2537 - val_loss: 1.3753
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2264 - val_loss: 1.7017
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3407 - val_loss: 1.2905
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2045 - val_loss: 1.2929
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1740 - val_loss: 1.6148
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3216 - val_loss: 1.2790
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1703 - val_loss: 1.2739
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1470 - val_loss: 1.3135
# Epoch 34/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1551 - val_loss: 1.2931
# Epoch 35/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1636 - val_loss: 1.3286
# Epoch 36/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1705 - val_loss: 1.2919
# Epoch 37/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1479 - val_loss: 1.5458
# Epoch 38/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2425 - val_loss: 1.2435
# Epoch 39/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1398 - val_loss: 1.2520
# Epoch 40/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1389 - val_loss: 1.4288
# Epoch 41/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1607 - val_loss: 1.2580
# Epoch 42/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1255 - val_loss: 1.5117
# Epoch 43/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2638 - val_loss: 1.3317
# Epoch 44/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1241 - val_loss: 1.2567
# Epoch 45/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1115 - val_loss: 1.2992
# Epoch 46/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1468 - val_loss: 1.2398
# Epoch 47/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1145 - val_loss: 1.3960
# Epoch 48/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1700 - val_loss: 1.2362
# Epoch 49/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1310 - val_loss: 1.3316
# Epoch 50/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1569 - val_loss: 1.2620
# Epoch 51/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1116 - val_loss: 1.2427
# Epoch 52/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1102 - val_loss: 1.2718
# Epoch 53/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1243 - val_loss: 1.3190
# Epoch 54/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1464 - val_loss: 1.2727
# Epoch 55/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1350 - val_loss: 1.2607
# Epoch 56/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1138 - val_loss: 1.2847
# Epoch 57/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1117 - val_loss: 1.3205
# Epoch 58/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1273 - val_loss: 1.2617
# seconds taken: 43.6
# start_time: 17:34:59 end_time: 17:35:42
# PICP: 0.950790413054564
# MPIW: 3.548
# Data appended successfully to qd_LosAngeles.csv

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('QD TCN prediction on Los Angeles Dataset')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %%
tcn_model.save('j_tcn_qd.keras')

# %% [markdown]
# ##### Confidence Loss

# %% [markdown]
# ###### Confidence LSTM

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

for layers in [[32,32]]:
    for ri in [0.5]:
        for qi in [0.95]:
            for deltai in [0.00017]:
                change_confidence_var(ri, qi, deltai)
                Confidence = create_lstm((input_window_size,1),layers,2)
                Confidence.compile(loss=confidence_loss,optimizer=Adam(learning_rate=0.005))
                epc = 300
                stop_patience = 10
                early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
                start_time = datetime.datetime.now()
                history = Confidence.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
                end_time = datetime.datetime.now()
                total_time = end_time - start_time
                total_time = round(total_time.total_seconds(),2)
                print('seconds taken:', total_time, '\nstart_time:', start_time.strftime('%H:%M:%S'), 'end_time:', end_time.strftime('%H:%M:%S'))
                y_pred = Confidence.predict(test_x, verbose=0)
                y_pred = scaler_y.inverse_transform(y_pred)
                test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
                test_y_ = np.squeeze(test_y_[:,0])
                y_u_pred = y_pred[:,0]
                y_l_pred = y_pred[:,1]
                K_u = y_u_pred > test_y_
                K_l = y_l_pred < test_y_
                PICP = np.mean(K_u * K_l)
                MPIW = np.round(np.mean(y_u_pred - y_l_pred),3)
                print('PICP:', PICP)
                print('MPIW:', MPIW)
                save_to_csv(savefilename, dataset, "Confidence_LSTM", PICP, MPIW, total_time, stop_patience, input_window_size, r, q, delta, layers)
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - loss: 0.0274 - val_loss: 0.0134
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0100 - val_loss: 0.0106
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0095 - val_loss: 0.0099
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0093 - val_loss: 0.0100
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0091 - val_loss: 0.0097
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0091 - val_loss: 0.0097
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0090 - val_loss: 0.0099
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0089 - val_loss: 0.0097
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0089 - val_loss: 0.0095
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0088 - val_loss: 0.0095
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0087 - val_loss: 0.0095
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0086 - val_loss: 0.0093
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0087
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0082
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0085
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0082
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 34/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0078 - val_loss: 0.0081
# Epoch 35/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 36/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0084
# Epoch 37/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 38/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 39/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 40/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0078 - val_loss: 0.0080
# Epoch 41/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 42/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 43/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 44/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 45/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0078 - val_loss: 0.0084
# seconds taken: 54.84
# start_time: 17:35:44 end_time: 17:36:39
# PICP: 0.9553799082100969
# MPIW: 3.589
# Data appended successfully to LosAngeles.csv

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('LSTM prediction on Los Angeles Dataset using Tube Loss')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %%
Confidence.save('j_LSTM_Confidence.keras')

# %% [markdown]
# ###### Confidence GRU

# %%
#q1 = 0.975
#deltai = 0.004
#learning_rate = 0.001

# %%
'''
qi = 0.95
deltai = 0.004
learning_rate = 0.001
'''
# Out:
# '\nqi = 0.95\ndeltai = 0.004\nlearning_rate = 0.001\n'

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

for dropout in [0.1]:
    for layers in [[16,16]]:
        for ri in [0.5]:
            for qi in [0.95]:
                for deltai in [0.005]:
                    change_confidence_var(ri, qi, deltai)
                    Confidence_GRU = create_gru((input_window_size,1),layers,2,dropout)
                    Confidence_GRU.compile(loss=confidence_loss,optimizer=Adam(learning_rate=0.0005))
                    epc = 300
                    stop_patience = 10
                    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
                    start_time = datetime.datetime.now()
                    history = Confidence_GRU.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
                    end_time = datetime.datetime.now()
                    total_time = end_time - start_time
                    total_time = round(total_time.total_seconds(),2)
                    print('seconds taken:', total_time, '\nstart_time:', start_time.strftime('%H:%M:%S'), 'end_time:', end_time.strftime('%H:%M:%S'))
                    y_pred = Confidence_GRU.predict(test_x, verbose=0)
                    y_pred = scaler_y.inverse_transform(y_pred)
                    test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
                    test_y_ = np.squeeze(test_y_[:,0])
                    y_u_pred = y_pred[:,0]
                    y_l_pred = y_pred[:,1]
                    K_u = y_u_pred > test_y_
                    K_l = y_l_pred < test_y_
                    PICP = np.mean(K_u * K_l)
                    MPIW = np.round(np.mean(y_u_pred - y_l_pred),3)
                    print('PICP:', PICP)
                    print('MPIW:', MPIW)
                    save_to_csv(savefilename, dataset, "Confidence_GRU", PICP, MPIW, total_time, stop_patience, input_window_size, r, q, delta,layers, dropout)
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 11s 42ms/step - loss: 0.0689 - val_loss: 0.0176
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0175 - val_loss: 0.0152
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0156 - val_loss: 0.0137
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0145 - val_loss: 0.0128
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0136 - val_loss: 0.0127
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0126 - val_loss: 0.0119
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0125 - val_loss: 0.0116
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0123 - val_loss: 0.0115
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0119 - val_loss: 0.0113
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0119 - val_loss: 0.0112
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0115 - val_loss: 0.0111
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0116 - val_loss: 0.0110
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0113 - val_loss: 0.0109
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0112 - val_loss: 0.0108
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0109 - val_loss: 0.0107
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0110 - val_loss: 0.0108
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0110 - val_loss: 0.0106
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0107 - val_loss: 0.0105
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0107 - val_loss: 0.0107
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0106 - val_loss: 0.0105
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0104 - val_loss: 0.0103
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0104 - val_loss: 0.0103
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 34/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 35/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 36/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 37/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 38/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 39/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 40/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 41/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0102 - val_loss: 0.0100
# Epoch 42/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 43/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 44/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 45/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 46/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 47/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 48/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0100 - val_loss: 0.0099
# Epoch 49/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 50/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 51/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 52/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 53/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0099 - val_loss: 0.0099
# Epoch 54/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0100 - val_loss: 0.0099
# Epoch 55/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0099
# Epoch 56/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 57/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 58/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0099
# Epoch 59/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0099
# Epoch 60/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 61/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 62/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 63/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 64/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 65/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0099
# Epoch 66/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 67/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 68/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 69/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 70/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0097
# Epoch 71/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 72/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 73/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 74/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 75/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 76/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 77/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 78/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 79/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 80/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 81/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 82/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 83/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 84/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 85/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 86/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 87/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0096
# Epoch 88/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 89/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 90/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0097 - val_loss: 0.0096
# Epoch 91/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0096
# Epoch 92/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 93/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0096
# Epoch 94/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0096 - val_loss: 0.0096
# Epoch 95/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 96/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 97/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 98/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 99/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0096 - val_loss: 0.0096
# Epoch 100/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0096
# seconds taken: 147.7
# start_time: 17:36:41 end_time: 17:39:09
# PICP: 0.958694543600204
# MPIW: 3.737
# Data appended successfully to LosAngeles.csv

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('GRU prediction on Los Angeles Dataset using Tube Loss')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %%
Confidence_GRU.save('j_GRU_Confidence.keras')

# %% [markdown]
# ###### Confidence TCN

# %%
#delta = 0.004, 0.0001
#learning_rate = 0.001, 0.0005

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

for dropout in [0.1]:
    for kernel in [3]:
        for layers in [[128]]:
            for ri in [0.5]:
                for qi in [0.95]:
                    for deltai in [0.0001]:
                        change_confidence_var(ri, qi, deltai)
                        tcn_Confidence = create_tcn(input_shape=(input_window_size,1),
                                               filters_list=layers,
                                               kernel_size=kernel,
                                               dropout_rate=dropout)
                        tcn_Confidence.compile(loss=confidence_loss, optimizer=Adam(learning_rate=0.0005))
                        epc = 300
                        stop_patience = 10
                        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
                        start_time = datetime.datetime.now()
                        history = tcn_Confidence.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128, validation_data=(val_x, val_y), callbacks=[early_stopping])
                        end_time = datetime.datetime.now()
                        total_time = end_time - start_time
                        total_time = round(total_time.total_seconds(),2)
                        print('seconds taken:', total_time, '\nstart_time:', start_time.strftime('%H:%M:%S'), 'end_time:', end_time.strftime('%H:%M:%S'))
                        y_pred = tcn_Confidence.predict(test_x, verbose=0)
                        y_pred = scaler_y.inverse_transform(y_pred)
                        test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
                        test_y_ = np.squeeze(test_y_[:,0])
                        y_u_pred = y_pred[:,0]
                        y_l_pred = y_pred[:,1]
                        K_u = y_u_pred > test_y_
                        K_l = y_l_pred < test_y_
                        PICP = np.mean(K_u * K_l)
                        MPIW = np.round(np.mean(y_u_pred - y_l_pred),3)
                        print('PICP:', PICP)
                        print('MPIW:', MPIW)
                        save_to_csv(savefilename, dataset, "Confidence_TCN", PICP, MPIW, total_time, stop_patience, input_window_size, r, q, delta, layers, dropout, kernel)
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - loss: 0.0286 - val_loss: 0.0108
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0101 - val_loss: 0.0096
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - val_loss: 0.0092
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0089
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0084
# seconds taken: 15.13
# start_time: 17:39:11 end_time: 17:39:27
# PICP: 0.9502804691483937
# MPIW: 3.555
# Data appended successfully to LosAngeles.csv

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('TCN prediction on Los Angeles Dataset using Tube Loss')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %%
tcn_Confidence.save('j_TCN_Confidence.keras')

# %% [markdown]
# ##### Quantile Loss

# %% [markdown]
# ###### Quantile LSTM

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

# %%
layers = [128]
dropout = 0
quantile1 = create_lstm((input_window_size,1),layers,1,dropout)
quantile2 = create_lstm((input_window_size,1),layers,1,dropout)

# %%
q1=0.03
q2=0.98
quantile1.compile(loss=quantile_loss(q1),optimizer=Adam(learning_rate=0.001))
quantile2.compile(loss=quantile_loss(q2),optimizer=Adam(learning_rate=0.001))

# %%
epc = 300
stop_patience = 10
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
start_time = datetime.datetime.now()
history = quantile1.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
end_time = datetime.datetime.now()
total_time = end_time - start_time
total_time1 = round(total_time.total_seconds(),2)
print('seconds taken:', total_time1,
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 34/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 35/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 36/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 37/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 38/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 39/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 40/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 41/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 42/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 43/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 44/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 45/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 46/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 47/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 48/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 49/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 50/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 51/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 52/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 53/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 54/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# seconds taken: 42.76
# start_time: 17:39:28 end_time: 17:40:11

# %%
epc = 300
stop_patience = 10
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
start_time = datetime.datetime.now()
history = quantile2.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
end_time = datetime.datetime.now()
total_time = end_time - start_time
total_time2 = round(total_time.total_seconds(),2)
print('seconds taken:', total_time2,
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0243 - val_loss: 0.0057
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 34/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 35/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 36/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 37/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 38/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 39/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 40/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 41/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 42/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 43/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 44/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 45/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# seconds taken: 36.42
# start_time: 17:40:11 end_time: 17:40:47

# %%
y_l_pred = quantile1.predict(test_x, verbose=0)
y_u_pred = quantile2.predict(test_x, verbose=0)
test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
# test_y_ = np.squeeze(test_y_[:,0])
y_l_pred = scaler_y.inverse_transform(y_l_pred)
y_u_pred = scaler_y.inverse_transform(y_u_pred)
K_u = y_u_pred > test_y_
K_l = y_l_pred < test_y_
PICP = np.mean(K_u * K_l)
MPIW = np.round(np.mean(y_u_pred - y_l_pred),3)
print('PICP:', PICP)
print('MPIW:', MPIW)
# Out:
# PICP: 0.9574196838347782
# MPIW: 4.001

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('LSTM prediction on Los Angeles Dataset using Quantile Loss')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %%
save_to_csv("quantile_"+savefilename, dataset, "Quantile_LSTM", PICP, MPIW, total_time1 + total_time2, stop_patience, input_window_size, q1, q2, layers, dropout)
# Out:
# Data appended successfully to quantile_LosAngeles.csv

# %%
quantile1.save('j_lstm_q1.keras')
quantile2.save('j_lstm_q2.keras')

# %% [markdown]
# ###### Quantile GRU

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

# %%
layers = [128]
dropout = 0
quantile1 = create_gru((input_window_size,1),layers,1,dropout)
quantile2 = create_gru((input_window_size,1),layers,1,dropout)

# %%
q1=0.025
q2=0.975
quantile1.compile(loss=quantile_loss(q1),optimizer=Adam(learning_rate=0.001))
quantile2.compile(loss=quantile_loss(q2),optimizer=Adam(learning_rate=0.001))

# %%
epc = 300
stop_patience = 10
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
start_time = datetime.datetime.now()
history = quantile1.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
end_time = datetime.datetime.now()
total_time = end_time - start_time
total_time1 = round(total_time.total_seconds(),2)
print('seconds taken:', total_time1,
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 34/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 35/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 36/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0027 - val_loss: 0.0031
# seconds taken: 31.1
# start_time: 17:40:50 end_time: 17:41:21

# %%
epc = 300
stop_patience = 10
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
start_time = datetime.datetime.now()
history = quantile2.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
end_time = datetime.datetime.now()
total_time = end_time - start_time
total_time2 = round(total_time.total_seconds(),2)
print('seconds taken:', total_time2,
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0227 - val_loss: 0.0055
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 34/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 35/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 36/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 37/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 38/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 39/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 40/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 41/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 42/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 43/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 44/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 45/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 46/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 47/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 48/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 49/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 50/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 51/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 52/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 53/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 54/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 55/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 56/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 57/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 58/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 59/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 60/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 61/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 62/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 63/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 64/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 65/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 66/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 67/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 68/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 69/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 70/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 71/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 72/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 73/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 74/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 75/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 76/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 77/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 78/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 79/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 80/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036 - val_loss: 0.0039
# seconds taken: 62.68
# start_time: 17:41:21 end_time: 17:42:24

# %%
y_l_pred = quantile1.predict(test_x, verbose=0)
y_u_pred = quantile2.predict(test_x, verbose=0)
test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
# test_y_ = np.squeeze(test_y_[:,0])
y_l_pred = scaler_y.inverse_transform(y_l_pred)
y_u_pred = scaler_y.inverse_transform(y_u_pred)
K_u = y_u_pred > test_y_
K_l = y_l_pred < test_y_
PICP = np.mean(K_u * K_l)
MPIW = np.round(np.mean(y_u_pred - y_l_pred),3)
print('PICP:', PICP)
print('MPIW:', MPIW)
# Out:
# PICP: 0.9510453850076491
# MPIW: 3.618

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('GRU prediction on Los Angeles Dataset using Quantile Loss')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %%
save_to_csv("quantile_"+savefilename, dataset, "Quantile_GRU", PICP, MPIW, total_time1 + total_time2, stop_patience, input_window_size, q1, q2, layers, dropout)
# Out:
# Data appended successfully to quantile_LosAngeles.csv

# %%
quantile1.save('j_gru_q1.keras')
quantile2.save('j_gru_q2.keras')

# %% [markdown]
# ###### Quantile TCN

# %%
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

# %%
layers = [128]
dropout = 0.1
kernel = 5
quantile1 = create_tcn((input_window_size,1), layers, kernel, dropout)
quantile2 = create_tcn((input_window_size,1), layers, kernel, dropout)

# %%
q1=0.025
q2=0.975
quantile1.compile(loss=quantile_loss(q1),optimizer=Adam(learning_rate=0.001))
quantile2.compile(loss=quantile_loss(q2),optimizer=Adam(learning_rate=0.001))

# %%
epc = 300
stop_patience = 10
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
start_time = datetime.datetime.now()
history = quantile1.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
end_time = datetime.datetime.now()
total_time = end_time - start_time
total_time1 = round(total_time.total_seconds(),2)
print('seconds taken:', total_time1,
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - val_loss: 0.0031
# seconds taken: 13.71
# start_time: 17:42:26 end_time: 17:42:40

# %%
epc = 300
stop_patience = 10
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
start_time = datetime.datetime.now()
history = quantile2.fit(train_x, train_y, epochs=epc, verbose=1, batch_size=128,  validation_data=(val_x, val_y), callbacks=[early_stopping])
end_time = datetime.datetime.now()
total_time = end_time - start_time
total_time2 = round(total_time.total_seconds(),2)
print('seconds taken:', total_time2,
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0138 - val_loss: 0.0055
# Epoch 2/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 3/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 4/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 5/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 6/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 7/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 8/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 9/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 10/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 11/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 12/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 13/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 14/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 15/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - val_loss: 0.0043
# Epoch 16/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - val_loss: 0.0043
# Epoch 17/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 18/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 19/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 20/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 21/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 22/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - val_loss: 0.0043
# Epoch 23/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 24/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 25/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 26/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 27/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 28/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 29/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 30/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 31/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 32/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 33/300
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - val_loss: 0.0042
# seconds taken: 19.82
# start_time: 17:42:40 end_time: 17:43:00

# %%
y_l_pred = quantile1.predict(test_x, verbose=0)
y_u_pred = quantile2.predict(test_x, verbose=0)
test_y_ = scaler_y.inverse_transform(test_y.reshape(-1,1))
# test_y_ = np.squeeze(test_y_[:,0])
y_l_pred = scaler_y.inverse_transform(y_l_pred)
y_u_pred = scaler_y.inverse_transform(y_u_pred)
K_u = y_u_pred > test_y_
K_l = y_l_pred < test_y_
PICP = np.mean(K_u * K_l)
MPIW = np.round(np.mean(y_u_pred - y_l_pred),3)
print('PICP:', PICP)
print('MPIW:', MPIW)
# Out:
# PICP: 0.9416114227434982
# MPIW: 3.779

# %%
actual=test_y_
# actual = np.squeeze(actual)
pred1=y_u_pred[:,:1]
pred2=y_l_pred[:,:1]
numEx = test_data.index
numEx = numEx[24:]
plt.figure(figsize=(15, 9))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='upper quantile')
plt.plot(numEx,pred2,label='lower quantile')
plt.legend(loc='upper right')
plt.title('TCN prediction on Los Angeles Dataset using Quantile Loss')
plt.xlabel('Timestamp')
plt.ylabel('Wind speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('k_lstm_tube')
plt.show()

# %%
save_to_csv("quantile_"+savefilename, dataset, "Quantile_TCN", PICP, MPIW, total_time1 + total_time2, stop_patience, input_window_size, q1, q2, layers, dropout, kernel)
# Out:
# Data appended successfully to quantile_LosAngeles.csv

# %%
quantile1.save('j_tcn_q1.keras')
quantile2.save('j_tcn_q2.keras')
