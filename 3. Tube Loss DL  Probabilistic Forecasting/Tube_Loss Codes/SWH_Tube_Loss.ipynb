# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, LSTM, Dropout
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import RepeatVector, TimeDistributed, Input, BatchNormalization, multiply, concatenate, Activation, dot
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop,Adam,SGD,Adagrad, Nadam, Ftrl
from keras.utils import plot_model, model_to_dot
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import keras.backend as K
import datetime
from tensorflow.keras import regularizers
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

# %%
def truncate(x, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=100, test_len=20):
    in_, out_= [], []
    for i in range(len(x)-train_len-test_len+1):
        in_.append(x[i:(i+train_len), feature_cols].tolist())
        out_.append(x[(i+train_len):(i+train_len+test_len), target_cols].tolist())
    return np.array(in_), np.array(out_)

# %%
#Preparing Dataset.
fileName = '42001h2021'
dataset = pd.read_csv("42001h2021.txt", sep='\t', lineterminator='\r')
dataset = dataset.replace('\n','', regex=True)
dataset=dataset[1:-1]
dataset["Date"] = pd.to_datetime(dataset["Date"])
dataset["WVHT"]=dataset["WVHT"].astype(float)
dataset = dataset[dataset['WVHT'] != 99]
data = dataset["WVHT"].to_numpy().reshape((len(dataset["WVHT"]),1))
X_in, X_out = truncate(data, feature_cols=range(1), target_cols=range(1),label_col=1, train_len=16, test_len=1)

# %%
train_x = X_in[:math.floor(X_in.shape[0]*0.70)]
train_y = X_out[:math.floor(X_out.shape[0]*0.70)]
test_x = X_in[math.floor(X_in.shape[0]*0.70):]
test_y = X_out[math.floor(X_out.shape[0]*0.70):]
print(train_x.shape, test_x.shape,train_y.shape, test_y.shape)
# Out:
# (1577, 16, 1) (677, 16, 1) (1577, 1, 1) (677, 1, 1)

# %%
# hyperparameters
r = 0.5
q = 0.95 #Prediction Interval.
delta = 0.001

def confidance_loss(y_true,y_pred):
  y_true = y_true[:,0]
  f1 = y_pred[:,0]
  f2 = y_pred[:,1]

  c1 = (1-q)*(y_true-f2)
  c2 = (1-q)*(f1-y_true)
  c3 = q*(f2-y_true)
  c4 = q*(y_true-f1)

  loss = K.switch(tf.math.logical_and((y_true <= f1),(y_true>=f2)),K.switch((y_true>(r*f1+(1-r)*f2)),c1,c2),K.switch((f2>y_true),c3,c4)) + (delta * tf.math.abs(f1-f2))
  return loss

# %%
input_train = Input(shape=(16, 1))
initializer = tf.keras.initializers.GlorotNormal(seed=None)
lstm_l1 = LSTM(128, activation='relu',kernel_initializer=initializer,return_sequences=True)(input_train)
dp_l1 = Dropout(0.4)(lstm_l1)
lstm_l2 = LSTM(64, activation='relu',kernel_initializer=initializer,return_sequences=True)(dp_l1)
dp_l2 = Dropout(0.3)(lstm_l2)
lstm_l3 = LSTM(32, activation='relu',kernel_initializer=initializer,return_sequences=False)(dp_l2)
dp_l3 = Dropout(0.2)(lstm_l3)
out = Dense(2)(dp_l3)
model = Model(inputs=input_train, outputs=out)
# Out:
# c:\Users\aades\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
opt = Adam(learning_rate=0.001)
model.compile(loss=confidance_loss,optimizer=opt)
model.summary()
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 16, 1)]           0
#
#  lstm_27 (LSTM)              (None, 16, 128)           66560
#
#  dropout_27 (Dropout)        (None, 16, 128)           0
#
#  lstm_28 (LSTM)              (None, 16, 64)            49408
#
#  dropout_28 (Dropout)        (None, 16, 64)            0
#
#  lstm_29 (LSTM)              (None, 32)                12416
#
#  dropout_29 (Dropout)        (None, 32)                0
#
#  dense_9 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 128450 (501.76 KB)
# Trainable params: 128450 (501.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
epc = 300
start_time = datetime.datetime.now()
stop_patience = 5
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
history = model.fit(train_x, train_y, validation_split=0.1, epochs=epc, verbose=1, batch_size=128)
end_time = datetime.datetime.now()
total_time = end_time - start_time
print('seconds taken:', round(total_time.total_seconds(),1),
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 12/12 [==============================] - 13s 200ms/step - loss: 0.9367 - val_loss: 0.2709
# Epoch 2/300
# 12/12 [==============================] - 1s 86ms/step - loss: 0.1740 - val_loss: 0.0757
# Epoch 3/300
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0980 - val_loss: 0.0641
# Epoch 4/300
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0787 - val_loss: 0.0532
# Epoch 5/300
# 12/12 [==============================] - 1s 92ms/step - loss: 0.0639 - val_loss: 0.0451
# Epoch 6/300
# 12/12 [==============================] - 1s 93ms/step - loss: 0.0638 - val_loss: 0.0440
# Epoch 7/300
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0637 - val_loss: 0.0444
# Epoch 8/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0574 - val_loss: 0.0418
# Epoch 9/300
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0572 - val_loss: 0.0403
# Epoch 10/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0558 - val_loss: 0.0416
# Epoch 11/300
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0581 - val_loss: 0.0418
# Epoch 12/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0590 - val_loss: 0.0524
# Epoch 13/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0595 - val_loss: 0.0412
# Epoch 14/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0582 - val_loss: 0.0402
# Epoch 15/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0548 - val_loss: 0.0410
# Epoch 16/300
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0522 - val_loss: 0.0384
# Epoch 17/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0535 - val_loss: 0.0381
# Epoch 18/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0531 - val_loss: 0.0393
# Epoch 19/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0534 - val_loss: 0.0374
# Epoch 20/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0508 - val_loss: 0.0375
# Epoch 21/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0499 - val_loss: 0.0361
# Epoch 22/300
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0520 - val_loss: 0.0364
# Epoch 23/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0504 - val_loss: 0.0359
# Epoch 24/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0512 - val_loss: 0.0383
# Epoch 25/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0497 - val_loss: 0.0353
# Epoch 26/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0484 - val_loss: 0.0349
# Epoch 27/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0476 - val_loss: 0.0340
# Epoch 28/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0476 - val_loss: 0.0361
# Epoch 29/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0483 - val_loss: 0.0404
# Epoch 30/300
# 12/12 [==============================] - 1s 80ms/step - loss: 0.0489 - val_loss: 0.0420
# Epoch 31/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0546 - val_loss: 0.0361
# Epoch 32/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0505 - val_loss: 0.0360
# Epoch 33/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0509 - val_loss: 0.0365
# Epoch 34/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0458 - val_loss: 0.0359
# Epoch 35/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0465 - val_loss: 0.0339
# Epoch 36/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0469 - val_loss: 0.0321
# Epoch 37/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0444 - val_loss: 0.0324
# Epoch 38/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0465 - val_loss: 0.0320
# Epoch 39/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0452 - val_loss: 0.0315
# Epoch 40/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0479 - val_loss: 0.0328
# Epoch 41/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0481 - val_loss: 0.0336
# Epoch 42/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0472 - val_loss: 0.0331
# Epoch 43/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0429 - val_loss: 0.0308
# Epoch 44/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0434 - val_loss: 0.0305
# Epoch 45/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0418 - val_loss: 0.0314
# Epoch 46/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0436 - val_loss: 0.0312
# Epoch 47/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0425 - val_loss: 0.0299
# Epoch 48/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0454 - val_loss: 0.0367
# Epoch 49/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0508 - val_loss: 0.0336
# Epoch 50/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0485 - val_loss: 0.0337
# Epoch 51/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0467 - val_loss: 0.0330
# Epoch 52/300
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0463 - val_loss: 0.0300
# Epoch 53/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0410 - val_loss: 0.0296
# Epoch 54/300
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0416 - val_loss: 0.0301
# Epoch 55/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0415 - val_loss: 0.0296
# Epoch 56/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0400 - val_loss: 0.0308
# Epoch 57/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0417 - val_loss: 0.0290
# Epoch 58/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0424 - val_loss: 0.0283
# Epoch 59/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0405 - val_loss: 0.0293
# Epoch 60/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0415 - val_loss: 0.0315
# Epoch 61/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0410 - val_loss: 0.0307
# Epoch 62/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0416 - val_loss: 0.0287
# Epoch 63/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0397 - val_loss: 0.0287
# Epoch 64/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0382 - val_loss: 0.0317
# Epoch 65/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0409 - val_loss: 0.0285
# Epoch 66/300
# 12/12 [==============================] - 1s 80ms/step - loss: 0.0390 - val_loss: 0.0283
# Epoch 67/300
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0395 - val_loss: 0.0274
# Epoch 68/300
# 12/12 [==============================] - 1s 80ms/step - loss: 0.0381 - val_loss: 0.0263
# Epoch 69/300
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0384 - val_loss: 0.0267
# Epoch 70/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0389 - val_loss: 0.0266
# Epoch 71/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0413 - val_loss: 0.0269
# Epoch 72/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0396 - val_loss: 0.0291
# Epoch 73/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0386 - val_loss: 0.0293
# Epoch 74/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0381 - val_loss: 0.0300
# Epoch 75/300
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0377 - val_loss: 0.0293
# Epoch 76/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0401 - val_loss: 0.0277
# Epoch 77/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0379 - val_loss: 0.0254
# Epoch 78/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0372 - val_loss: 0.0236
# Epoch 79/300
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0367 - val_loss: 0.0243
# Epoch 80/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0387 - val_loss: 0.0256
# Epoch 81/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0399 - val_loss: 0.0303
# Epoch 82/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0380 - val_loss: 0.0265
# Epoch 83/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0364 - val_loss: 0.0255
# Epoch 84/300
# 12/12 [==============================] - 1s 80ms/step - loss: 0.0365 - val_loss: 0.0254
# Epoch 85/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0364 - val_loss: 0.0245
# Epoch 86/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0355 - val_loss: 0.0226
# Epoch 87/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0357 - val_loss: 0.0228
# Epoch 88/300
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0345 - val_loss: 0.0240
# Epoch 89/300
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0380 - val_loss: 0.0273
# Epoch 90/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0380 - val_loss: 0.0240
# Epoch 91/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0358 - val_loss: 0.0225
# Epoch 92/300
# 12/12 [==============================] - 1s 82ms/step - loss: 0.0349 - val_loss: 0.0214
# Epoch 93/300
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0353 - val_loss: 0.0233
# Epoch 94/300
# 12/12 [==============================] - 1s 80ms/step - loss: 0.0364 - val_loss: 0.0276
# Epoch 95/300
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0362 - val_loss: 0.0241
# Epoch 96/300
# 12/12 [==============================] - 1s 79ms/step - loss: 0.0347 - val_loss: 0.0236
# Epoch 97/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0341 - val_loss: 0.0245
# Epoch 98/300
# 12/12 [==============================] - 1s 71ms/step - loss: 0.0356 - val_loss: 0.0238
# Epoch 99/300
# 12/12 [==============================] - 1s 63ms/step - loss: 0.0331 - val_loss: 0.0263
# Epoch 100/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0351 - val_loss: 0.0236
# Epoch 101/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0351 - val_loss: 0.0229
# Epoch 102/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0343 - val_loss: 0.0239
# Epoch 103/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0334 - val_loss: 0.0218
# Epoch 104/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0326 - val_loss: 0.0212
# Epoch 105/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0332 - val_loss: 0.0216
# Epoch 106/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0332 - val_loss: 0.0230
# Epoch 107/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0341 - val_loss: 0.0217
# Epoch 108/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0323 - val_loss: 0.0229
# Epoch 109/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0333 - val_loss: 0.0226
# Epoch 110/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0352 - val_loss: 0.0218
# Epoch 111/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0345 - val_loss: 0.0216
# Epoch 112/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0334 - val_loss: 0.0209
# Epoch 113/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0314 - val_loss: 0.0215
# Epoch 114/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0315 - val_loss: 0.0220
# Epoch 115/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0318 - val_loss: 0.0208
# Epoch 116/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0332 - val_loss: 0.0217
# Epoch 117/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0321 - val_loss: 0.0218
# Epoch 118/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0327 - val_loss: 0.0245
# Epoch 119/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0339 - val_loss: 0.0252
# Epoch 120/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0357 - val_loss: 0.0252
# Epoch 121/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0330 - val_loss: 0.0217
# Epoch 122/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0343 - val_loss: 0.0215
# Epoch 123/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0352 - val_loss: 0.0226
# Epoch 124/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0345 - val_loss: 0.0219
# Epoch 125/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0331 - val_loss: 0.0233
# Epoch 126/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0323 - val_loss: 0.0209
# Epoch 127/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0332 - val_loss: 0.0221
# Epoch 128/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0297 - val_loss: 0.0208
# Epoch 129/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0315 - val_loss: 0.0208
# Epoch 130/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0322 - val_loss: 0.0211
# Epoch 131/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0311 - val_loss: 0.0204
# Epoch 132/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0311 - val_loss: 0.0197
# Epoch 133/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0305 - val_loss: 0.0196
# Epoch 134/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0314 - val_loss: 0.0204
# Epoch 135/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0298 - val_loss: 0.0209
# Epoch 136/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0296 - val_loss: 0.0211
# Epoch 137/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0322 - val_loss: 0.0216
# Epoch 138/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0304 - val_loss: 0.0208
# Epoch 139/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0306 - val_loss: 0.0203
# Epoch 140/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0336 - val_loss: 0.0255
# Epoch 141/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0320 - val_loss: 0.0212
# Epoch 142/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0299 - val_loss: 0.0195
# Epoch 143/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0312 - val_loss: 0.0189
# Epoch 144/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0303 - val_loss: 0.0205
# Epoch 145/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0307 - val_loss: 0.0200
# Epoch 146/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0279 - val_loss: 0.0189
# Epoch 147/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0296 - val_loss: 0.0190
# Epoch 148/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0293 - val_loss: 0.0197
# Epoch 149/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0305 - val_loss: 0.0192
# Epoch 150/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0300 - val_loss: 0.0194
# Epoch 151/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0318 - val_loss: 0.0196
# Epoch 152/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0285 - val_loss: 0.0190
# Epoch 153/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0309 - val_loss: 0.0186
# Epoch 154/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0306 - val_loss: 0.0232
# Epoch 155/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0301 - val_loss: 0.0205
# Epoch 156/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0303 - val_loss: 0.0214
# Epoch 157/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0306 - val_loss: 0.0198
# Epoch 158/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0295 - val_loss: 0.0203
# Epoch 159/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0299 - val_loss: 0.0198
# Epoch 160/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0293 - val_loss: 0.0192
# Epoch 161/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0287 - val_loss: 0.0195
# Epoch 162/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0291 - val_loss: 0.0188
# Epoch 163/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0289 - val_loss: 0.0187
# Epoch 164/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0290 - val_loss: 0.0189
# Epoch 165/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0304 - val_loss: 0.0187
# Epoch 166/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0279 - val_loss: 0.0191
# Epoch 167/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0294 - val_loss: 0.0196
# Epoch 168/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0283 - val_loss: 0.0196
# Epoch 169/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0300 - val_loss: 0.0190
# Epoch 170/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0280 - val_loss: 0.0197
# Epoch 171/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0287 - val_loss: 0.0191
# Epoch 172/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0280 - val_loss: 0.0189
# Epoch 173/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0296 - val_loss: 0.0187
# Epoch 174/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0302 - val_loss: 0.0191
# Epoch 175/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0289 - val_loss: 0.0194
# Epoch 176/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0287 - val_loss: 0.0193
# Epoch 177/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0295 - val_loss: 0.0177
# Epoch 178/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0289 - val_loss: 0.0177
# Epoch 179/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0283 - val_loss: 0.0181
# Epoch 180/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0283 - val_loss: 0.0192
# Epoch 181/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0322 - val_loss: 0.0212
# Epoch 182/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0306 - val_loss: 0.0203
# Epoch 183/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0296 - val_loss: 0.0204
# Epoch 184/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0288 - val_loss: 0.0183
# Epoch 185/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0277 - val_loss: 0.0176
# Epoch 186/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0268 - val_loss: 0.0172
# Epoch 187/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0274 - val_loss: 0.0173
# Epoch 188/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0276 - val_loss: 0.0182
# Epoch 189/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0285 - val_loss: 0.0181
# Epoch 190/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0276 - val_loss: 0.0184
# Epoch 191/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0273 - val_loss: 0.0178
# Epoch 192/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0281 - val_loss: 0.0199
# Epoch 193/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0285 - val_loss: 0.0196
# Epoch 194/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0294 - val_loss: 0.0196
# Epoch 195/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0289 - val_loss: 0.0190
# Epoch 196/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0281 - val_loss: 0.0183
# Epoch 197/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0263 - val_loss: 0.0174
# Epoch 198/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0288 - val_loss: 0.0185
# Epoch 199/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0271 - val_loss: 0.0180
# Epoch 200/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0266 - val_loss: 0.0172
# Epoch 201/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0258 - val_loss: 0.0174
# Epoch 202/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0272 - val_loss: 0.0175
# Epoch 203/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0274 - val_loss: 0.0177
# Epoch 204/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0270 - val_loss: 0.0185
# Epoch 205/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0266 - val_loss: 0.0172
# Epoch 206/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0267 - val_loss: 0.0177
# Epoch 207/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0288 - val_loss: 0.0190
# Epoch 208/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0283 - val_loss: 0.0188
# Epoch 209/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0277 - val_loss: 0.0179
# Epoch 210/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0276 - val_loss: 0.0170
# Epoch 211/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0283 - val_loss: 0.0175
# Epoch 212/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0280 - val_loss: 0.0188
# Epoch 213/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0273 - val_loss: 0.0183
# Epoch 214/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0291 - val_loss: 0.0188
# Epoch 215/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0277 - val_loss: 0.0179
# Epoch 216/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0256 - val_loss: 0.0188
# Epoch 217/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0269 - val_loss: 0.0177
# Epoch 218/300
# 12/12 [==============================] - 1s 55ms/step - loss: 0.0280 - val_loss: 0.0173
# Epoch 219/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0262 - val_loss: 0.0173
# Epoch 220/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0267 - val_loss: 0.0177
# Epoch 221/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0268 - val_loss: 0.0175
# Epoch 222/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0258 - val_loss: 0.0173
# Epoch 223/300
# 12/12 [==============================] - 1s 63ms/step - loss: 0.0257 - val_loss: 0.0174
# Epoch 224/300
# 12/12 [==============================] - 1s 66ms/step - loss: 0.0258 - val_loss: 0.0172
# Epoch 225/300
# 12/12 [==============================] - 1s 63ms/step - loss: 0.0272 - val_loss: 0.0174
# Epoch 226/300
# 12/12 [==============================] - 1s 66ms/step - loss: 0.0261 - val_loss: 0.0168
# Epoch 227/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0260 - val_loss: 0.0173
# Epoch 228/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0269 - val_loss: 0.0178
# Epoch 229/300
# 12/12 [==============================] - 1s 63ms/step - loss: 0.0258 - val_loss: 0.0189
# Epoch 230/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0279 - val_loss: 0.0183
# Epoch 231/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0270 - val_loss: 0.0181
# Epoch 232/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0257 - val_loss: 0.0185
# Epoch 233/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0289 - val_loss: 0.0180
# Epoch 234/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0277 - val_loss: 0.0204
# Epoch 235/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0274 - val_loss: 0.0197
# Epoch 236/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0274 - val_loss: 0.0190
# Epoch 237/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0286 - val_loss: 0.0188
# Epoch 238/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0275 - val_loss: 0.0177
# Epoch 239/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0257 - val_loss: 0.0180
# Epoch 240/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0263 - val_loss: 0.0172
# Epoch 241/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0273 - val_loss: 0.0177
# Epoch 242/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0259 - val_loss: 0.0178
# Epoch 243/300
# 12/12 [==============================] - 1s 64ms/step - loss: 0.0261 - val_loss: 0.0174
# Epoch 244/300
# 12/12 [==============================] - 1s 65ms/step - loss: 0.0254 - val_loss: 0.0171
# Epoch 245/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0250 - val_loss: 0.0165
# Epoch 246/300
# 12/12 [==============================] - 1s 66ms/step - loss: 0.0255 - val_loss: 0.0166
# Epoch 247/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0246 - val_loss: 0.0167
# Epoch 248/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0267 - val_loss: 0.0183
# Epoch 249/300
# 12/12 [==============================] - 1s 63ms/step - loss: 0.0265 - val_loss: 0.0172
# Epoch 250/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0259 - val_loss: 0.0171
# Epoch 251/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0261 - val_loss: 0.0173
# Epoch 252/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0261 - val_loss: 0.0170
# Epoch 253/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0250 - val_loss: 0.0165
# Epoch 254/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0245 - val_loss: 0.0165
# Epoch 255/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0262 - val_loss: 0.0168
# Epoch 256/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0252 - val_loss: 0.0174
# Epoch 257/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0239 - val_loss: 0.0164
# Epoch 258/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0242 - val_loss: 0.0156
# Epoch 259/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0246 - val_loss: 0.0167
# Epoch 260/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0237 - val_loss: 0.0161
# Epoch 261/300
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0253 - val_loss: 0.0164
# Epoch 262/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0259 - val_loss: 0.0176
# Epoch 263/300
# 12/12 [==============================] - 1s 64ms/step - loss: 0.0274 - val_loss: 0.0199
# Epoch 264/300
# 12/12 [==============================] - 1s 68ms/step - loss: 0.0266 - val_loss: 0.0184
# Epoch 265/300
# 12/12 [==============================] - 1s 63ms/step - loss: 0.0284 - val_loss: 0.0180
# Epoch 266/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0255 - val_loss: 0.0188
# Epoch 267/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0276 - val_loss: 0.0181
# Epoch 268/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0268 - val_loss: 0.0178
# Epoch 269/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0272 - val_loss: 0.0186
# Epoch 270/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0267 - val_loss: 0.0192
# Epoch 271/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0273 - val_loss: 0.0201
# Epoch 272/300
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0286 - val_loss: 0.0175
# Epoch 273/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0261 - val_loss: 0.0170
# Epoch 274/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0271 - val_loss: 0.0198
# Epoch 275/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0257 - val_loss: 0.0168
# Epoch 276/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0243 - val_loss: 0.0165
# Epoch 277/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0254 - val_loss: 0.0163
# Epoch 278/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0244 - val_loss: 0.0165
# Epoch 279/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0251 - val_loss: 0.0162
# Epoch 280/300
# 12/12 [==============================] - 1s 64ms/step - loss: 0.0238 - val_loss: 0.0162
# Epoch 281/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0248 - val_loss: 0.0165
# Epoch 282/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0269 - val_loss: 0.0174
# Epoch 283/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0246 - val_loss: 0.0166
# Epoch 284/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0247 - val_loss: 0.0181
# Epoch 285/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0259 - val_loss: 0.0171
# Epoch 286/300
# 12/12 [==============================] - 1s 64ms/step - loss: 0.0237 - val_loss: 0.0164
# Epoch 287/300
# 12/12 [==============================] - 1s 63ms/step - loss: 0.0248 - val_loss: 0.0160
# Epoch 288/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0246 - val_loss: 0.0158
# Epoch 289/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0235 - val_loss: 0.0155
# Epoch 290/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0242 - val_loss: 0.0160
# Epoch 291/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0251 - val_loss: 0.0165
# Epoch 292/300
# 12/12 [==============================] - 1s 64ms/step - loss: 0.0250 - val_loss: 0.0173
# Epoch 293/300
# 12/12 [==============================] - 1s 60ms/step - loss: 0.0249 - val_loss: 0.0165
# Epoch 294/300
# 12/12 [==============================] - 1s 64ms/step - loss: 0.0251 - val_loss: 0.0160
# Epoch 295/300
# 12/12 [==============================] - 1s 61ms/step - loss: 0.0239 - val_loss: 0.0158
# Epoch 296/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0240 - val_loss: 0.0157
# Epoch 297/300
# 12/12 [==============================] - 1s 62ms/step - loss: 0.0236 - val_loss: 0.0153
# Epoch 298/300
# 12/12 [==============================] - 1s 59ms/step - loss: 0.0253 - val_loss: 0.0154
# Epoch 299/300
# 12/12 [==============================] - 1s 57ms/step - loss: 0.0242 - val_loss: 0.0167
# Epoch 300/300
# 12/12 [==============================] - 1s 64ms/step - loss: 0.0244 - val_loss: 0.0166
# seconds taken: 250.5
# start_time: 01:15:31 end_time: 01:19:42

# %%
fig,ax = plt.subplots()
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='test loss')
ax.set_xlabel('EPOCHS')
ax.set_ylabel('Loss value')
plt.legend()

# %%
y_pred = model.predict(test_x, verbose=0)
test_y_ = np.squeeze(test_y[:,0])
y_u_pred = y_pred[:,0]
y_l_pred = y_pred[:,1]
K_u = y_u_pred > test_y_
K_l = y_l_pred < test_y_
print('PICP:', np.mean(K_u * K_l))
print('MPIW:', np.round(np.mean(y_u_pred - y_l_pred),3))
# Out:
# PICP: 0.9675036927621861
# MPIW: 0.324

# %%
actual=test_y
actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = range(len(actual))
plt.figure(figsize=(15, 8))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='f1')
plt.plot(numEx,pred2,label='f2')
plt.legend(loc='best')
plt.title('Actual vs Pred')
plt.show()
