# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, LSTM, Dropout
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import RepeatVector, TimeDistributed, Input, BatchNormalization, multiply, concatenate, Activation, dot
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop,Adam,SGD,Adagrad, Nadam, Ftrl
#from keras.utils.vis_utils import plot_model, model_to_dot
from tensorflow.keras.utils import plot_model
import keras.backend as K
import datetime
from tensorflow.keras import regularizers
tf.keras.utils.set_random_seed(48) # Data reproducibility
tf.config.experimental.enable_op_determinism()

# %%
df = pd.read_csv('Sunspots.csv')
df = df[['Monthly Mean Total Sunspot Number']]
df.head()
# Out:
#    Monthly Mean Total Sunspot Number
# 0                               96.7
# 1                              104.3
# 2                              116.7
# 3                               92.8
# 4                              141.7

# %%
df1 = df.to_numpy()

# %%
def truncate(x, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=100, test_len=20):
    in_, out_= [], []
    for i in range(len(x)-train_len-test_len+1):
        in_.append(x[i:(i+train_len), feature_cols].tolist())
        out_.append(x[(i+train_len):(i+train_len+test_len), target_cols].tolist())
    return np.array(in_), np.array(out_)
X_in, X_out = truncate(df1, feature_cols=range(1), target_cols=range(1),label_col=1, train_len=16, test_len=1)
print(X_in.shape, X_out.shape)
# Out:
# (3249, 16, 1) (3249, 1, 1)

# %%
train_x = X_in[:math.floor(X_in.shape[0]*0.70)]
train_y = X_out[:math.floor(X_out.shape[0]*0.70)]
test_x = X_in[math.floor(X_in.shape[0]*0.70):]
test_y = X_out[math.floor(X_out.shape[0]*0.70):]
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
# Out:
# (2274, 16, 1) (2274, 1, 1) (975, 16, 1) (975, 1, 1)

# %%
r=0.5 # confidence {0-1}
q = 0.95
delta = 0.002# 0.05,0.1

def confidance_loss(y_true,y_pred):
  y_true = y_true[:,0]
  f1 = y_pred[:,0]
  f2 = y_pred[:,1]

  c1 = (1-q)*(y_true-f2)
  c2 = (1-q)*(f1-y_true)
  c3 = q*(f2-y_true)
  c4 = q*(y_true-f1)

  loss = K.switch(tf.math.logical_and((y_true <= f1),(y_true>=f2)),K.switch((y_true>r*(f1+f2)),c1,c2),K.switch((f2>y_true),c3,c4)) + (delta * tf.math.abs(f1-f2))

  return loss

# %%
input_train = Input(shape=(16, 1))
initializer = tf.keras.initializers.GlorotNormal(seed=None)
lstm_l1 = LSTM(256, activation='relu',kernel_initializer=initializer,return_sequences=True)(input_train)
dp_l1 = Dropout(0.3)(lstm_l1)
lstm_l2 = LSTM(128, activation='relu',kernel_initializer=initializer,return_sequences=False)(dp_l1)
dp_l2 = Dropout(0.2)(lstm_l2)
# lstm_l3 = LSTM(128, activation='relu',kernel_initializer=initializer,return_sequences=False)(dp_l1)
# dp_l3 = Dropout(0.1)(lstm_l3)
out = Dense(2)(dp_l2)
model = Model(inputs=input_train, outputs=out)
# Out:
# c:\Users\aades\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
opt = Adam(learning_rate=0.001)
model.compile(loss=confidance_loss,optimizer=opt)
model.summary()
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "model_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 16, 1)]           0
#
#  lstm_53 (LSTM)              (None, 16, 256)           264192
#
#  dropout_51 (Dropout)        (None, 16, 256)           0
#
#  lstm_54 (LSTM)              (None, 128)               197120
#
#  dropout_52 (Dropout)        (None, 128)               0
#
#  dense_20 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 461570 (1.76 MB)
# Trainable params: 461570 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
epc = 300
start_time = datetime.datetime.now()
stop_patience = 5
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
history = model.fit(train_x, train_y, validation_split=0.1, epochs=epc, verbose=1, batch_size=64)
end_time = datetime.datetime.now()
total_time = end_time - start_time
print('seconds taken:', round(total_time.total_seconds(),1),
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 32/32 [==============================] - 5s 96ms/step - loss: 12.5862 - val_loss: 7.0801
# Epoch 2/300
# 32/32 [==============================] - 3s 88ms/step - loss: 8.7559 - val_loss: 6.8148
# Epoch 3/300
# 32/32 [==============================] - 3s 89ms/step - loss: 7.6571 - val_loss: 4.5942
# Epoch 4/300
# 32/32 [==============================] - 3s 89ms/step - loss: 7.2653 - val_loss: 5.2801
# Epoch 5/300
# 32/32 [==============================] - 3s 89ms/step - loss: 6.0976 - val_loss: 4.5137
# Epoch 6/300
# 32/32 [==============================] - 3s 91ms/step - loss: 6.1528 - val_loss: 5.0196
# Epoch 7/300
# 32/32 [==============================] - 3s 93ms/step - loss: 6.2313 - val_loss: 4.7973
# Epoch 8/300
# 32/32 [==============================] - 3s 93ms/step - loss: 6.2282 - val_loss: 4.4503
# Epoch 9/300
# 32/32 [==============================] - 3s 93ms/step - loss: 5.9433 - val_loss: 4.5147
# Epoch 10/300
# 32/32 [==============================] - 3s 92ms/step - loss: 5.7357 - val_loss: 5.0107
# Epoch 11/300
# 32/32 [==============================] - 3s 92ms/step - loss: 5.2195 - val_loss: 4.1914
# Epoch 12/300
# 32/32 [==============================] - 3s 93ms/step - loss: 5.1050 - val_loss: 4.0158
# Epoch 13/300
# 32/32 [==============================] - 3s 95ms/step - loss: 5.5186 - val_loss: 4.8062
# Epoch 14/300
# 32/32 [==============================] - 3s 96ms/step - loss: 8.5627 - val_loss: 8.7961
# Epoch 15/300
# 32/32 [==============================] - 3s 96ms/step - loss: 10.5700 - val_loss: 6.1615
# Epoch 16/300
# 32/32 [==============================] - 3s 98ms/step - loss: 8.6833 - val_loss: 5.4134
# Epoch 17/300
# 32/32 [==============================] - 3s 98ms/step - loss: 6.5137 - val_loss: 4.8464
# Epoch 18/300
# 32/32 [==============================] - 3s 99ms/step - loss: 6.4863 - val_loss: 5.4274
# Epoch 19/300
# 32/32 [==============================] - 3s 100ms/step - loss: 6.5507 - val_loss: 4.8187
# Epoch 20/300
# 32/32 [==============================] - 3s 100ms/step - loss: 6.3509 - val_loss: 6.0974
# Epoch 21/300
# 32/32 [==============================] - 3s 103ms/step - loss: 8.6181 - val_loss: 8.3138
# Epoch 22/300
# 32/32 [==============================] - 3s 102ms/step - loss: 10.3690 - val_loss: 5.7994
# Epoch 23/300
# 32/32 [==============================] - 3s 105ms/step - loss: 10.5463 - val_loss: 8.4723
# Epoch 24/300
# 32/32 [==============================] - 3s 106ms/step - loss: 12.0495 - val_loss: 6.7009
# Epoch 25/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.0424 - val_loss: 6.3809
# Epoch 26/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.5462 - val_loss: 7.3317
# Epoch 27/300
# 32/32 [==============================] - 3s 109ms/step - loss: 8.3110 - val_loss: 7.5953
# Epoch 28/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.2871 - val_loss: 7.2248
# Epoch 29/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.7368 - val_loss: 6.1977
# Epoch 30/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.1703 - val_loss: 5.8398
# Epoch 31/300
# 32/32 [==============================] - 3s 109ms/step - loss: 10.8571 - val_loss: 8.1968
# Epoch 32/300
# 32/32 [==============================] - 3s 109ms/step - loss: 9.8935 - val_loss: 27.9591
# Epoch 33/300
# 32/32 [==============================] - 3s 108ms/step - loss: 9.8345 - val_loss: 11.0857
# Epoch 34/300
# 32/32 [==============================] - 3s 107ms/step - loss: 11.3449 - val_loss: 11.8697
# Epoch 35/300
# 32/32 [==============================] - 3s 108ms/step - loss: 11.0652 - val_loss: 7.2399
# Epoch 36/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.4620 - val_loss: 6.0340
# Epoch 37/300
# 32/32 [==============================] - 4s 110ms/step - loss: 8.0588 - val_loss: 6.1991
# Epoch 38/300
# 32/32 [==============================] - 3s 109ms/step - loss: 10.7152 - val_loss: 8.8492
# Epoch 39/300
# 32/32 [==============================] - 3s 109ms/step - loss: 10.2804 - val_loss: 12.3000
# Epoch 40/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.6278 - val_loss: 11.8889
# Epoch 41/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.4906 - val_loss: 7.5101
# Epoch 42/300
# 32/32 [==============================] - 3s 109ms/step - loss: 12.0237 - val_loss: 7.2893
# Epoch 43/300
# 32/32 [==============================] - 3s 109ms/step - loss: 10.4425 - val_loss: 8.0472
# Epoch 44/300
# 32/32 [==============================] - 3s 108ms/step - loss: 11.0301 - val_loss: 12.9597
# Epoch 45/300
# 32/32 [==============================] - 3s 109ms/step - loss: 11.8866 - val_loss: 7.4028
# Epoch 46/300
# 32/32 [==============================] - 3s 109ms/step - loss: 9.2433 - val_loss: 6.8578
# Epoch 47/300
# 32/32 [==============================] - 3s 109ms/step - loss: 9.6606 - val_loss: 7.0993
# Epoch 48/300
# 32/32 [==============================] - 3s 108ms/step - loss: 9.6507 - val_loss: 6.8617
# Epoch 49/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.9859 - val_loss: 7.3761
# Epoch 50/300
# 32/32 [==============================] - 3s 108ms/step - loss: 12.3233 - val_loss: 7.5341
# Epoch 51/300
# 32/32 [==============================] - 3s 108ms/step - loss: 10.1642 - val_loss: 6.5970
# Epoch 52/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.8663 - val_loss: 6.7194
# Epoch 53/300
# 32/32 [==============================] - 3s 108ms/step - loss: 10.8638 - val_loss: 27.0254
# Epoch 54/300
# 32/32 [==============================] - 4s 113ms/step - loss: 9.1876 - val_loss: 8.9209
# Epoch 55/300
# 32/32 [==============================] - 4s 110ms/step - loss: 8.4802 - val_loss: 8.7519
# Epoch 56/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.2301 - val_loss: 6.8141
# Epoch 57/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.3713 - val_loss: 6.8294
# Epoch 58/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.1374 - val_loss: 6.3905
# Epoch 59/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.5099 - val_loss: 6.7324
# Epoch 60/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.5021 - val_loss: 6.9480
# Epoch 61/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.6393 - val_loss: 7.0691
# Epoch 62/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.0981 - val_loss: 6.0105
# Epoch 63/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.4513 - val_loss: 7.2967
# Epoch 64/300
# 32/32 [==============================] - 4s 110ms/step - loss: 7.4332 - val_loss: 6.2372
# Epoch 65/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.3084 - val_loss: 6.7744
# Epoch 66/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.3060 - val_loss: 6.0358
# Epoch 67/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.3869 - val_loss: 6.2237
# Epoch 68/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.2783 - val_loss: 6.3456
# Epoch 69/300
# 32/32 [==============================] - 4s 110ms/step - loss: 7.0954 - val_loss: 6.3356
# Epoch 70/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.1294 - val_loss: 6.1659
# Epoch 71/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.5047 - val_loss: 7.1397
# Epoch 72/300
# 32/32 [==============================] - 4s 110ms/step - loss: 7.4465 - val_loss: 5.8270
# Epoch 73/300
# 32/32 [==============================] - 4s 110ms/step - loss: 7.1507 - val_loss: 6.4428
# Epoch 74/300
# 32/32 [==============================] - 4s 109ms/step - loss: 7.3117 - val_loss: 6.0869
# Epoch 75/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.1756 - val_loss: 5.9404
# Epoch 76/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.9791 - val_loss: 5.9517
# Epoch 77/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.0233 - val_loss: 6.2211
# Epoch 78/300
# 32/32 [==============================] - 4s 110ms/step - loss: 6.7103 - val_loss: 5.9179
# Epoch 79/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.7955 - val_loss: 8.9815
# Epoch 80/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.0455 - val_loss: 7.1989
# Epoch 81/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.6209 - val_loss: 5.4547
# Epoch 82/300
# 32/32 [==============================] - 3s 108ms/step - loss: 6.6531 - val_loss: 5.3174
# Epoch 83/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.3754 - val_loss: 5.9048
# Epoch 84/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.8387 - val_loss: 5.6506
# Epoch 85/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.5229 - val_loss: 5.4827
# Epoch 86/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.3455 - val_loss: 6.7502
# Epoch 87/300
# 32/32 [==============================] - 4s 110ms/step - loss: 6.1855 - val_loss: 5.2280
# Epoch 88/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.6951 - val_loss: 5.7623
# Epoch 89/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.1634 - val_loss: 7.8722
# Epoch 90/300
# 32/32 [==============================] - 4s 110ms/step - loss: 5.8842 - val_loss: 5.5951
# Epoch 91/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.7311 - val_loss: 7.5662
# Epoch 92/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.0667 - val_loss: 4.7647
# Epoch 93/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.0434 - val_loss: 5.2329
# Epoch 94/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.5562 - val_loss: 5.4418
# Epoch 95/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.2709 - val_loss: 5.6863
# Epoch 96/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.1807 - val_loss: 7.5388
# Epoch 97/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.0569 - val_loss: 5.1792
# Epoch 98/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.8456 - val_loss: 5.0404
# Epoch 99/300
# 32/32 [==============================] - 3s 108ms/step - loss: 6.0148 - val_loss: 5.3362
# Epoch 100/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.9303 - val_loss: 5.0799
# Epoch 101/300
# 32/32 [==============================] - 3s 107ms/step - loss: 6.1295 - val_loss: 6.3061
# Epoch 102/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.9434 - val_loss: 4.8620
# Epoch 103/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.9961 - val_loss: 6.0089
# Epoch 104/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.8087 - val_loss: 6.4321
# Epoch 105/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.8807 - val_loss: 6.3689
# Epoch 106/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.4445 - val_loss: 5.7008
# Epoch 107/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.6898 - val_loss: 5.6077
# Epoch 108/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.4004 - val_loss: 5.2842
# Epoch 109/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.4344 - val_loss: 5.2380
# Epoch 110/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.6188 - val_loss: 7.6605
# Epoch 111/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.5490 - val_loss: 5.3497
# Epoch 112/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.4895 - val_loss: 5.3838
# Epoch 113/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.4257 - val_loss: 5.3444
# Epoch 114/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.4417 - val_loss: 7.3607
# Epoch 115/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.2561 - val_loss: 6.1750
# Epoch 116/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.6015 - val_loss: 4.7505
# Epoch 117/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.1273 - val_loss: 4.7919
# Epoch 118/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.6817 - val_loss: 4.8303
# Epoch 119/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.4490 - val_loss: 4.6346
# Epoch 120/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.5514 - val_loss: 4.3574
# Epoch 121/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.5061 - val_loss: 4.5166
# Epoch 122/300
# 32/32 [==============================] - 3s 106ms/step - loss: 5.2380 - val_loss: 6.0497
# Epoch 123/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.2684 - val_loss: 5.1919
# Epoch 124/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.6173 - val_loss: 4.7299
# Epoch 125/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.3819 - val_loss: 4.5575
# Epoch 126/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.5277 - val_loss: 4.5020
# Epoch 127/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.3198 - val_loss: 4.9947
# Epoch 128/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.6874 - val_loss: 5.6064
# Epoch 129/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.7469 - val_loss: 4.4365
# Epoch 130/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.5333 - val_loss: 4.6509
# Epoch 131/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.5343 - val_loss: 4.7712
# Epoch 132/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.9581 - val_loss: 4.8457
# Epoch 133/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.2539 - val_loss: 4.6055
# Epoch 134/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.9467 - val_loss: 4.2590
# Epoch 135/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.1734 - val_loss: 4.2872
# Epoch 136/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.0060 - val_loss: 4.3613
# Epoch 137/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.0128 - val_loss: 4.4006
# Epoch 138/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.2905 - val_loss: 4.4317
# Epoch 139/300
# 32/32 [==============================] - 3s 110ms/step - loss: 5.0749 - val_loss: 4.5321
# Epoch 140/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.0337 - val_loss: 4.4320
# Epoch 141/300
# 32/32 [==============================] - 4s 111ms/step - loss: 4.9765 - val_loss: 4.4754
# Epoch 142/300
# 32/32 [==============================] - 4s 111ms/step - loss: 6.1396 - val_loss: 4.4785
# Epoch 143/300
# 32/32 [==============================] - 3s 108ms/step - loss: 6.7147 - val_loss: 5.8503
# Epoch 144/300
# 32/32 [==============================] - 3s 108ms/step - loss: 6.5338 - val_loss: 4.8564
# Epoch 145/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.8764 - val_loss: 5.3900
# Epoch 146/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.9013 - val_loss: 5.1038
# Epoch 147/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.6904 - val_loss: 4.9658
# Epoch 148/300
# 32/32 [==============================] - 3s 109ms/step - loss: 9.4589 - val_loss: 8.2592
# Epoch 149/300
# 32/32 [==============================] - 3s 109ms/step - loss: 10.8925 - val_loss: 7.4502
# Epoch 150/300
# 32/32 [==============================] - 3s 107ms/step - loss: 10.1422 - val_loss: 7.3467
# Epoch 151/300
# 32/32 [==============================] - 3s 108ms/step - loss: 10.7792 - val_loss: 7.6913
# Epoch 152/300
# 32/32 [==============================] - 3s 109ms/step - loss: 9.3014 - val_loss: 7.3897
# Epoch 153/300
# 32/32 [==============================] - 4s 110ms/step - loss: 8.6360 - val_loss: 6.8547
# Epoch 154/300
# 32/32 [==============================] - 4s 114ms/step - loss: 9.3001 - val_loss: 6.4886
# Epoch 155/300
# 32/32 [==============================] - 3s 109ms/step - loss: 8.6651 - val_loss: 6.8157
# Epoch 156/300
# 32/32 [==============================] - 3s 109ms/step - loss: 8.5025 - val_loss: 6.7385
# Epoch 157/300
# 32/32 [==============================] - 3s 109ms/step - loss: 8.7866 - val_loss: 5.8475
# Epoch 158/300
# 32/32 [==============================] - 3s 109ms/step - loss: 8.1892 - val_loss: 6.5317
# Epoch 159/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.6880 - val_loss: 5.7415
# Epoch 160/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.8505 - val_loss: 5.9918
# Epoch 161/300
# 32/32 [==============================] - 3s 109ms/step - loss: 7.4927 - val_loss: 5.8352
# Epoch 162/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.7983 - val_loss: 5.7539
# Epoch 163/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.2738 - val_loss: 5.6296
# Epoch 164/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.0174 - val_loss: 6.4123
# Epoch 165/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.2163 - val_loss: 5.9980
# Epoch 166/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.4253 - val_loss: 8.3683
# Epoch 167/300
# 32/32 [==============================] - 3s 106ms/step - loss: 8.8219 - val_loss: 6.8255
# Epoch 168/300
# 32/32 [==============================] - 3s 107ms/step - loss: 9.4238 - val_loss: 7.5817
# Epoch 169/300
# 32/32 [==============================] - 3s 108ms/step - loss: 8.5326 - val_loss: 6.2496
# Epoch 170/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.8616 - val_loss: 5.7725
# Epoch 171/300
# 32/32 [==============================] - 3s 107ms/step - loss: 8.9434 - val_loss: 6.4068
# Epoch 172/300
# 32/32 [==============================] - 4s 110ms/step - loss: 7.3625 - val_loss: 6.8222
# Epoch 173/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.6788 - val_loss: 5.9261
# Epoch 174/300
# 32/32 [==============================] - 4s 110ms/step - loss: 6.1985 - val_loss: 4.8856
# Epoch 175/300
# 32/32 [==============================] - 3s 107ms/step - loss: 6.8031 - val_loss: 5.8049
# Epoch 176/300
# 32/32 [==============================] - 3s 107ms/step - loss: 6.2110 - val_loss: 5.1242
# Epoch 177/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.0361 - val_loss: 5.4911
# Epoch 178/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.8982 - val_loss: 6.6011
# Epoch 179/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.5766 - val_loss: 5.5094
# Epoch 180/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.7904 - val_loss: 5.4425
# Epoch 181/300
# 32/32 [==============================] - 3s 108ms/step - loss: 7.0365 - val_loss: 6.3222
# Epoch 182/300
# 32/32 [==============================] - 3s 110ms/step - loss: 6.9563 - val_loss: 5.8171
# Epoch 183/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.2922 - val_loss: 4.7833
# Epoch 184/300
# 32/32 [==============================] - 3s 110ms/step - loss: 6.3178 - val_loss: 5.1450
# Epoch 185/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.7794 - val_loss: 4.7218
# Epoch 186/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.7290 - val_loss: 4.8800
# Epoch 187/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.5804 - val_loss: 4.5941
# Epoch 188/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.3924 - val_loss: 4.5186
# Epoch 189/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.4244 - val_loss: 4.3984
# Epoch 190/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.1633 - val_loss: 4.1311
# Epoch 191/300
# 32/32 [==============================] - 3s 106ms/step - loss: 5.3307 - val_loss: 4.3055
# Epoch 192/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.6191 - val_loss: 5.3226
# Epoch 193/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.6592 - val_loss: 4.5097
# Epoch 194/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.3343 - val_loss: 4.3613
# Epoch 195/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.2179 - val_loss: 4.8033
# Epoch 196/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.4740 - val_loss: 5.7637
# Epoch 197/300
# 32/32 [==============================] - 3s 107ms/step - loss: 6.7897 - val_loss: 5.1036
# Epoch 198/300
# 32/32 [==============================] - 4s 111ms/step - loss: 6.2434 - val_loss: 5.2273
# Epoch 199/300
# 32/32 [==============================] - 3s 109ms/step - loss: 6.2035 - val_loss: 5.0341
# Epoch 200/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.7216 - val_loss: 4.4404
# Epoch 201/300
# 32/32 [==============================] - 4s 110ms/step - loss: 5.5689 - val_loss: 5.0952
# Epoch 202/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.2984 - val_loss: 4.4973
# Epoch 203/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.3065 - val_loss: 4.3622
# Epoch 204/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.3634 - val_loss: 4.6761
# Epoch 205/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.3004 - val_loss: 4.7144
# Epoch 206/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.0626 - val_loss: 4.2315
# Epoch 207/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.1067 - val_loss: 4.2458
# Epoch 208/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.2560 - val_loss: 4.2577
# Epoch 209/300
# 32/32 [==============================] - 3s 109ms/step - loss: 5.0474 - val_loss: 5.2531
# Epoch 210/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.2208 - val_loss: 4.9271
# Epoch 211/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.8991 - val_loss: 4.5975
# Epoch 212/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.1027 - val_loss: 4.6133
# Epoch 213/300
# 32/32 [==============================] - 3s 107ms/step - loss: 5.0796 - val_loss: 4.2527
# Epoch 214/300
# 32/32 [==============================] - 3s 106ms/step - loss: 5.0598 - val_loss: 4.7021
# Epoch 215/300
# 32/32 [==============================] - 3s 108ms/step - loss: 5.1380 - val_loss: 4.4488
# Epoch 216/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.8937 - val_loss: 4.7289
# Epoch 217/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.6432 - val_loss: 4.4193
# Epoch 218/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.8284 - val_loss: 4.3188
# Epoch 219/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.9793 - val_loss: 4.3243
# Epoch 220/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.7443 - val_loss: 4.5754
# Epoch 221/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.6149 - val_loss: 4.4644
# Epoch 222/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.7649 - val_loss: 4.2994
# Epoch 223/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.6815 - val_loss: 4.2707
# Epoch 224/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.6732 - val_loss: 4.5689
# Epoch 225/300
# 32/32 [==============================] - 4s 111ms/step - loss: 4.6516 - val_loss: 4.8135
# Epoch 226/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.6877 - val_loss: 4.2264
# Epoch 227/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.8059 - val_loss: 4.1254
# Epoch 228/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.6713 - val_loss: 4.1598
# Epoch 229/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.6243 - val_loss: 4.4168
# Epoch 230/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.7179 - val_loss: 4.1097
# Epoch 231/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.6335 - val_loss: 4.1185
# Epoch 232/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.4603 - val_loss: 4.3929
# Epoch 233/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.4832 - val_loss: 4.0478
# Epoch 234/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.5677 - val_loss: 4.0527
# Epoch 235/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.5995 - val_loss: 4.0757
# Epoch 236/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.6220 - val_loss: 4.1832
# Epoch 237/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.6060 - val_loss: 4.0795
# Epoch 238/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.4856 - val_loss: 4.0437
# Epoch 239/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.7924 - val_loss: 4.1600
# Epoch 240/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.5754 - val_loss: 4.0729
# Epoch 241/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.3583 - val_loss: 4.1135
# Epoch 242/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.5086 - val_loss: 4.0057
# Epoch 243/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.4821 - val_loss: 4.2326
# Epoch 244/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.4966 - val_loss: 3.9660
# Epoch 245/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.3378 - val_loss: 3.8962
# Epoch 246/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.3643 - val_loss: 3.9322
# Epoch 247/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.5336 - val_loss: 3.8983
# Epoch 248/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.3841 - val_loss: 3.9660
# Epoch 249/300
# 32/32 [==============================] - 4s 110ms/step - loss: 4.2786 - val_loss: 4.0981
# Epoch 250/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.3936 - val_loss: 4.2568
# Epoch 251/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.3623 - val_loss: 3.9211
# Epoch 252/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.3444 - val_loss: 3.9294
# Epoch 253/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.4311 - val_loss: 4.1924
# Epoch 254/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.3947 - val_loss: 4.0635
# Epoch 255/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.3698 - val_loss: 4.0278
# Epoch 256/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2449 - val_loss: 3.8361
# Epoch 257/300
# 32/32 [==============================] - 4s 111ms/step - loss: 4.2071 - val_loss: 3.8042
# Epoch 258/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2991 - val_loss: 4.0238
# Epoch 259/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.0931 - val_loss: 3.8623
# Epoch 260/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.4294 - val_loss: 3.9194
# Epoch 261/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.2378 - val_loss: 4.0339
# Epoch 262/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.3339 - val_loss: 3.9626
# Epoch 263/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2970 - val_loss: 4.2077
# Epoch 264/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.2554 - val_loss: 3.9432
# Epoch 265/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2647 - val_loss: 4.3685
# Epoch 266/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.3168 - val_loss: 4.1182
# Epoch 267/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.2190 - val_loss: 3.9279
# Epoch 268/300
# 32/32 [==============================] - 4s 112ms/step - loss: 4.2358 - val_loss: 4.0144
# Epoch 269/300
# 32/32 [==============================] - 4s 110ms/step - loss: 4.2136 - val_loss: 3.9165
# Epoch 270/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.1870 - val_loss: 3.9417
# Epoch 271/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.0926 - val_loss: 3.8375
# Epoch 272/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2178 - val_loss: 4.1111
# Epoch 273/300
# 32/32 [==============================] - 4s 110ms/step - loss: 4.1431 - val_loss: 3.9518
# Epoch 274/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2414 - val_loss: 3.8116
# Epoch 275/300
# 32/32 [==============================] - 4s 111ms/step - loss: 4.0475 - val_loss: 4.1287
# Epoch 276/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2310 - val_loss: 4.0711
# Epoch 277/300
# 32/32 [==============================] - 4s 110ms/step - loss: 4.2411 - val_loss: 3.8530
# Epoch 278/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.2467 - val_loss: 4.0640
# Epoch 279/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2126 - val_loss: 3.9421
# Epoch 280/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.1182 - val_loss: 3.7555
# Epoch 281/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.2622 - val_loss: 3.9972
# Epoch 282/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.1806 - val_loss: 3.9750
# Epoch 283/300
# 32/32 [==============================] - 4s 109ms/step - loss: 4.0261 - val_loss: 4.0770
# Epoch 284/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.1371 - val_loss: 4.2663
# Epoch 285/300
# 32/32 [==============================] - 4s 110ms/step - loss: 4.3451 - val_loss: 3.8800
# Epoch 286/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.1750 - val_loss: 3.9193
# Epoch 287/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.0203 - val_loss: 3.7351
# Epoch 288/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.0386 - val_loss: 4.3484
# Epoch 289/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.2792 - val_loss: 3.9872
# Epoch 290/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.0721 - val_loss: 4.3296
# Epoch 291/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.0236 - val_loss: 3.8018
# Epoch 292/300
# 32/32 [==============================] - 4s 110ms/step - loss: 4.1554 - val_loss: 4.1072
# Epoch 293/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.0913 - val_loss: 3.8519
# Epoch 294/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.0991 - val_loss: 4.2552
# Epoch 295/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.0727 - val_loss: 3.9560
# Epoch 296/300
# 32/32 [==============================] - 3s 110ms/step - loss: 4.1570 - val_loss: 3.9513
# Epoch 297/300
# 32/32 [==============================] - 3s 109ms/step - loss: 4.1154 - val_loss: 4.4184
# Epoch 298/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.0080 - val_loss: 4.1743
# Epoch 299/300
# 32/32 [==============================] - 3s 108ms/step - loss: 4.1017 - val_loss: 4.1651
# Epoch 300/300
# 32/32 [==============================] - 3s 107ms/step - loss: 4.1172 - val_loss: 3.9675
# seconds taken: 1032.6
# start_time: 04:00:42 end_time: 04:17:55

# %%
y_pred = model.predict(test_x, verbose=0)
test_y_ = np.squeeze(test_y)  # Actual test values
y_u_pred = y_pred[:, 0]  # Upper bound predictions
y_l_pred = y_pred[:, 1]  # Lower bound predictions

K_u = y_u_pred > test_y_
K_l = y_l_pred < test_y_

print(f'PICP: {np.mean(K_u * K_l)}')
print(f'MPIW: {np.round(np.mean(y_u_pred - y_l_pred), 3)}')
# Out:
# PICP: 0.9517948717948718
# MPIW: 101.20500183105469

# %%
fig,ax = plt.subplots()
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='test loss')
ax.set_xlabel('EPOCHS')
ax.set_ylabel('Loss value')
plt.legend()

# %%
actual = np.squeeze(test_y)
pred1 = y_u_pred
pred2 = y_l_pred
numEx = range(len(actual))
plt.figure(figsize=(15, 8))
plt.plot(numEx, actual, label='Actual')
plt.plot(numEx, pred1, label='Upper Bound (f1)')
plt.plot(numEx, pred2, label='Lower Bound (f2)')
plt.legend(loc='best')
plt.title('Actual vs Predicted (Upper and Lower Bounds)')
plt.show()
