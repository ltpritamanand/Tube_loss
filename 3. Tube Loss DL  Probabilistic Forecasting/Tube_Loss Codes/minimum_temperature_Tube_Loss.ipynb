# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, LSTM, Dropout
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import RepeatVector, TimeDistributed, Input, BatchNormalization, multiply, concatenate, Activation, dot
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop,Adam,SGD,Adagrad, Nadam, Ftrl
#from keras.utils.vis_utils import plot_model, model_to_dot
from tensorflow.keras.utils import plot_model
import keras.backend as K
import datetime
from tensorflow.keras import regularizers
tf.keras.utils.set_random_seed(48) # Data reproducibility
tf.config.experimental.enable_op_determinism()

# %%
df = pd.read_csv('daily-minimum-temperatures-in-me.csv')
df['Daily minimum temperatures in Melbourne, Australia, 1981-1990'] = df['Daily minimum temperatures in Melbourne, Australia, 1981-1990'].replace({'?0.2': np.nan, '?0.8': np.nan, '?0.1': np.nan})

df['Daily minimum temperatures in Melbourne, Australia, 1981-1990'] = df['Daily minimum temperatures in Melbourne, Australia, 1981-1990'].astype(float)

df.dropna(inplace=True)

df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

# %%
df1 = df.to_numpy()

# %%
def truncate(x, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=100, test_len=20):
    in_, out_= [], []
    for i in range(len(x)-train_len-test_len+1):
        in_.append(x[i:(i+train_len), feature_cols].tolist())
        out_.append(x[(i+train_len):(i+train_len+test_len), target_cols].tolist())
    return np.array(in_), np.array(out_)
X_in, X_out = truncate(df1, feature_cols=range(1), target_cols=range(1),label_col=1, train_len=16, test_len=1)
print(X_in.shape, X_out.shape)
# Out:
# (3631, 16, 1) (3631, 1, 1)

# %%
train_x = X_in[:math.floor(X_in.shape[0]*0.70)]
train_y = X_out[:math.floor(X_out.shape[0]*0.70)]
test_x = X_in[math.floor(X_in.shape[0]*0.70):]
test_y = X_out[math.floor(X_out.shape[0]*0.70):]
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
# Out:
# (2541, 16, 1) (2541, 1, 1) (1090, 16, 1) (1090, 1, 1)

# %%
r=0.5 # confidence {0-1}
q = 0.95
delta = 0.001# 0.05,0.1

def confidance_loss(y_true,y_pred):
  y_true = y_true[:,0]
  f1 = y_pred[:,0]
  f2 = y_pred[:,1]

  c1 = (1-q)*(y_true-f2)
  c2 = (1-q)*(f1-y_true)
  c3 = q*(f2-y_true)
  c4 = q*(y_true-f1)

  loss = K.switch(tf.math.logical_and((y_true <= f1),(y_true>=f2)),K.switch((y_true>r*(f1+f2)),c1,c2),K.switch((f2>y_true),c3,c4)) + (delta * tf.math.abs(f1-f2))

  return loss

# %%
input_train = Input(shape=(16, 1))
initializer = tf.keras.initializers.GlorotNormal(seed=None)
lstm_l1 = LSTM(16, activation='relu',kernel_initializer=initializer,return_sequences=True)(input_train)
# dp_l1 = Dropout(0.3)(lstm_l1)
lstm_l2 = LSTM(8, activation='relu',kernel_initializer=initializer,return_sequences=False)(lstm_l1)
# dp_l2 = Dropout(0.2)(lstm_l2)
# lstm_l3 = LSTM(128, activation='relu',kernel_initializer=initializer,return_sequences=False)(dp_l1)
# dp_l3 = Dropout(0.1)(lstm_l3)
out = Dense(2)(lstm_l2)
model = Model(inputs=input_train, outputs=out)
# Out:
# c:\Users\aades\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\initializers\initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
opt = Adam(learning_rate=0.001)
model.compile(loss=confidance_loss,optimizer=opt)
model.summary()
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 16, 1)]           0
#
#  lstm (LSTM)                 (None, 16, 16)            1152
#
#  lstm_1 (LSTM)               (None, 8)                 800
#
#  dense (Dense)               (None, 2)                 18
#
# =================================================================
# Total params: 1970 (7.70 KB)
# Trainable params: 1970 (7.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
epc = 300
start_time = datetime.datetime.now()
stop_patience = 5
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
history = model.fit(train_x, train_y, validation_split=0.1, epochs=epc, verbose=1, batch_size=128)
end_time = datetime.datetime.now()
total_time = end_time - start_time
print('seconds taken:', round(total_time.total_seconds(),1),
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 18/18 [==============================] - 3s 42ms/step - loss: 6.1179 - val_loss: 4.9611
# Epoch 2/300
# 18/18 [==============================] - 0s 12ms/step - loss: 4.1118 - val_loss: 2.0537
# Epoch 3/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.9265 - val_loss: 0.4984
# Epoch 4/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5102 - val_loss: 0.4288
# Epoch 5/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.4557 - val_loss: 0.4236
# Epoch 6/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.4365 - val_loss: 0.4280
# Epoch 7/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.4151 - val_loss: 0.4199
# Epoch 8/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.4173 - val_loss: 0.4061
# Epoch 9/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.4090 - val_loss: 0.4366
# Epoch 10/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.4089 - val_loss: 0.4185
# Epoch 11/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.4013 - val_loss: 0.4138
# Epoch 12/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.4113 - val_loss: 0.4084
# Epoch 13/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.4041 - val_loss: 0.4350
# Epoch 14/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.4100 - val_loss: 0.4019
# Epoch 15/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.4010 - val_loss: 0.4104
# Epoch 16/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.4004 - val_loss: 0.4078
# Epoch 17/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3936 - val_loss: 0.4053
# Epoch 18/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3999 - val_loss: 0.3989
# Epoch 19/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3895 - val_loss: 0.4102
# Epoch 20/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3957 - val_loss: 0.3914
# Epoch 21/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3889 - val_loss: 0.4066
# Epoch 22/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3959 - val_loss: 0.4090
# Epoch 23/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3923 - val_loss: 0.3946
# Epoch 24/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3891 - val_loss: 0.3959
# Epoch 25/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3854 - val_loss: 0.3906
# Epoch 26/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3833 - val_loss: 0.3935
# Epoch 27/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3854 - val_loss: 0.3892
# Epoch 28/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3839 - val_loss: 0.3856
# Epoch 29/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3820 - val_loss: 0.3838
# Epoch 30/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3815 - val_loss: 0.3790
# Epoch 31/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3816 - val_loss: 0.3924
# Epoch 32/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3845 - val_loss: 0.3867
# Epoch 33/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3812 - val_loss: 0.3859
# Epoch 34/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3755 - val_loss: 0.3955
# Epoch 35/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3818 - val_loss: 0.3866
# Epoch 36/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3793 - val_loss: 0.3864
# Epoch 37/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3773 - val_loss: 0.3823
# Epoch 38/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3776 - val_loss: 0.3945
# Epoch 39/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3780 - val_loss: 0.3984
# Epoch 40/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3820 - val_loss: 0.3774
# Epoch 41/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3800 - val_loss: 0.3736
# Epoch 42/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3715 - val_loss: 0.3800
# Epoch 43/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3733 - val_loss: 0.3738
# Epoch 44/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3742 - val_loss: 0.3829
# Epoch 45/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3771 - val_loss: 0.3754
# Epoch 46/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3734 - val_loss: 0.3779
# Epoch 47/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3783 - val_loss: 0.3744
# Epoch 48/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3801 - val_loss: 0.3812
# Epoch 49/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3724 - val_loss: 0.3878
# Epoch 50/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3748 - val_loss: 0.3703
# Epoch 51/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3731 - val_loss: 0.3753
# Epoch 52/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3698 - val_loss: 0.3875
# Epoch 53/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3737 - val_loss: 0.3845
# Epoch 54/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3742 - val_loss: 0.3742
# Epoch 55/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3703 - val_loss: 0.3737
# Epoch 56/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3726 - val_loss: 0.3659
# Epoch 57/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3731 - val_loss: 0.3762
# Epoch 58/300
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3708 - val_loss: 0.3830
# Epoch 59/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3878 - val_loss: 0.3644
# Epoch 60/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3758 - val_loss: 0.3773
# Epoch 61/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3741 - val_loss: 0.3625
# Epoch 62/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3707 - val_loss: 0.3734
# Epoch 63/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3722 - val_loss: 0.3760
# Epoch 64/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3775 - val_loss: 0.3757
# Epoch 65/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3710 - val_loss: 0.3696
# Epoch 66/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3727 - val_loss: 0.3649
# Epoch 67/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3686 - val_loss: 0.3855
# Epoch 68/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3736 - val_loss: 0.3659
# Epoch 69/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3665 - val_loss: 0.3749
# Epoch 70/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3753 - val_loss: 0.3782
# Epoch 71/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3742 - val_loss: 0.3684
# Epoch 72/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3659 - val_loss: 0.3777
# Epoch 73/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3675 - val_loss: 0.3758
# Epoch 74/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3721 - val_loss: 0.3721
# Epoch 75/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3672 - val_loss: 0.3758
# Epoch 76/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3735 - val_loss: 0.3772
# Epoch 77/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3688 - val_loss: 0.3671
# Epoch 78/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3683 - val_loss: 0.3672
# Epoch 79/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3681 - val_loss: 0.3656
# Epoch 80/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3656 - val_loss: 0.3723
# Epoch 81/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3647 - val_loss: 0.3699
# Epoch 82/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3687 - val_loss: 0.3898
# Epoch 83/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3856 - val_loss: 0.3828
# Epoch 84/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3798 - val_loss: 0.3689
# Epoch 85/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3775 - val_loss: 0.3628
# Epoch 86/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3692 - val_loss: 0.3675
# Epoch 87/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3701 - val_loss: 0.3658
# Epoch 88/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3720 - val_loss: 0.3959
# Epoch 89/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3722 - val_loss: 0.3611
# Epoch 90/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3658 - val_loss: 0.3649
# Epoch 91/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3642 - val_loss: 0.3826
# Epoch 92/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3672 - val_loss: 0.3833
# Epoch 93/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3737 - val_loss: 0.3810
# Epoch 94/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3698 - val_loss: 0.3734
# Epoch 95/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3670 - val_loss: 0.3631
# Epoch 96/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3649 - val_loss: 0.3627
# Epoch 97/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3648 - val_loss: 0.3640
# Epoch 98/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3658 - val_loss: 0.3669
# Epoch 99/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3641 - val_loss: 0.3731
# Epoch 100/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3632 - val_loss: 0.3653
# Epoch 101/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3658 - val_loss: 0.3769
# Epoch 102/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3665 - val_loss: 0.3782
# Epoch 103/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3632 - val_loss: 0.3634
# Epoch 104/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3643 - val_loss: 0.3624
# Epoch 105/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3661 - val_loss: 0.3660
# Epoch 106/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3633 - val_loss: 0.3638
# Epoch 107/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3644 - val_loss: 0.3672
# Epoch 108/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3590 - val_loss: 0.3914
# Epoch 109/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3731 - val_loss: 0.3701
# Epoch 110/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3699 - val_loss: 0.3760
# Epoch 111/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3637 - val_loss: 0.3818
# Epoch 112/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3654 - val_loss: 0.3687
# Epoch 113/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3683 - val_loss: 0.3743
# Epoch 114/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3647 - val_loss: 0.3664
# Epoch 115/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3621 - val_loss: 0.3719
# Epoch 116/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3637 - val_loss: 0.3628
# Epoch 117/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3616 - val_loss: 0.3610
# Epoch 118/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3677 - val_loss: 0.3638
# Epoch 119/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3619 - val_loss: 0.3721
# Epoch 120/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3636 - val_loss: 0.3635
# Epoch 121/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3618 - val_loss: 0.3661
# Epoch 122/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3632 - val_loss: 0.3655
# Epoch 123/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3654 - val_loss: 0.3624
# Epoch 124/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3683 - val_loss: 0.3573
# Epoch 125/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3698 - val_loss: 0.3751
# Epoch 126/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3648 - val_loss: 0.3614
# Epoch 127/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3642 - val_loss: 0.3682
# Epoch 128/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3612 - val_loss: 0.3652
# Epoch 129/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3625 - val_loss: 0.3650
# Epoch 130/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3632 - val_loss: 0.3637
# Epoch 131/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3638 - val_loss: 0.3644
# Epoch 132/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3642 - val_loss: 0.3623
# Epoch 133/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3620 - val_loss: 0.3652
# Epoch 134/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3684 - val_loss: 0.3924
# Epoch 135/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3657 - val_loss: 0.3691
# Epoch 136/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3645 - val_loss: 0.3614
# Epoch 137/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3607 - val_loss: 0.3585
# Epoch 138/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3654 - val_loss: 0.3712
# Epoch 139/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3597 - val_loss: 0.3609
# Epoch 140/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3687 - val_loss: 0.3653
# Epoch 141/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3655 - val_loss: 0.3894
# Epoch 142/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3670 - val_loss: 0.3645
# Epoch 143/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3605 - val_loss: 0.3636
# Epoch 144/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3603 - val_loss: 0.3634
# Epoch 145/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3626 - val_loss: 0.3630
# Epoch 146/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3669 - val_loss: 0.3581
# Epoch 147/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3635 - val_loss: 0.3622
# Epoch 148/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3684 - val_loss: 0.3757
# Epoch 149/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3662 - val_loss: 0.3627
# Epoch 150/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3671 - val_loss: 0.3751
# Epoch 151/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3621 - val_loss: 0.3768
# Epoch 152/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3674 - val_loss: 0.3767
# Epoch 153/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3742 - val_loss: 0.3601
# Epoch 154/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3629 - val_loss: 0.3623
# Epoch 155/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3622 - val_loss: 0.3621
# Epoch 156/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3618 - val_loss: 0.3702
# Epoch 157/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3658 - val_loss: 0.3671
# Epoch 158/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3609 - val_loss: 0.3687
# Epoch 159/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3631 - val_loss: 0.3591
# Epoch 160/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3727 - val_loss: 0.3787
# Epoch 161/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3697 - val_loss: 0.3816
# Epoch 162/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3680 - val_loss: 0.3604
# Epoch 163/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3630 - val_loss: 0.3626
# Epoch 164/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3616 - val_loss: 0.3600
# Epoch 165/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3642 - val_loss: 0.3636
# Epoch 166/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3699 - val_loss: 0.3637
# Epoch 167/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3583 - val_loss: 0.3741
# Epoch 168/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3628 - val_loss: 0.3771
# Epoch 169/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3668 - val_loss: 0.3629
# Epoch 170/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3619 - val_loss: 0.3629
# Epoch 171/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3583 - val_loss: 0.3627
# Epoch 172/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3600 - val_loss: 0.3643
# Epoch 173/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3611 - val_loss: 0.3815
# Epoch 174/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3650 - val_loss: 0.3696
# Epoch 175/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3655 - val_loss: 0.3582
# Epoch 176/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3592 - val_loss: 0.3634
# Epoch 177/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3596 - val_loss: 0.3711
# Epoch 178/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3587 - val_loss: 0.3633
# Epoch 179/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3603 - val_loss: 0.3615
# Epoch 180/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3607 - val_loss: 0.3613
# Epoch 181/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3634 - val_loss: 0.3589
# Epoch 182/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3597 - val_loss: 0.3563
# Epoch 183/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3584 - val_loss: 0.3582
# Epoch 184/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3597 - val_loss: 0.3733
# Epoch 185/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3603 - val_loss: 0.3627
# Epoch 186/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3594 - val_loss: 0.3619
# Epoch 187/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3584 - val_loss: 0.3598
# Epoch 188/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3662 - val_loss: 0.3580
# Epoch 189/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3636 - val_loss: 0.3637
# Epoch 190/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3593 - val_loss: 0.3584
# Epoch 191/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3616 - val_loss: 0.3606
# Epoch 192/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3627 - val_loss: 0.3553
# Epoch 193/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3578 - val_loss: 0.3679
# Epoch 194/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3604 - val_loss: 0.3632
# Epoch 195/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3545 - val_loss: 0.3663
# Epoch 196/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3637 - val_loss: 0.3617
# Epoch 197/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3596 - val_loss: 0.3614
# Epoch 198/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3582 - val_loss: 0.3710
# Epoch 199/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3640 - val_loss: 0.3645
# Epoch 200/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3725 - val_loss: 0.3659
# Epoch 201/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3591 - val_loss: 0.3598
# Epoch 202/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3587 - val_loss: 0.3610
# Epoch 203/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3548 - val_loss: 0.3610
# Epoch 204/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3632 - val_loss: 0.3583
# Epoch 205/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3556 - val_loss: 0.3595
# Epoch 206/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3582 - val_loss: 0.3724
# Epoch 207/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3604 - val_loss: 0.3659
# Epoch 208/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3585 - val_loss: 0.3715
# Epoch 209/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3624 - val_loss: 0.3769
# Epoch 210/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3613 - val_loss: 0.3725
# Epoch 211/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3577 - val_loss: 0.3743
# Epoch 212/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3680 - val_loss: 0.3606
# Epoch 213/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3585 - val_loss: 0.3747
# Epoch 214/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3589 - val_loss: 0.3575
# Epoch 215/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3606 - val_loss: 0.3691
# Epoch 216/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3581 - val_loss: 0.3742
# Epoch 217/300
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3649 - val_loss: 0.3673
# Epoch 218/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3555 - val_loss: 0.3641
# Epoch 219/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3617 - val_loss: 0.3552
# Epoch 220/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3590 - val_loss: 0.3596
# Epoch 221/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3561 - val_loss: 0.3682
# Epoch 222/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3553 - val_loss: 0.3717
# Epoch 223/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3586 - val_loss: 0.3616
# Epoch 224/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3585 - val_loss: 0.3609
# Epoch 225/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3565 - val_loss: 0.3547
# Epoch 226/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3625 - val_loss: 0.3635
# Epoch 227/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3564 - val_loss: 0.3586
# Epoch 228/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3578 - val_loss: 0.3737
# Epoch 229/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3599 - val_loss: 0.3707
# Epoch 230/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3596 - val_loss: 0.3548
# Epoch 231/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3564 - val_loss: 0.3585
# Epoch 232/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3527 - val_loss: 0.3739
# Epoch 233/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3606 - val_loss: 0.3609
# Epoch 234/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3566 - val_loss: 0.3581
# Epoch 235/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3575 - val_loss: 0.3543
# Epoch 236/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3622 - val_loss: 0.3562
# Epoch 237/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3567 - val_loss: 0.3632
# Epoch 238/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3548 - val_loss: 0.3634
# Epoch 239/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3567 - val_loss: 0.3592
# Epoch 240/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3554 - val_loss: 0.3531
# Epoch 241/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3559 - val_loss: 0.3691
# Epoch 242/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3564 - val_loss: 0.3568
# Epoch 243/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3540 - val_loss: 0.3577
# Epoch 244/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3562 - val_loss: 0.3718
# Epoch 245/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3590 - val_loss: 0.3551
# Epoch 246/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3764 - val_loss: 0.3635
# Epoch 247/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3665 - val_loss: 0.3554
# Epoch 248/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3600 - val_loss: 0.3615
# Epoch 249/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3562 - val_loss: 0.3688
# Epoch 250/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3582 - val_loss: 0.3541
# Epoch 251/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3596 - val_loss: 0.3549
# Epoch 252/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3537 - val_loss: 0.3666
# Epoch 253/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3577 - val_loss: 0.3621
# Epoch 254/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3554 - val_loss: 0.3616
# Epoch 255/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3513 - val_loss: 0.3642
# Epoch 256/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3535 - val_loss: 0.3769
# Epoch 257/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3574 - val_loss: 0.3666
# Epoch 258/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3590 - val_loss: 0.3608
# Epoch 259/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3570 - val_loss: 0.3571
# Epoch 260/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3607 - val_loss: 0.3568
# Epoch 261/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3588 - val_loss: 0.3673
# Epoch 262/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3552 - val_loss: 0.3576
# Epoch 263/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3534 - val_loss: 0.3656
# Epoch 264/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3566 - val_loss: 0.3480
# Epoch 265/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3551 - val_loss: 0.3540
# Epoch 266/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3555 - val_loss: 0.3544
# Epoch 267/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3548 - val_loss: 0.3642
# Epoch 268/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3548 - val_loss: 0.3570
# Epoch 269/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3556 - val_loss: 0.3552
# Epoch 270/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3557 - val_loss: 0.3551
# Epoch 271/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3537 - val_loss: 0.3807
# Epoch 272/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3541 - val_loss: 0.3779
# Epoch 273/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3565 - val_loss: 0.3618
# Epoch 274/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3574 - val_loss: 0.3621
# Epoch 275/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3584 - val_loss: 0.3569
# Epoch 276/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3545 - val_loss: 0.3529
# Epoch 277/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3540 - val_loss: 0.3604
# Epoch 278/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3528 - val_loss: 0.3624
# Epoch 279/300
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3514 - val_loss: 0.3637
# Epoch 280/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3563 - val_loss: 0.3623
# Epoch 281/300
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3540 - val_loss: 0.3601
# Epoch 282/300
# 18/18 [==============================] - 0s 19ms/step - loss: 0.3543 - val_loss: 0.3547
# Epoch 283/300
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3548 - val_loss: 0.3533
# Epoch 284/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3547 - val_loss: 0.3532
# Epoch 285/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3498 - val_loss: 0.3679
# Epoch 286/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3617 - val_loss: 0.3561
# Epoch 287/300
# 18/18 [==============================] - 0s 18ms/step - loss: 0.3542 - val_loss: 0.3605
# Epoch 288/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3546 - val_loss: 0.3700
# Epoch 289/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3585 - val_loss: 0.3566
# Epoch 290/300
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3537 - val_loss: 0.3523
# Epoch 291/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3514 - val_loss: 0.3586
# Epoch 292/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3589 - val_loss: 0.3537
# Epoch 293/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3523 - val_loss: 0.3478
# Epoch 294/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3545 - val_loss: 0.3562
# Epoch 295/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3521 - val_loss: 0.3581
# Epoch 296/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3580 - val_loss: 0.3646
# Epoch 297/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3523 - val_loss: 0.3603
# Epoch 298/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3506 - val_loss: 0.3673
# Epoch 299/300
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3568 - val_loss: 0.3481
# Epoch 300/300
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3551 - val_loss: 0.3592
# seconds taken: 64.4
# start_time: 20:02:42 end_time: 20:03:46

# %%
y_pred = model.predict(test_x, verbose=0)
test_y_ = np.squeeze(test_y)  # Actual test values
y_u_pred = y_pred[:, 0]  # Upper bound predictions
y_l_pred = y_pred[:, 1]  # Lower bound predictions

K_u = y_u_pred > test_y_
K_l = y_l_pred < test_y_

print(f'PICP: {np.mean(K_u * K_l)}')
print(f'MPIW: {np.round(np.mean(y_u_pred - y_l_pred), 3)}')
# Out:
# PICP: 0.9513761467889909
# MPIW: 9.503999710083008

# %%
fig,ax = plt.subplots()
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='test loss')
ax.set_xlabel('EPOCHS')
ax.set_ylabel('Loss value')
plt.legend()

# %%
actual = np.squeeze(test_y)
pred1 = y_u_pred
pred2 = y_l_pred
numEx = range(len(actual))
plt.figure(figsize=(15, 8))
plt.plot(numEx, actual, label='Actual')
plt.plot(numEx, pred1, label='Upper Bound (f1)')
plt.plot(numEx, pred2, label='Lower Bound (f2)')
plt.legend(loc='best')
plt.title('Actual vs Predicted (Upper and Lower Bounds)')
plt.show()
