# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from pylab import rcParams
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
tf.keras.utils.set_random_seed(1)
tf.config.experimental.enable_op_determinism()
# Set seeds for reproducibility
seed_value = 128
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, LSTM, Dropout
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import RepeatVector, TimeDistributed, Input, BatchNormalization, multiply, concatenate, Activation, dot
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop,Adam,SGD,Adagrad, Nadam, Ftrl
#from keras.utils.vis_utils import plot_model, model_to_dot
from tensorflow.keras.utils import plot_model
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import keras.backend as K
import datetime
from tensorflow.keras import regularizers

# %%
df = pd.read_csv('daily-total-female-births-CA.csv',index_col='date', parse_dates=True)
df["births"]=df["births"].astype(float)
df.head()
# Out:
#             births
# date
# 1959-01-01    35.0
# 1959-01-02    32.0
# 1959-01-03    30.0
# 1959-01-04    31.0
# 1959-01-05    44.0

# %%
df1 = df.to_numpy()

# %%
def truncate(x, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=100, test_len=20):
    in_, out_= [], []
    for i in range(len(x)-train_len-test_len+1):
        in_.append(x[i:(i+train_len), feature_cols].tolist())
        out_.append(x[(i+train_len):(i+train_len+test_len), target_cols].tolist())
    return np.array(in_), np.array(out_)
X_in, X_out = truncate(df1, feature_cols=range(1), target_cols=range(1),label_col=1, train_len=12, test_len=1)
print(X_in.shape, X_out.shape)
# Out:
# (353, 12, 1) (353, 1, 1)

# %%
train_x = X_in[:math.floor(X_in.shape[0]*0.70)]
train_y = X_out[:math.floor(X_out.shape[0]*0.70)]
test_x = X_in[math.floor(X_in.shape[0]*0.70):]
test_y = X_out[math.floor(X_out.shape[0]*0.70):]
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
# Out:
# (247, 12, 1) (247, 1, 1) (106, 12, 1) (106, 1, 1)

# %%
r=0.5 # confidence {0-1}
q = 0.95
delta = 0.003 # 0.05,0.1
l=2

def confidance_loss(y_true,y_pred):
  y_true = y_true[:,0]
  f1 = y_pred[:,0]
  f2 = y_pred[:,1]

  c1 = (1-q)*(y_true-f2)
  c2 = (1-q)*(f1-y_true)
  c3 = q*(f2-y_true)
  c4 = q*(y_true-f1)

  loss = K.switch(tf.math.logical_and((y_true <= f1),(y_true>=f2)),K.switch((y_true>r*(f1+f2)),c1,c2),K.switch((f2>y_true),c3,c4)) + (delta * tf.math.abs(f1-f2))

  return loss

# %%
#Model Architecture.
input_train = Input(shape=(12, 1))
initializer = tf.keras.initializers.GlorotNormal(seed=None)
lstm_l1 = LSTM(100, activation='relu',kernel_initializer=initializer,return_sequences=False)(input_train)
out = Dense(2)(lstm_l1)
model = Model(inputs=input_train, outputs=out)

# %%
opt = Adam(learning_rate=0.005)
model.compile(loss=confidance_loss,optimizer=opt)
model.summary()
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 12, 1)]           0
#
#  lstm_1 (LSTM)               (None, 100)               40800
#
#  dense_1 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 41002 (160.16 KB)
# Trainable params: 41002 (160.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
epc = 300
start_time = datetime.datetime.now()
history = model.fit(train_x, train_y, validation_split=0.1, epochs=epc, verbose=1, batch_size=128)
end_time = datetime.datetime.now()
total_time = end_time - start_time
print('seconds taken:', round(total_time.total_seconds(),1),
	'\nstart_time:', start_time.strftime('%H:%M:%S'),
	'end_time:', end_time.strftime('%H:%M:%S'))
# Out:
# Epoch 1/300
# 2/2 [==============================] - 4s 570ms/step - loss: 32.9529 - val_loss: 11.6224
# Epoch 2/300
# 2/2 [==============================] - 0s 70ms/step - loss: 7.3538 - val_loss: 5.2476
# Epoch 3/300
# 2/2 [==============================] - 0s 74ms/step - loss: 5.0097 - val_loss: 4.6465
# Epoch 4/300
# 2/2 [==============================] - 0s 74ms/step - loss: 3.7660 - val_loss: 1.8546
# Epoch 5/300
# 2/2 [==============================] - 0s 72ms/step - loss: 2.5414 - val_loss: 37.0165
# Epoch 6/300
# 2/2 [==============================] - 0s 76ms/step - loss: 25.2047 - val_loss: 1.7870
# Epoch 7/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.7714 - val_loss: 3.0315
# Epoch 8/300
# 2/2 [==============================] - 0s 82ms/step - loss: 2.8804 - val_loss: 3.5570
# Epoch 9/300
# 2/2 [==============================] - 0s 83ms/step - loss: 3.0628 - val_loss: 3.2757
# Epoch 10/300
# 2/2 [==============================] - 0s 82ms/step - loss: 2.9043 - val_loss: 2.9290
# Epoch 11/300
# 2/2 [==============================] - 0s 78ms/step - loss: 2.6224 - val_loss: 2.6562
# Epoch 12/300
# 2/2 [==============================] - 0s 81ms/step - loss: 2.3568 - val_loss: 2.2676
# Epoch 13/300
# 2/2 [==============================] - 0s 97ms/step - loss: 1.9983 - val_loss: 1.7210
# Epoch 14/300
# 2/2 [==============================] - 0s 85ms/step - loss: 1.5654 - val_loss: 1.4805
# Epoch 15/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.4298 - val_loss: 1.4791
# Epoch 16/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.3308 - val_loss: 1.4786
# Epoch 17/300
# 2/2 [==============================] - 0s 80ms/step - loss: 1.3279 - val_loss: 1.4655
# Epoch 18/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.2586 - val_loss: 1.4345
# Epoch 19/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.3389 - val_loss: 1.4391
# Epoch 20/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.3866 - val_loss: 1.4691
# Epoch 21/300
# 2/2 [==============================] - 0s 78ms/step - loss: 1.3079 - val_loss: 1.5167
# Epoch 22/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.2911 - val_loss: 1.5049
# Epoch 23/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.2721 - val_loss: 1.4468
# Epoch 24/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.2501 - val_loss: 1.3878
# Epoch 25/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.2385 - val_loss: 1.4314
# Epoch 26/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.2309 - val_loss: 1.4593
# Epoch 27/300
# 2/2 [==============================] - 0s 80ms/step - loss: 1.2409 - val_loss: 1.4712
# Epoch 28/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.2419 - val_loss: 1.4758
# Epoch 29/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.2475 - val_loss: 1.4628
# Epoch 30/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.2382 - val_loss: 1.4508
# Epoch 31/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.2337 - val_loss: 1.4346
# Epoch 32/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.2175 - val_loss: 1.3491
# Epoch 33/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.1949 - val_loss: 1.4098
# Epoch 34/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.2027 - val_loss: 1.4306
# Epoch 35/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.2043 - val_loss: 1.4428
# Epoch 36/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.2180 - val_loss: 1.4443
# Epoch 37/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.2418 - val_loss: 1.4492
# Epoch 38/300
# 2/2 [==============================] - 0s 79ms/step - loss: 1.2246 - val_loss: 1.4726
# Epoch 39/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.2052 - val_loss: 1.4596
# Epoch 40/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.1898 - val_loss: 1.4179
# Epoch 41/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.2045 - val_loss: 1.4224
# Epoch 42/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.1861 - val_loss: 1.4654
# Epoch 43/300
# 2/2 [==============================] - 0s 64ms/step - loss: 1.1945 - val_loss: 1.4615
# Epoch 44/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.2092 - val_loss: 1.4271
# Epoch 45/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.2044 - val_loss: 1.4444
# Epoch 46/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.1819 - val_loss: 1.4241
# Epoch 47/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1525 - val_loss: 1.4030
# Epoch 48/300
# 2/2 [==============================] - 0s 64ms/step - loss: 1.1814 - val_loss: 1.4568
# Epoch 49/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1985 - val_loss: 1.4967
# Epoch 50/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.1896 - val_loss: 1.4572
# Epoch 51/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.2285 - val_loss: 1.4548
# Epoch 52/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1807 - val_loss: 1.4588
# Epoch 53/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.2143 - val_loss: 1.4243
# Epoch 54/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1343 - val_loss: 1.4563
# Epoch 55/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.1771 - val_loss: 1.4237
# Epoch 56/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1294 - val_loss: 1.3794
# Epoch 57/300
# 2/2 [==============================] - 0s 64ms/step - loss: 1.2110 - val_loss: 1.4594
# Epoch 58/300
# 2/2 [==============================] - 0s 63ms/step - loss: 1.1577 - val_loss: 1.5104
# Epoch 59/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.1790 - val_loss: 1.4298
# Epoch 60/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.2134 - val_loss: 1.4449
# Epoch 61/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1968 - val_loss: 1.4361
# Epoch 62/300
# 2/2 [==============================] - 0s 80ms/step - loss: 1.1238 - val_loss: 1.3408
# Epoch 63/300
# 2/2 [==============================] - 0s 79ms/step - loss: 1.2677 - val_loss: 1.4694
# Epoch 64/300
# 2/2 [==============================] - 0s 79ms/step - loss: 1.1756 - val_loss: 1.4920
# Epoch 65/300
# 2/2 [==============================] - 0s 89ms/step - loss: 1.1838 - val_loss: 1.4408
# Epoch 66/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.2561 - val_loss: 1.5219
# Epoch 67/300
# 2/2 [==============================] - 0s 84ms/step - loss: 1.1776 - val_loss: 1.4696
# Epoch 68/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.1059 - val_loss: 1.3918
# Epoch 69/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.1691 - val_loss: 1.4457
# Epoch 70/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1728 - val_loss: 1.4956
# Epoch 71/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.1702 - val_loss: 1.4375
# Epoch 72/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.2123 - val_loss: 1.5102
# Epoch 73/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.1862 - val_loss: 1.4682
# Epoch 74/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1454 - val_loss: 1.3759
# Epoch 75/300
# 2/2 [==============================] - 0s 78ms/step - loss: 1.1425 - val_loss: 1.4763
# Epoch 76/300
# 2/2 [==============================] - 0s 76ms/step - loss: 1.1327 - val_loss: 1.4962
# Epoch 77/300
# 2/2 [==============================] - 0s 63ms/step - loss: 1.1143 - val_loss: 1.4232
# Epoch 78/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1961 - val_loss: 1.4734
# Epoch 79/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0971 - val_loss: 1.4946
# Epoch 80/300
# 2/2 [==============================] - 0s 89ms/step - loss: 1.0704 - val_loss: 1.3938
# Epoch 81/300
# 2/2 [==============================] - 0s 59ms/step - loss: 1.1138 - val_loss: 1.4460
# Epoch 82/300
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0537 - val_loss: 1.6170
# Epoch 83/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0765 - val_loss: 1.3656
# Epoch 84/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.1352 - val_loss: 1.4667
# Epoch 85/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.1692 - val_loss: 1.4546
# Epoch 86/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1266 - val_loss: 1.3739
# Epoch 87/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.2139 - val_loss: 1.4066
# Epoch 88/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1046 - val_loss: 1.5261
# Epoch 89/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.1417 - val_loss: 1.4004
# Epoch 90/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0995 - val_loss: 1.4285
# Epoch 91/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.1111 - val_loss: 1.7306
# Epoch 92/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.1454 - val_loss: 1.4252
# Epoch 93/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.1061 - val_loss: 1.4492
# Epoch 94/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0901 - val_loss: 1.5796
# Epoch 95/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0822 - val_loss: 1.4062
# Epoch 96/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1124 - val_loss: 1.4398
# Epoch 97/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0734 - val_loss: 1.6813
# Epoch 98/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1103 - val_loss: 1.3524
# Epoch 99/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0721 - val_loss: 1.3633
# Epoch 100/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0593 - val_loss: 1.6701
# Epoch 101/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0661 - val_loss: 1.4239
# Epoch 102/300
# 2/2 [==============================] - 0s 78ms/step - loss: 1.0656 - val_loss: 1.4312
# Epoch 103/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0789 - val_loss: 1.5291
# Epoch 104/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0474 - val_loss: 1.6803
# Epoch 105/300
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0102 - val_loss: 1.6207
# Epoch 106/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0238 - val_loss: 1.4529
# Epoch 107/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0379 - val_loss: 1.4682
# Epoch 108/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0540 - val_loss: 1.3965
# Epoch 109/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0539 - val_loss: 1.6870
# Epoch 110/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0434 - val_loss: 1.6940
# Epoch 111/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0484 - val_loss: 1.3802
# Epoch 112/300
# 2/2 [==============================] - 0s 78ms/step - loss: 1.0836 - val_loss: 1.6664
# Epoch 113/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.1326 - val_loss: 1.4588
# Epoch 114/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1264 - val_loss: 1.3731
# Epoch 115/300
# 2/2 [==============================] - 0s 78ms/step - loss: 1.1465 - val_loss: 1.3910
# Epoch 116/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0791 - val_loss: 1.5618
# Epoch 117/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0716 - val_loss: 1.4051
# Epoch 118/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1207 - val_loss: 1.3999
# Epoch 119/300
# 2/2 [==============================] - 0s 79ms/step - loss: 1.0480 - val_loss: 1.7104
# Epoch 120/300
# 2/2 [==============================] - 0s 78ms/step - loss: 1.1494 - val_loss: 1.4852
# Epoch 121/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.1543 - val_loss: 1.4337
# Epoch 122/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.1089 - val_loss: 1.5318
# Epoch 123/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0671 - val_loss: 1.5180
# Epoch 124/300
# 2/2 [==============================] - 0s 90ms/step - loss: 1.0235 - val_loss: 1.3505
# Epoch 125/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0683 - val_loss: 1.4485
# Epoch 126/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0643 - val_loss: 1.6335
# Epoch 127/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1065 - val_loss: 1.3931
# Epoch 128/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0857 - val_loss: 1.3547
# Epoch 129/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0860 - val_loss: 1.6361
# Epoch 130/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0651 - val_loss: 1.6605
# Epoch 131/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.9936 - val_loss: 1.3470
# Epoch 132/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0710 - val_loss: 1.6666
# Epoch 133/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1100 - val_loss: 1.4314
# Epoch 134/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1294 - val_loss: 1.3388
# Epoch 135/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1698 - val_loss: 1.4354
# Epoch 136/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0669 - val_loss: 1.6301
# Epoch 137/300
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0672 - val_loss: 1.3641
# Epoch 138/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0417 - val_loss: 1.4043
# Epoch 139/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0190 - val_loss: 1.5450
# Epoch 140/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0539 - val_loss: 1.4121
# Epoch 141/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0693 - val_loss: 1.4378
# Epoch 142/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0496 - val_loss: 1.5010
# Epoch 143/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0443 - val_loss: 1.6246
# Epoch 144/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0444 - val_loss: 1.3317
# Epoch 145/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0351 - val_loss: 1.5363
# Epoch 146/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0507 - val_loss: 1.6140
# Epoch 147/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0636 - val_loss: 1.3457
# Epoch 148/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0702 - val_loss: 1.6858
# Epoch 149/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0557 - val_loss: 1.8376
# Epoch 150/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0374 - val_loss: 1.5359
# Epoch 151/300
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0539 - val_loss: 1.7583
# Epoch 152/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0971 - val_loss: 1.7178
# Epoch 153/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1247 - val_loss: 1.4033
# Epoch 154/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1533 - val_loss: 1.4026
# Epoch 155/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0880 - val_loss: 1.3970
# Epoch 156/300
# 2/2 [==============================] - 0s 84ms/step - loss: 1.1048 - val_loss: 1.3739
# Epoch 157/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0939 - val_loss: 1.4026
# Epoch 158/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0840 - val_loss: 1.4047
# Epoch 159/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0922 - val_loss: 1.3019
# Epoch 160/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0776 - val_loss: 1.5910
# Epoch 161/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0619 - val_loss: 1.4482
# Epoch 162/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0631 - val_loss: 1.6469
# Epoch 163/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0499 - val_loss: 1.6155
# Epoch 164/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0395 - val_loss: 1.5043
# Epoch 165/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0410 - val_loss: 1.7226
# Epoch 166/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0353 - val_loss: 1.3856
# Epoch 167/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0722 - val_loss: 1.7511
# Epoch 168/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0741 - val_loss: 1.3518
# Epoch 169/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0652 - val_loss: 1.3255
# Epoch 170/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.1390 - val_loss: 1.9746
# Epoch 171/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.1458 - val_loss: 1.3757
# Epoch 172/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0819 - val_loss: 1.3228
# Epoch 173/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1256 - val_loss: 1.5435
# Epoch 174/300
# 2/2 [==============================] - 0s 96ms/step - loss: 1.0965 - val_loss: 1.3819
# Epoch 175/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0722 - val_loss: 1.3712
# Epoch 176/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0856 - val_loss: 1.3517
# Epoch 177/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0415 - val_loss: 1.9162
# Epoch 178/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0795 - val_loss: 1.3599
# Epoch 179/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0630 - val_loss: 1.6589
# Epoch 180/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0792 - val_loss: 1.5471
# Epoch 181/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0679 - val_loss: 1.3865
# Epoch 182/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0868 - val_loss: 1.6929
# Epoch 183/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0342 - val_loss: 1.5435
# Epoch 184/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0207 - val_loss: 1.5623
# Epoch 185/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0166 - val_loss: 1.7529
# Epoch 186/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0372 - val_loss: 1.3792
# Epoch 187/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0779 - val_loss: 1.3343
# Epoch 188/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0372 - val_loss: 1.9285
# Epoch 189/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0719 - val_loss: 1.3439
# Epoch 190/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0665 - val_loss: 1.4057
# Epoch 191/300
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0345 - val_loss: 1.8521
# Epoch 192/300
# 2/2 [==============================] - 0s 85ms/step - loss: 1.0156 - val_loss: 1.5898
# Epoch 193/300
# 2/2 [==============================] - 0s 71ms/step - loss: 0.9880 - val_loss: 1.6899
# Epoch 194/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0141 - val_loss: 1.4124
# Epoch 195/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0320 - val_loss: 1.5631
# Epoch 196/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0276 - val_loss: 1.8495
# Epoch 197/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0095 - val_loss: 1.4832
# Epoch 198/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0051 - val_loss: 1.8183
# Epoch 199/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0171 - val_loss: 1.5820
# Epoch 200/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0212 - val_loss: 1.4315
# Epoch 201/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0165 - val_loss: 1.7485
# Epoch 202/300
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0011 - val_loss: 1.7549
# Epoch 203/300
# 2/2 [==============================] - 0s 69ms/step - loss: 0.9733 - val_loss: 1.6071
# Epoch 204/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0099 - val_loss: 1.8372
# Epoch 205/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0343 - val_loss: 1.5519
# Epoch 206/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0003 - val_loss: 1.6090
# Epoch 207/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0258 - val_loss: 1.6762
# Epoch 208/300
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9978 - val_loss: 1.9078
# Epoch 209/300
# 2/2 [==============================] - 0s 90ms/step - loss: 1.0393 - val_loss: 1.4169
# Epoch 210/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0927 - val_loss: 1.3590
# Epoch 211/300
# 2/2 [==============================] - 0s 78ms/step - loss: 1.0364 - val_loss: 1.9095
# Epoch 212/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0695 - val_loss: 1.3168
# Epoch 213/300
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0561 - val_loss: 1.2871
# Epoch 214/300
# 2/2 [==============================] - 0s 64ms/step - loss: 0.9945 - val_loss: 1.5242
# Epoch 215/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0294 - val_loss: 1.4177
# Epoch 216/300
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0768 - val_loss: 1.5640
# Epoch 217/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0421 - val_loss: 1.6214
# Epoch 218/300
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9931 - val_loss: 1.5420
# Epoch 219/300
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9906 - val_loss: 1.5704
# Epoch 220/300
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0095 - val_loss: 1.6103
# Epoch 221/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0308 - val_loss: 1.4829
# Epoch 222/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0168 - val_loss: 1.4774
# Epoch 223/300
# 2/2 [==============================] - 0s 67ms/step - loss: 0.9784 - val_loss: 1.3752
# Epoch 224/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0094 - val_loss: 1.5799
# Epoch 225/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0129 - val_loss: 1.3692
# Epoch 226/300
# 2/2 [==============================] - 0s 91ms/step - loss: 1.0495 - val_loss: 1.8111
# Epoch 227/300
# 2/2 [==============================] - 0s 65ms/step - loss: 0.9976 - val_loss: 1.4577
# Epoch 228/300
# 2/2 [==============================] - 0s 62ms/step - loss: 0.9646 - val_loss: 2.0442
# Epoch 229/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0209 - val_loss: 1.3213
# Epoch 230/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0880 - val_loss: 1.5659
# Epoch 231/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0212 - val_loss: 1.5726
# Epoch 232/300
# 2/2 [==============================] - 0s 71ms/step - loss: 0.9826 - val_loss: 1.4649
# Epoch 233/300
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9739 - val_loss: 1.6766
# Epoch 234/300
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0166 - val_loss: 1.3761
# Epoch 235/300
# 2/2 [==============================] - 0s 78ms/step - loss: 1.0527 - val_loss: 1.6287
# Epoch 236/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0156 - val_loss: 1.4234
# Epoch 237/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.9697 - val_loss: 1.8428
# Epoch 238/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0304 - val_loss: 1.2948
# Epoch 239/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0404 - val_loss: 1.5850
# Epoch 240/300
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9873 - val_loss: 1.3492
# Epoch 241/300
# 2/2 [==============================] - 0s 62ms/step - loss: 0.9959 - val_loss: 1.5395
# Epoch 242/300
# 2/2 [==============================] - 0s 117ms/step - loss: 1.0157 - val_loss: 1.4545
# Epoch 243/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0558 - val_loss: 1.3646
# Epoch 244/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0898 - val_loss: 1.5126
# Epoch 245/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0009 - val_loss: 1.2853
# Epoch 246/300
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0477 - val_loss: 1.7669
# Epoch 247/300
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0207 - val_loss: 1.3626
# Epoch 248/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0196 - val_loss: 1.6053
# Epoch 249/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9813 - val_loss: 1.4304
# Epoch 250/300
# 2/2 [==============================] - 0s 64ms/step - loss: 0.9886 - val_loss: 1.4742
# Epoch 251/300
# 2/2 [==============================] - 0s 66ms/step - loss: 0.9920 - val_loss: 1.6928
# Epoch 252/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0400 - val_loss: 1.3470
# Epoch 253/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0658 - val_loss: 1.4337
# Epoch 254/300
# 2/2 [==============================] - 0s 69ms/step - loss: 0.9682 - val_loss: 1.8153
# Epoch 255/300
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9734 - val_loss: 1.3146
# Epoch 256/300
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9823 - val_loss: 1.8236
# Epoch 257/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0517 - val_loss: 1.3180
# Epoch 258/300
# 2/2 [==============================] - 0s 98ms/step - loss: 1.0039 - val_loss: 1.4951
# Epoch 259/300
# 2/2 [==============================] - 0s 64ms/step - loss: 0.9762 - val_loss: 1.5018
# Epoch 260/300
# 2/2 [==============================] - 0s 65ms/step - loss: 0.9705 - val_loss: 1.4443
# Epoch 261/300
# 2/2 [==============================] - 0s 62ms/step - loss: 0.9675 - val_loss: 1.2972
# Epoch 262/300
# 2/2 [==============================] - 0s 64ms/step - loss: 0.9704 - val_loss: 1.7805
# Epoch 263/300
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9944 - val_loss: 1.1845
# Epoch 264/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0945 - val_loss: 2.3082
# Epoch 265/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1036 - val_loss: 1.2717
# Epoch 266/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1885 - val_loss: 1.3274
# Epoch 267/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0778 - val_loss: 1.9253
# Epoch 268/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1093 - val_loss: 1.3770
# Epoch 269/300
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0519 - val_loss: 1.3390
# Epoch 270/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0303 - val_loss: 1.5994
# Epoch 271/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0191 - val_loss: 1.5381
# Epoch 272/300
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0307 - val_loss: 1.4005
# Epoch 273/300
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0451 - val_loss: 1.4625
# Epoch 274/300
# 2/2 [==============================] - 0s 90ms/step - loss: 1.0790 - val_loss: 1.5599
# Epoch 275/300
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9815 - val_loss: 1.2976
# Epoch 276/300
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0237 - val_loss: 1.4785
# Epoch 277/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0100 - val_loss: 1.6520
# Epoch 278/300
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0358 - val_loss: 1.2833
# Epoch 279/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0228 - val_loss: 2.0337
# Epoch 280/300
# 2/2 [==============================] - 0s 69ms/step - loss: 0.9975 - val_loss: 1.2274
# Epoch 281/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0432 - val_loss: 1.5217
# Epoch 282/300
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0072 - val_loss: 1.4966
# Epoch 283/300
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0379 - val_loss: 1.2601
# Epoch 284/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0013 - val_loss: 1.8731
# Epoch 285/300
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9870 - val_loss: 1.2666
# Epoch 286/300
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0234 - val_loss: 1.6446
# Epoch 287/300
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0255 - val_loss: 1.4532
# Epoch 288/300
# 2/2 [==============================] - 0s 67ms/step - loss: 0.9844 - val_loss: 1.4561
# Epoch 289/300
# 2/2 [==============================] - 0s 66ms/step - loss: 0.9678 - val_loss: 1.4565
# Epoch 290/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9991 - val_loss: 1.5291
# Epoch 291/300
# 2/2 [==============================] - 0s 65ms/step - loss: 0.9830 - val_loss: 1.4616
# Epoch 292/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9535 - val_loss: 1.2380
# Epoch 293/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.9820 - val_loss: 1.7476
# Epoch 294/300
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0195 - val_loss: 1.3224
# Epoch 295/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0545 - val_loss: 1.2888
# Epoch 296/300
# 2/2 [==============================] - 0s 70ms/step - loss: 0.9752 - val_loss: 1.9071
# Epoch 297/300
# 2/2 [==============================] - 0s 63ms/step - loss: 0.9908 - val_loss: 1.2523
# Epoch 298/300
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0339 - val_loss: 1.4707
# Epoch 299/300
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0447 - val_loss: 1.5112
# Epoch 300/300
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0413 - val_loss: 1.3130
# seconds taken: 34.0
# start_time: 23:12:42 end_time: 23:13:16

# %%
fig,ax = plt.subplots()
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='test loss')
ax.set_xlabel('EPOCHS')
ax.set_ylabel('Loss value')
plt.legend()

# %%
y_pred = model.predict(test_x, verbose=0)
test_y_ = np.squeeze(test_y[:,0])
y_u_pred = y_pred[:,0]
y_l_pred = y_pred[:,1]
K_u = y_u_pred > test_y_
K_l = y_l_pred < test_y_
print('PICP:', np.mean(K_u * K_l))
print('MPIW:', np.round(np.mean(y_u_pred - y_l_pred),3))
# Out:
# PICP: 0.9528301886792453
# MPIW: 26.975

# %%
actual=test_y
actual = np.squeeze(actual)
pred1=y_u_pred
pred2=y_l_pred
numEx = range(len(actual))
plt.figure(figsize=(15, 8))
plt.plot(numEx,actual,label='Actual')
plt.plot(numEx,pred1,label='f1')
plt.plot(numEx,pred2,label='f2')
plt.legend(loc='best')
plt.title('Actual vs Pred')
plt.show()
