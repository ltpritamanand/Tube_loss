# %%
import numpy as np
import pandas as pd
import math
import tensorflow as tf
import keras.backend as K
import datetime
import matplotlib.pyplot as plt
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
tf.keras.utils.set_random_seed(48)
tf.config.experimental.enable_op_determinism()

# %%
r = 0.5
q = 0.95
delta = 0.02
l = 2

def confidence_loss(y_true, y_pred):
    y_true = y_true[:, 0]
    f1 = y_pred[:, 0]
    f2 = y_pred[:, 1]

    c1 = (1 - q) * (y_true - f2)
    c2 = (1 - q) * (f1 - y_true)
    c3 = q * (f2 - y_true)
    c4 = q * (y_true - f1)

    loss = K.switch(tf.math.logical_and((y_true <= f1), (y_true >= f2)),
                    K.switch((y_true > r * (f1 + f2)), c1, c2),
                    K.switch((f2 > y_true), c3, c4)) + (delta * tf.math.abs(f1 - f2))

    return loss

# %%
dataset = pd.read_csv("datasets_56102_107707_monthly-beer-production-in-austr.csv")

dataset["Month"] = pd.to_datetime(dataset["Month"])
dataset["Monthly beer production"] = dataset["Monthly beer production"].astype(float)

# %%
data = dataset["Monthly beer production"].to_numpy().reshape((len(dataset["Monthly beer production"]), 1))

# %%
mean_data = np.mean(data)
std_data = np.std(data)

def relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

if std_data == 0:
    data_normalized = data - mean_data  # Only mean-center if std is 0
else:
    data_normalized = (data - mean_data) / std_data  # Standardize normally

# %%
def truncate(x, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=100, test_len=20):
    in_, out_ = [], []
    for i in range(len(x) - train_len - test_len + 1):
        in_.append(x[i:(i + train_len), feature_cols].tolist())
        out_.append(x[(i + train_len):(i + train_len + test_len), target_cols].tolist())
    return np.array(in_), np.array(out_)

X_in, X_out = truncate(data, feature_cols=range(1), target_cols=range(1), label_col=1, train_len=12, test_len=1)

# %%
train_x = X_in[:math.floor(X_in.shape[0] * 0.70)]
train_y = X_out[:math.floor(X_out.shape[0] * 0.70)]
test_x = X_in[math.floor(X_in.shape[0] * 0.70):]
test_y = X_out[math.floor(X_out.shape[0] * 0.70):]
print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
# Out:
# (324, 12, 1) (140, 12, 1) (324, 1, 1) (140, 1, 1)

# %%
input_train = Input(shape=(12, 1))  
initializer = tf.keras.initializers.he_normal(seed=128)
lstm_l1 = LSTM(64, activation='relu', kernel_initializer=initializer, return_sequences=True)(input_train)
lstm_l2 = LSTM(32, activation='relu', kernel_initializer=initializer, return_sequences=False)(lstm_l1)

out = Dense(2)(lstm_l2) 
model = Model(inputs=input_train, outputs=out)

opt = Adam(learning_rate=0.01)
model.compile(loss=confidence_loss, optimizer=opt)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 12, 1)]           0
#
#  lstm (LSTM)                 (None, 12, 64)            16896
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 2)                 66
#
# =================================================================
# Total params: 29378 (114.76 KB)
# Trainable params: 29378 (114.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
epochs = 300
start_time = datetime.datetime.now()
stop_patience = 5
#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=stop_patience, mode='min')
history = model.fit(train_x, train_y, validation_split=0.1, epochs=epochs, verbose=1, batch_size=64)#,callbacks=[early_stopping]
end_time = datetime.datetime.now()
total_time = end_time - start_time
print(f'Seconds taken: {round(total_time.total_seconds(), 1)}, Start time: {start_time.strftime("%H:%M:%S")}, End time: {end_time.strftime("%H:%M:%S")}')

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


y_pred = model.predict(test_x, verbose=0)
test_y_ = np.squeeze(test_y)  # Actual test values
y_u_pred = y_pred[:, 0]  # Upper bound predictions
y_l_pred = y_pred[:, 1]  # Lower bound predictions

K_u = y_u_pred > test_y_
K_l = y_l_pred < test_y_

print(f'PICP: {np.mean(K_u * K_l)}')
print(f'MPIW: {np.round(np.mean(y_u_pred - y_l_pred), 3)}')


actual = np.squeeze(test_y)
pred1 = y_u_pred
pred2 = y_l_pred
numEx = range(len(actual))
plt.figure(figsize=(15, 8))
plt.plot(numEx, actual, label='Actual')
plt.plot(numEx, pred1, label='Upper Bound (f1)')
plt.plot(numEx, pred2, label='Lower Bound (f2)')
plt.legend(loc='best')
plt.title('Actual vs Predicted (Upper and Lower Bounds)')
plt.show()
#0.005,6,7,8
# Out:
# Epoch 1/300
# 5/5 [==============================] - 3s 112ms/step - loss: 563.2410 - val_loss: 104.9631
# Epoch 2/300
# 5/5 [==============================] - 0s 19ms/step - loss: 56.2362 - val_loss: 25.0350
# Epoch 3/300
# 5/5 [==============================] - 0s 18ms/step - loss: 16.8298 - val_loss: 24.8237
# Epoch 4/300
# 5/5 [==============================] - 0s 18ms/step - loss: 25.0132 - val_loss: 19.7487
# Epoch 5/300
# 5/5 [==============================] - 0s 18ms/step - loss: 16.3477 - val_loss: 23.2325
# Epoch 6/300
# 5/5 [==============================] - 0s 20ms/step - loss: 17.6570 - val_loss: 24.4166
# Epoch 7/300
# 5/5 [==============================] - 0s 16ms/step - loss: 18.5859 - val_loss: 23.9854
# Epoch 8/300
# 5/5 [==============================] - 0s 19ms/step - loss: 18.2204 - val_loss: 24.3583
# Epoch 9/300
# 5/5 [==============================] - 0s 26ms/step - loss: 17.1653 - val_loss: 21.0541
# Epoch 10/300
# 5/5 [==============================] - 0s 19ms/step - loss: 15.4256 - val_loss: 19.2253
# Epoch 11/300
# 5/5 [==============================] - 0s 18ms/step - loss: 13.7731 - val_loss: 16.9836
# Epoch 12/300
# 5/5 [==============================] - 0s 18ms/step - loss: 11.8804 - val_loss: 15.4129
# Epoch 13/300
# 5/5 [==============================] - 0s 18ms/step - loss: 11.3060 - val_loss: 14.2523
# Epoch 14/300
# 5/5 [==============================] - 0s 18ms/step - loss: 10.6875 - val_loss: 13.1374
# Epoch 15/300
# 5/5 [==============================] - 0s 18ms/step - loss: 9.5793 - val_loss: 11.5926
# Epoch 16/300
# 5/5 [==============================] - 0s 18ms/step - loss: 8.8202 - val_loss: 10.9261
# Epoch 17/300
# 5/5 [==============================] - 0s 18ms/step - loss: 8.1594 - val_loss: 9.7980
# Epoch 18/300
# 5/5 [==============================] - 0s 17ms/step - loss: 7.2773 - val_loss: 8.6138
# Epoch 19/300
# 5/5 [==============================] - 0s 17ms/step - loss: 6.3690 - val_loss: 7.5788
# Epoch 20/300
# 5/5 [==============================] - 0s 18ms/step - loss: 5.5627 - val_loss: 6.7379
# Epoch 21/300
# 5/5 [==============================] - 0s 16ms/step - loss: 4.9395 - val_loss: 6.3029
# Epoch 22/300
# 5/5 [==============================] - 0s 19ms/step - loss: 4.1989 - val_loss: 4.8421
# Epoch 23/300
# 5/5 [==============================] - 0s 17ms/step - loss: 3.0556 - val_loss: 3.3846
# Epoch 24/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.4209 - val_loss: 4.7794
# Epoch 25/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.3100 - val_loss: 3.5636
# Epoch 26/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2019 - val_loss: 4.1141
# Epoch 27/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.3510 - val_loss: 3.6601
# Epoch 28/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2182 - val_loss: 3.5336
# Epoch 29/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.2784 - val_loss: 3.7678
# Epoch 30/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.2510 - val_loss: 3.5632
# Epoch 31/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1873 - val_loss: 3.7475
# Epoch 32/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1543 - val_loss: 3.8636
# Epoch 33/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3637 - val_loss: 3.8475
# Epoch 34/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.2571 - val_loss: 5.0677
# Epoch 35/300
# 5/5 [==============================] - 0s 18ms/step - loss: 3.2802 - val_loss: 5.8578
# Epoch 36/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.8325 - val_loss: 4.1899
# Epoch 37/300
# 5/5 [==============================] - 0s 19ms/step - loss: 3.2110 - val_loss: 5.6261
# Epoch 38/300
# 5/5 [==============================] - 0s 24ms/step - loss: 3.0624 - val_loss: 4.6095
# Epoch 39/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.5795 - val_loss: 3.7424
# Epoch 40/300
# 5/5 [==============================] - 0s 25ms/step - loss: 2.2815 - val_loss: 4.1445
# Epoch 41/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.3038 - val_loss: 4.3116
# Epoch 42/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2187 - val_loss: 3.6091
# Epoch 43/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1709 - val_loss: 4.1411
# Epoch 44/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.2321 - val_loss: 3.7658
# Epoch 45/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1351 - val_loss: 3.7847
# Epoch 46/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0928 - val_loss: 3.7993
# Epoch 47/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1932 - val_loss: 3.9650
# Epoch 48/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1275 - val_loss: 3.7932
# Epoch 49/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1918 - val_loss: 3.7466
# Epoch 50/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0987 - val_loss: 3.9684
# Epoch 51/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1311 - val_loss: 3.8882
# Epoch 52/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2462 - val_loss: 3.7720
# Epoch 53/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1389 - val_loss: 4.0366
# Epoch 54/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.4533 - val_loss: 3.9846
# Epoch 55/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0965 - val_loss: 3.6041
# Epoch 56/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1195 - val_loss: 3.9667
# Epoch 57/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1291 - val_loss: 3.8008
# Epoch 58/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1831 - val_loss: 3.6778
# Epoch 59/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0868 - val_loss: 3.6190
# Epoch 60/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0786 - val_loss: 3.7682
# Epoch 61/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0859 - val_loss: 3.7586
# Epoch 62/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0885 - val_loss: 3.6944
# Epoch 63/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0202 - val_loss: 3.9121
# Epoch 64/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1283 - val_loss: 3.6795
# Epoch 65/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1295 - val_loss: 4.4239
# Epoch 66/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3418 - val_loss: 3.4081
# Epoch 67/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2402 - val_loss: 4.1830
# Epoch 68/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1675 - val_loss: 3.8066
# Epoch 69/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1215 - val_loss: 3.7700
# Epoch 70/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0541 - val_loss: 3.8310
# Epoch 71/300
# 5/5 [==============================] - 0s 28ms/step - loss: 2.0952 - val_loss: 3.5680
# Epoch 72/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1043 - val_loss: 3.8341
# Epoch 73/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0400 - val_loss: 3.9417
# Epoch 74/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1887 - val_loss: 3.7260
# Epoch 75/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0556 - val_loss: 3.8236
# Epoch 76/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1025 - val_loss: 3.8023
# Epoch 77/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.2113 - val_loss: 3.7542
# Epoch 78/300
# 5/5 [==============================] - 0s 15ms/step - loss: 2.0720 - val_loss: 3.8579
# Epoch 79/300
# 5/5 [==============================] - 0s 24ms/step - loss: 2.0514 - val_loss: 4.6920
# Epoch 80/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2709 - val_loss: 3.5275
# Epoch 81/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1364 - val_loss: 3.7622
# Epoch 82/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0838 - val_loss: 3.8273
# Epoch 83/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1141 - val_loss: 3.7271
# Epoch 84/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0802 - val_loss: 4.0688
# Epoch 85/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1118 - val_loss: 3.8467
# Epoch 86/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1712 - val_loss: 3.9047
# Epoch 87/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0320 - val_loss: 3.8813
# Epoch 88/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0185 - val_loss: 3.8923
# Epoch 89/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0811 - val_loss: 3.6838
# Epoch 90/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0442 - val_loss: 3.8783
# Epoch 91/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0418 - val_loss: 3.7369
# Epoch 92/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0240 - val_loss: 4.0753
# Epoch 93/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1493 - val_loss: 3.5818
# Epoch 94/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1274 - val_loss: 3.9527
# Epoch 95/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1055 - val_loss: 3.9560
# Epoch 96/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0762 - val_loss: 3.7929
# Epoch 97/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0647 - val_loss: 3.7845
# Epoch 98/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0770 - val_loss: 3.8817
# Epoch 99/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1759 - val_loss: 3.8583
# Epoch 100/300
# 5/5 [==============================] - 0s 24ms/step - loss: 2.0421 - val_loss: 4.1210
# Epoch 101/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2177 - val_loss: 3.6115
# Epoch 102/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.3104 - val_loss: 5.3654
# Epoch 103/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.5644 - val_loss: 3.5607
# Epoch 104/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2460 - val_loss: 4.1265
# Epoch 105/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1250 - val_loss: 3.8179
# Epoch 106/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0083 - val_loss: 4.1156
# Epoch 107/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1794 - val_loss: 3.8059
# Epoch 108/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1563 - val_loss: 3.9460
# Epoch 109/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0724 - val_loss: 3.8625
# Epoch 110/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1073 - val_loss: 3.7086
# Epoch 111/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0413 - val_loss: 4.2065
# Epoch 112/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.4777 - val_loss: 3.8878
# Epoch 113/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1387 - val_loss: 4.3640
# Epoch 114/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3180 - val_loss: 3.6481
# Epoch 115/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.4585 - val_loss: 5.6017
# Epoch 116/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6785 - val_loss: 3.4233
# Epoch 117/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.3537 - val_loss: 5.2790
# Epoch 118/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4298 - val_loss: 3.7216
# Epoch 119/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.2647 - val_loss: 4.2053
# Epoch 120/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1229 - val_loss: 3.7159
# Epoch 121/300
# 5/5 [==============================] - 0s 31ms/step - loss: 2.1814 - val_loss: 3.8941
# Epoch 122/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0455 - val_loss: 3.9710
# Epoch 123/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1155 - val_loss: 3.7319
# Epoch 124/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0522 - val_loss: 4.2122
# Epoch 125/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2069 - val_loss: 3.4979
# Epoch 126/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0908 - val_loss: 4.1878
# Epoch 127/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.2159 - val_loss: 3.8419
# Epoch 128/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2737 - val_loss: 4.2973
# Epoch 129/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2431 - val_loss: 3.5243
# Epoch 130/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3710 - val_loss: 4.0755
# Epoch 131/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2159 - val_loss: 4.1528
# Epoch 132/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2675 - val_loss: 3.7475
# Epoch 133/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1355 - val_loss: 4.4892
# Epoch 134/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0938 - val_loss: 3.7024
# Epoch 135/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0433 - val_loss: 4.3426
# Epoch 136/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2311 - val_loss: 3.5121
# Epoch 137/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1489 - val_loss: 4.2425
# Epoch 138/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1231 - val_loss: 3.6578
# Epoch 139/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1120 - val_loss: 4.0662
# Epoch 140/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0790 - val_loss: 3.9606
# Epoch 141/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0105 - val_loss: 4.3342
# Epoch 142/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1353 - val_loss: 3.8518
# Epoch 143/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1341 - val_loss: 3.7693
# Epoch 144/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0301 - val_loss: 3.8749
# Epoch 145/300
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0529 - val_loss: 3.6262
# Epoch 146/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0643 - val_loss: 3.8399
# Epoch 147/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0438 - val_loss: 3.8474
# Epoch 148/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0249 - val_loss: 3.9636
# Epoch 149/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1041 - val_loss: 3.5060
# Epoch 150/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1038 - val_loss: 4.1405
# Epoch 151/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2139 - val_loss: 3.5861
# Epoch 152/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0689 - val_loss: 3.9925
# Epoch 153/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0739 - val_loss: 3.9334
# Epoch 154/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0019 - val_loss: 4.4675
# Epoch 155/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.2500 - val_loss: 3.5184
# Epoch 156/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.3412 - val_loss: 3.8059
# Epoch 157/300
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2097 - val_loss: 4.0797
# Epoch 158/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.2575 - val_loss: 3.8288
# Epoch 159/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0341 - val_loss: 3.9736
# Epoch 160/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1024 - val_loss: 3.9077
# Epoch 161/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2686 - val_loss: 4.2391
# Epoch 162/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1049 - val_loss: 3.7230
# Epoch 163/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3682 - val_loss: 3.5686
# Epoch 164/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1273 - val_loss: 4.0465
# Epoch 165/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0882 - val_loss: 3.9043
# Epoch 166/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0950 - val_loss: 4.0280
# Epoch 167/300
# 5/5 [==============================] - 0s 28ms/step - loss: 2.1351 - val_loss: 3.7188
# Epoch 168/300
# 5/5 [==============================] - 0s 23ms/step - loss: 2.1046 - val_loss: 3.8583
# Epoch 169/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.0025 - val_loss: 3.9414
# Epoch 170/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.2170 - val_loss: 3.5246
# Epoch 171/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1266 - val_loss: 4.4798
# Epoch 172/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.2908 - val_loss: 3.7656
# Epoch 173/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2209 - val_loss: 4.8732
# Epoch 174/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.4618 - val_loss: 3.7285
# Epoch 175/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6089 - val_loss: 5.0816
# Epoch 176/300
# 5/5 [==============================] - 0s 15ms/step - loss: 2.4514 - val_loss: 3.6130
# Epoch 177/300
# 5/5 [==============================] - 0s 15ms/step - loss: 2.3958 - val_loss: 5.2090
# Epoch 178/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.3229 - val_loss: 3.6025
# Epoch 179/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.3342 - val_loss: 3.8942
# Epoch 180/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.3023 - val_loss: 3.6186
# Epoch 181/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0595 - val_loss: 4.2017
# Epoch 182/300
# 5/5 [==============================] - 0s 28ms/step - loss: 2.1819 - val_loss: 4.9938
# Epoch 183/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.4626 - val_loss: 3.5286
# Epoch 184/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.3533 - val_loss: 3.7610
# Epoch 185/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1553 - val_loss: 3.9465
# Epoch 186/300
# 5/5 [==============================] - 0s 23ms/step - loss: 2.0966 - val_loss: 4.0249
# Epoch 187/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.0177 - val_loss: 3.7418
# Epoch 188/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1484 - val_loss: 3.8111
# Epoch 189/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1644 - val_loss: 3.5589
# Epoch 190/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1669 - val_loss: 3.7381
# Epoch 191/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0420 - val_loss: 4.0429
# Epoch 192/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0248 - val_loss: 3.7705
# Epoch 193/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0044 - val_loss: 3.7735
# Epoch 194/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0914 - val_loss: 3.5996
# Epoch 195/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0970 - val_loss: 4.0119
# Epoch 196/300
# 5/5 [==============================] - 0s 39ms/step - loss: 2.0322 - val_loss: 3.9398
# Epoch 197/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0829 - val_loss: 3.6678
# Epoch 198/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0433 - val_loss: 4.1815
# Epoch 199/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1876 - val_loss: 3.8391
# Epoch 200/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0578 - val_loss: 4.3531
# Epoch 201/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1990 - val_loss: 3.4953
# Epoch 202/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1391 - val_loss: 3.8323
# Epoch 203/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0691 - val_loss: 3.9582
# Epoch 204/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0900 - val_loss: 3.9813
# Epoch 205/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1240 - val_loss: 3.7525
# Epoch 206/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0816 - val_loss: 3.8543
# Epoch 207/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0390 - val_loss: 3.7189
# Epoch 208/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0717 - val_loss: 4.0885
# Epoch 209/300
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2155 - val_loss: 3.7501
# Epoch 210/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.3844 - val_loss: 3.8676
# Epoch 211/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1690 - val_loss: 3.8860
# Epoch 212/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.4627 - val_loss: 3.9953
# Epoch 213/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.0300 - val_loss: 3.9454
# Epoch 214/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.0476 - val_loss: 3.7980
# Epoch 215/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0446 - val_loss: 4.0408
# Epoch 216/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1181 - val_loss: 3.7374
# Epoch 217/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0891 - val_loss: 3.8598
# Epoch 218/300
# 5/5 [==============================] - 0s 30ms/step - loss: 2.0711 - val_loss: 4.1418
# Epoch 219/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1323 - val_loss: 3.5380
# Epoch 220/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2877 - val_loss: 4.4177
# Epoch 221/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.2669 - val_loss: 3.8835
# Epoch 222/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.3977 - val_loss: 3.6544
# Epoch 223/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2703 - val_loss: 3.9258
# Epoch 224/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.5376 - val_loss: 3.8094
# Epoch 225/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1517 - val_loss: 4.0197
# Epoch 226/300
# 5/5 [==============================] - 0s 24ms/step - loss: 2.0324 - val_loss: 3.8084
# Epoch 227/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0850 - val_loss: 3.7458
# Epoch 228/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0531 - val_loss: 3.9285
# Epoch 229/300
# 5/5 [==============================] - 0s 25ms/step - loss: 2.1772 - val_loss: 3.8019
# Epoch 230/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.0630 - val_loss: 3.9155
# Epoch 231/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0701 - val_loss: 3.5979
# Epoch 232/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1002 - val_loss: 3.6783
# Epoch 233/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0405 - val_loss: 4.0824
# Epoch 234/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0202 - val_loss: 3.9310
# Epoch 235/300
# 5/5 [==============================] - 0s 23ms/step - loss: 2.0258 - val_loss: 3.8515
# Epoch 236/300
# 5/5 [==============================] - 0s 22ms/step - loss: 2.1866 - val_loss: 3.6253
# Epoch 237/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0463 - val_loss: 4.1743
# Epoch 238/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.0326 - val_loss: 3.8767
# Epoch 239/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0862 - val_loss: 3.6541
# Epoch 240/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0641 - val_loss: 3.7049
# Epoch 241/300
# 5/5 [==============================] - 0s 22ms/step - loss: 1.9843 - val_loss: 4.3725
# Epoch 242/300
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0637 - val_loss: 3.6369
# Epoch 243/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0962 - val_loss: 3.6803
# Epoch 244/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0773 - val_loss: 3.9663
# Epoch 245/300
# 5/5 [==============================] - 0s 23ms/step - loss: 2.0073 - val_loss: 3.7438
# Epoch 246/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1199 - val_loss: 3.6751
# Epoch 247/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1954 - val_loss: 3.9822
# Epoch 248/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0434 - val_loss: 3.9923
# Epoch 249/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0015 - val_loss: 4.0291
# Epoch 250/300
# 5/5 [==============================] - 0s 23ms/step - loss: 2.0898 - val_loss: 3.6574
# Epoch 251/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.1763 - val_loss: 3.6960
# Epoch 252/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1163 - val_loss: 4.0771
# Epoch 253/300
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0977 - val_loss: 3.8388
# Epoch 254/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.3638 - val_loss: 3.6242
# Epoch 255/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.2257 - val_loss: 5.7409
# Epoch 256/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7155 - val_loss: 3.5138
# Epoch 257/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.3285 - val_loss: 4.6229
# Epoch 258/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.3241 - val_loss: 3.7594
# Epoch 259/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2674 - val_loss: 3.7102
# Epoch 260/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1717 - val_loss: 3.9046
# Epoch 261/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1286 - val_loss: 3.9195
# Epoch 262/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9969 - val_loss: 4.0373
# Epoch 263/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1362 - val_loss: 3.7154
# Epoch 264/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0632 - val_loss: 3.6201
# Epoch 265/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0742 - val_loss: 4.1069
# Epoch 266/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9933 - val_loss: 3.7505
# Epoch 267/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0799 - val_loss: 3.6704
# Epoch 268/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0399 - val_loss: 3.9448
# Epoch 269/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1177 - val_loss: 3.7144
# Epoch 270/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0843 - val_loss: 4.1030
# Epoch 271/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0572 - val_loss: 3.7639
# Epoch 272/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0300 - val_loss: 4.0671
# Epoch 273/300
# 5/5 [==============================] - 0s 18ms/step - loss: 1.9825 - val_loss: 3.6464
# Epoch 274/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0658 - val_loss: 3.8398
# Epoch 275/300
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1271 - val_loss: 3.9829
# Epoch 276/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1557 - val_loss: 3.6577
# Epoch 277/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0681 - val_loss: 3.8595
# Epoch 278/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0001 - val_loss: 3.9235
# Epoch 279/300
# 5/5 [==============================] - 0s 15ms/step - loss: 1.9853 - val_loss: 3.9616
# Epoch 280/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0094 - val_loss: 3.6248
# Epoch 281/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0522 - val_loss: 4.0376
# Epoch 282/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0291 - val_loss: 3.6719
# Epoch 283/300
# 5/5 [==============================] - 0s 15ms/step - loss: 2.0609 - val_loss: 3.9275
# Epoch 284/300
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9999 - val_loss: 3.9142
# Epoch 285/300
# 5/5 [==============================] - 0s 15ms/step - loss: 2.1593 - val_loss: 3.5604
# Epoch 286/300
# 5/5 [==============================] - 0s 15ms/step - loss: 2.1172 - val_loss: 3.7834
# Epoch 287/300
# 5/5 [==============================] - 0s 15ms/step - loss: 2.0353 - val_loss: 4.0783
# Epoch 288/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1101 - val_loss: 3.5383
# Epoch 289/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1607 - val_loss: 3.6130
# Epoch 290/300
# 5/5 [==============================] - 0s 15ms/step - loss: 2.0078 - val_loss: 4.1193
# Epoch 291/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0221 - val_loss: 3.6717
# Epoch 292/300
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1157 - val_loss: 4.3455
# Epoch 293/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1675 - val_loss: 3.6149
# Epoch 294/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2126 - val_loss: 3.9726
# Epoch 295/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0963 - val_loss: 4.1605
# Epoch 296/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.3816 - val_loss: 3.5187
# Epoch 297/300
# 5/5 [==============================] - 0s 16ms/step - loss: 2.2161 - val_loss: 4.0392
# Epoch 298/300
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1210 - val_loss: 3.9984
# Epoch 299/300
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0064 - val_loss: 3.9455
# Epoch 300/300
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0757 - val_loss: 3.5265
# Seconds taken: 30.2, Start time: 18:30:45, End time: 18:31:15
# PICP: 0.95
# MPIW: 46.816001892089844
